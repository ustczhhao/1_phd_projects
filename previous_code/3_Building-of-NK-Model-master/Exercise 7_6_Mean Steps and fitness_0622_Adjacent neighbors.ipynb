# %%
aver_step = []
std_step = []
aver_optimal_fitness = []
std_optimal_fitness = []

# %%
# %run E7_6_Readfile.py

# %%
# N =4 
# walk_4_list = [walk_40, walk_41, walk_42, walk_43]
walk_4_list = [walk_40, walk_42, walk_43]

for i in walk_4_list:
    step_length = []
    optimal_fitness = []
    for j in i:
        for s in j:
            step_length.append(len(s))
            optimal_fitness.append(s[-1][-1])
            
    aver_step_length = sum(step_length)/len(step_length)
    std_step_length = np.std(step_length, ddof = 1)
    aver_fitness = sum(optimal_fitness)/len(optimal_fitness)
    std_fitness = np.std(optimal_fitness, ddof = 1)
    
    aver_step.append(aver_step_length)
    std_step.append(std_step_length)
    aver_optimal_fitness.append(aver_fitness)
    std_optimal_fitness.append(std_fitness)
    
print(aver_step)
print(std_step)
print(aver_optimal_fitness)
print(std_optimal_fitness)
# Out:
# [2.969, 2.713, 2.5]
# [0.95128541665682231, 1.2239808532526679, 1.1972608042667368]
# [0.675576553532616, 0.6947598311887023, 0.6875025865055163]
# [0.11088839258876874, 0.095349476754792661, 0.09138455988198739]

# %%
# N =8

# walk_8_list = [walk_80, walk_81, walk_82, walk_83, walk_84, walk_85, walk_86, walk_87]
walk_8_list = [walk_80, walk_82, walk_84, walk_86, walk_87]

for i in walk_8_list:
    step_length = []
    optimal_fitness = []
    for j in i:
        for s in j:
            step_length.append(len(s))
            optimal_fitness.append(s[-1][-1])
            
    aver_step_length = sum(step_length)/len(step_length)
    std_step_length = np.std(step_length, ddof = 1)
    aver_fitness = sum(optimal_fitness)/len(optimal_fitness)
    std_fitness = np.std(optimal_fitness, ddof = 1)
    
    aver_step.append(aver_step_length)
    std_step.append(std_step_length)
    aver_optimal_fitness.append(aver_fitness)
    std_optimal_fitness.append(std_fitness)
    
print(aver_step)
print(std_step)
print(aver_optimal_fitness)
print(std_optimal_fitness)

print(aver_step[3:])
print(std_step[3:])
print(aver_optimal_fitness[3:])
print(std_optimal_fitness[3:])
# Out:
# [2.969, 2.713, 2.5, 4.96, 4.755, 3.935, 3.33, 3.115]
# [0.95128541665682231, 1.2239808532526679, 1.1972608042667368, 1.3994135765949816, 2.0560160996943098, 1.7854867579914906, 1.488393535095915, 1.4034759508964678]
# [0.675576553532616, 0.6947598311887023, 0.6875025865055163, 0.6726109903224868, 0.7073854637592196, 0.6979248732516914, 0.6775554168792669, 0.6696911600744847]
# [0.11088839258876874, 0.095349476754792661, 0.09138455988198739, 0.074465444909923781, 0.068202699524267899, 0.055881979296812441, 0.05655406665393263, 0.05417212055164343]
# [4.96, 4.755, 3.935, 3.33, 3.115]
# [1.3994135765949816, 2.0560160996943098, 1.7854867579914906, 1.488393535095915, 1.4034759508964678]
# [0.6726109903224868, 0.7073854637592196, 0.6979248732516914, 0.6775554168792669, 0.6696911600744847]
# [0.074465444909923781, 0.068202699524267899, 0.055881979296812441, 0.05655406665393263, 0.05417212055164343]

# %%
# %run E7_6_12_Readfile.py

# %%
# N =12
# walk_12_list = [walk_120, walk_121, walk_122, walk_123, walk_124, walk_125, walk_126, walk_127, walk_128, walk_129, \
#                walk_1210, walk_1211]
walk_12_list = [walk_120, walk_122, walk_124, walk_126, walk_128,  \
               walk_1210, walk_1211]

for i in walk_12_list:
    step_length = []
    optimal_fitness = []
    for j in i:
        for s in j:
            step_length.append(len(s))
            optimal_fitness.append(s[-1][-1])
            
    aver_step_length = sum(step_length)/len(step_length)
    std_step_length = np.std(step_length, ddof = 1)
    aver_fitness = sum(optimal_fitness)/len(optimal_fitness)
    std_fitness = np.std(optimal_fitness, ddof = 1)
    
    aver_step.append(aver_step_length)
    std_step.append(std_step_length)
    aver_optimal_fitness.append(aver_fitness)
    std_optimal_fitness.append(std_fitness)
    
print(aver_step)
print(std_step)
print(aver_optimal_fitness)
print(std_optimal_fitness)
# Out:
# [2.969, 2.713, 2.5, 4.96, 4.755, 3.935, 3.33, 3.115, 7.011, 6.55, 5.603, 4.917, 4.122, 3.734, 3.596]
# [0.95128541665682231, 1.2239808532526679, 1.1972608042667368, 1.3994135765949816, 2.0560160996943098, 1.7854867579914906, 1.488393535095915, 1.4034759508964678, 1.7595382846005299, 2.3641254385267061, 2.2597560703530588, 2.1191039619616592, 1.8608005208991583, 1.6864424354504628, 1.5495758081440174]
# [0.675576553532616, 0.6947598311887023, 0.6875025865055163, 0.6726109903224868, 0.7073854637592196, 0.6979248732516914, 0.6775554168792669, 0.6696911600744847, 0.6678060268800665, 0.7027211642276384, 0.7017154501649017, 0.6917855233633149, 0.6739284338534746, 0.6597004922567739, 0.6538461693256354]
# ...

# %%
# %run E7_6_16_Readfile.py

# %%
# walk_16_list = [walk_160, walk_161, walk_162, walk_163, walk_164, walk_165, walk_166, walk_167, walk_168, walk_169, \
#                walk_1610, walk_1611, walk_1612, walk_1613, walk_1614, walk_1615]

walk_16_list = [walk_160, walk_162, walk_164, walk_166, walk_168,  \
               walk_1610, walk_1612, walk_1614, walk_1615]

for i in walk_16_list:
    step_length = []
    optimal_fitness = []
    for j in i:
        for s in j:
            step_length.append(len(s))
            optimal_fitness.append(s[-1][-1])
            
    aver_step_length = sum(step_length)/len(step_length)
    std_step_length = np.std(step_length, ddof = 1)
    aver_fitness = sum(optimal_fitness)/len(optimal_fitness)
    std_fitness = np.std(optimal_fitness, ddof = 1)
    
    aver_step.append(aver_step_length)
    std_step.append(std_step_length)
    aver_optimal_fitness.append(aver_fitness)
    std_optimal_fitness.append(std_fitness)
    
    
print(aver_step)
print(std_step)
print(aver_optimal_fitness)
print(std_optimal_fitness)

print(aver_step[-9])
print(std_step[-9])
print(aver_optimal_fitness[-9])
print(std_optimal_fitness[-9])
# Out:
# [2.969, 2.713, 2.5, 4.96, 4.755, 3.935, 3.33, 3.115, 7.011, 6.55, 5.603, 4.917, 4.122, 3.734, 3.596, 9.094, 8.152, 7.058, 6.18, 5.475, 4.996, 4.388, 4.043, 3.953, 9.094, 8.152, 7.058, 6.18, 5.475, 4.996, 4.388, 4.043, 3.953, 9.094, 8.152, 7.058, 6.18, 5.475, 4.996, 4.388, 4.043, 3.953, 9.094, 8.152, 7.058, 6.18, 5.475, 4.996, 4.388, 4.043, 3.953, 9.094, 8.152, 7.058, 6.18, 5.475, 4.996, 4.388, 4.043, 3.953]
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

plt.figure(figsize=(10,8))
m1 = np.array(range(1, len(aver_step)+1))
n1 = np.array(aver_step)
e1 = np.array(std_step)


# x_ticks = ['4_0', '4_1',  '4_2', '4_3', '8_0', '8_1', '8_2', '8_3', '8_4', '8_5', '8_6', '8_7', '12_1', '12_2', '12_3', \
#            '12_4', '12_5', '12_6', '12_7', '12_8', '12_9', '12_10', '12_11', '16_0', '16_1', '16_2', '16_3', '16_4', '16_5', \
#            '16_6', '16_7', '16_8', '16_9', '16_10', '16_11', '16_12', '16_13', '16_14', '16_15']

# x_ticks = ['4_0',  '4_2', '4_3', '8_0',  '8_2', '8_4', '8_6', '8_7', '12_0', '12_2', \
#            '12_4',  '12_6',  '12_8', '12_10', '12_11', '16_0', '16_2',  '16_4', \
#            '16_6',  '16_8',  '16_10',  '16_12', '16_14', '16_15']

plt.errorbar(m1, n1, e1, linestyle='None', marker='^')
plt.xlim(0, len(aver_step)+2)
plt.ylim(0, 12)

# plt.xticks(m1, x_ticks)
plt.rcParams.update({'font.size': 16})

plt.xlabel('Index')
plt.ylabel('Average steps to reach local optima (adjacent neneighbors)')
plt.show()
# Out:
# C:\Users\zhpc\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
print('AVER STEP', aver_step)
print('STD STEP', std_step)
print('AVER FITNESS', aver_optimal_fitness)
print('STD FITNESS', std_optimal_fitness)
# Out:
# AVER STEP [2.949, 2.924, 2.694, 2.472, 5.041, 4.822, 4.679, 4.337, 4.012, 3.675, 3.447, 3.141]
# STD STEP [1.0126324231548309, 1.2164307229364539, 1.1999182488002271, 1.1919046256461281, 1.4146802890831272, 1.7825525219452842, 1.8064391000590698, 1.8657202126556682, 1.7660619963565762, 1.7281091867591474, 1.5930250245142819, 1.4557603642901666]
# AVER FITNESS [0.6568519837798384, 0.6969552948078087, 0.7020548397626049, 0.6940044956261684, 0.670401417873088, 0.6880846735556562, 0.6992882154059904, 0.7038951158247617, 0.695799234107779, 0.6940888485318958, 0.6730169923774761, 0.6684686901638365]
# STD FITNESS [0.12012834800879105, 0.099834172931291681, 0.090888207637575311, 0.088268352165144864, 0.091265335771275199, 0.065647622632607941, 0.063709989876124029, 0.062532468218083698, 0.059780601584876948, 0.060527665002768155, 0.058758097910973341, 0.058113358300101801]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

plt.figure(figsize=(10,8))
m2 = np.array(range(1, len(aver_optimal_fitness)+1))
n2 = np.array(aver_optimal_fitness)
e2 = np.array(std_optimal_fitness)

plt.errorbar(m2, n2, e2, linestyle='None', marker='^')
plt.xlim(0, len(aver_optimal_fitness)+2)
plt.ylim(0, 1)

plt.rcParams.update({'font.size': 16})

plt.xlabel('Index')
plt.ylabel('Mean optimal fitness achieved (adjacent neighbors)')
plt.show()
# Out:
# C:\Users\zhpc\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
