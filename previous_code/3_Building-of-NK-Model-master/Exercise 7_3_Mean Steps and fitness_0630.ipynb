# %%
aver_step = []
std_step = []
aver_optimal_fitness = []
std_optimal_fitness = []

# %%
# %run E7_630_Readfile.py

# %%
walk_8_list = [walk_823, walk_843, walk_873]

for i in walk_8_list:
    step_length = []
    optimal_fitness = []
    for j in i:
        for s in j:
            step_length.append(len(s))
            optimal_fitness.append(s[-1][-1])
            
    aver_step_length = sum(step_length)/len(step_length)
    std_step_length = np.std(step_length, ddof = 1)
    aver_fitness = sum(optimal_fitness)/len(optimal_fitness)
    std_fitness = np.std(optimal_fitness, ddof = 1)
    
    aver_step.append(aver_step_length)
    std_step.append(std_step_length)
    aver_optimal_fitness.append(aver_fitness)
    std_optimal_fitness.append(std_fitness)
    
print(aver_step)
print(std_step)
print(aver_optimal_fitness)
print(std_optimal_fitness)
# Out:
# [4.82, 4.125, 3.157]
# [1.9817990633582225, 1.7693234598301988, 1.5279678287469556]
# [0.7033104857367408, 0.6958394728935117, 0.6682370361825748]
# [0.072499208363149034, 0.063406575900521206, 0.057597184040012045]

# %%
# %run E7_630_16_Readfile.py

# %%
walk_16_list = [walk_1623, walk_1643, walk_1683, walk_16153]

for i in walk_16_list:
    step_length = []
    optimal_fitness = []
    for j in i:
        for s in j:
            step_length.append(len(s))
            optimal_fitness.append(s[-1][-1])
            
    aver_step_length = sum(step_length)/len(step_length)
    std_step_length = np.std(step_length, ddof = 1)
    aver_fitness = sum(optimal_fitness)/len(optimal_fitness)
    std_fitness = np.std(optimal_fitness, ddof = 1)
    
    aver_step.append(aver_step_length)
    std_step.append(std_step_length)
    aver_optimal_fitness.append(aver_fitness)
    std_optimal_fitness.append(std_fitness)
    
print(aver_step)
print(std_step)
print(aver_optimal_fitness)
print(std_optimal_fitness)
# Out:
# [4.82, 4.125, 3.157, 8.655, 7.621, 5.666, 3.824]
# [1.9817990633582225, 1.7693234598301988, 1.5279678287469556, 2.814942077361255, 2.8353832895039779, 2.2701536506583859, 1.689934874449273]
# [0.7033104857367408, 0.6958394728935117, 0.6682370361825748, 0.7062799702036576, 0.7093453241179173, 0.6853449763503329, 0.6405253908534493]
# [0.072499208363149034, 0.063406575900521206, 0.057597184040012045, 0.048313897574811922, 0.043169951138852081, 0.041308643236051004, 0.035966951406277474]

# %%
aver_step_2 = []
std_step_2 = []
aver_optimal_fitness_2 = []
std_optimal_fitness_2 = []

# %%
# %run E7_6302_Readfile.py

# %%
walk_82_list = [walk_804, walk_824, walk_844, walk_874]

for i in walk_82_list:
    step_length = []
    optimal_fitness = []
    for j in i:
        for s in j:
            step_length.append(len(s))
            optimal_fitness.append(s[-1][-1])
            
    aver_step_length = sum(step_length)/len(step_length)
    std_step_length = np.std(step_length, ddof = 1)
    aver_fitness = sum(optimal_fitness)/len(optimal_fitness)
    std_fitness = np.std(optimal_fitness, ddof = 1)
    
    aver_step_2.append(aver_step_length)
    std_step_2.append(std_step_length)
    aver_optimal_fitness_2.append(aver_fitness)
    std_optimal_fitness_2.append(std_fitness)
    
print(aver_step_2)
print(std_step_2)
print(aver_optimal_fitness_2)
print(std_optimal_fitness_2)
# Out:
# [5.029, 4.602, 3.894, 3.131]
# [1.4512977865570063, 1.8206896800143926, 1.7290904411723969, 1.4724153649724683]
# [0.6872291442685641, 0.7016759588002025, 0.7002821042208932, 0.6689469472596626]
# [0.079227224648587988, 0.066922175631977193, 0.059795903358582383, 0.056160450224563868]

# %%
# %run E7_6302_16_Readfile.py

# %%
walk_162_list = [walk_1604, walk_1624, walk_1644, walk_1684, walk_16154]

for i in walk_162_list:
    step_length = []
    optimal_fitness = []
    for j in i:
        for s in j:
            step_length.append(len(s))
            optimal_fitness.append(s[-1][-1])
            
    aver_step_length = sum(step_length)/len(step_length)
    std_step_length = np.std(step_length, ddof = 1)
    aver_fitness = sum(optimal_fitness)/len(optimal_fitness)
    std_fitness = np.std(optimal_fitness, ddof = 1)
    
    aver_step_2.append(aver_step_length)
    std_step_2.append(std_step_length)
    aver_optimal_fitness_2.append(aver_fitness)
    std_optimal_fitness_2.append(std_fitness)
    
print(aver_step_2[4:])
print(std_step_2[4:])
print(aver_optimal_fitness_2[4:])
print(std_optimal_fitness_2[4:])
# Out:
# [9.016, 8.265, 7.209, 5.426, 3.913]
# [2.0148954821041718, 2.6528876366730669, 2.5733132224703898, 2.1943881469191675, 1.7379446054035932]
# [0.6663190930291697, 0.7010846111888949, 0.7050907513567464, 0.6822153440535437, 0.6414450679756473]
# [0.056852451516424367, 0.045816470476059974, 0.04485382746781711, 0.041889636251950656, 0.035762986058643101]
