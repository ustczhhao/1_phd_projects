# %%
# %run E7_9_Readfile.py

# %%
# N=20 and K =5

n =len(w_effect_205[0])

total_diff_list = []

for i in w_effect_205:
    diff_list = []
    for j in range(1, n):
        diff_list.append(i[j]-i[j-1])
        
    total_diff_list.append(diff_list)
    
# print('1', total_diff_list)

total_each_site_205 = []

for i in range(n-1):
    one_site = []
    for j in total_diff_list:
        one_site.append(j[i])
        
    total_each_site_205.append(one_site)

print('2',total_each_site_205, len(total_each_site_205))


positive = []
negative = []
zero =[]

b = np.array(total_each_site_205[0])
num_0_p = b[b>0].size
positive.append(num_0_p)

num_0_n = b[b<0].size
negative.append(num_0_n)

num_0_0 = b[b==0].size
zero.append(num_0_0)


c = np.array(total_each_site_205[1])
num_1_p = c[c>0].size
positive.append(num_1_p)

num_1_n = c[c<0].size
negative.append(num_1_n)

num_1_0 = c[c==0].size
zero.append(num_1_0)


d = np.array(total_each_site_205[2])
num_2_p = d[d>0].size
positive.append(num_2_p)

num_2_n = d[d<0].size
negative.append(num_2_n)

num_2_0 = d[d==0].size
zero.append(num_2_0)


e = np.array(total_each_site_205[3])
num_3_p = e[e>0].size
positive.append(num_3_p)

num_3_n = e[e<0].size
negative.append(num_3_n)

num_3_0 = e[e==0].size
zero.append(num_3_0)


print('p', positive)
print('n', negative)
print('z', zero)

num_list = []
for i in range(4):
    num_list.append([positive[i], negative[i], zero[i]])
    
print(num_list)
# Out:
# 2 [[0.048884260154810455, -0.024974152463146382, -0.00895454699275211, -0.02658656381532265, -0.013717373052798854, 0.09067069139998873, 1.1102230246251565e-16, -0.03890814430076739, 0.06982864667591188, 0.03113407252046374, 0.027957945789550465, -0.043412668422005196, 0.058538238383868735, 0.0, -0.0013469899096085758, 0.05122736982229603, -2.220446049250313e-16, 0.0, 5.551115123125783e-17, -0.02519658373446726, 0.006552040334556641, 0.0008914070745414393, 0.005886718003090929, -1.1102230246251565e-16, -0.10311956254787324, 1.1102230246251565e-16, 0.045581429598685164, 0.0, -0.02823230588975645, -0.019861159064847256, 0.02929184633275661, -0.008745515271049165, 0.016892465759258957, 0.0, 0.06327935792310502, -0.04480604642801933, -0.01749383288731743, -0.00503854635658707, 0.04335601326729849, -2.220446049250313e-16, 0.03579004024935167, 0.04346266022282297, 0.01666140900504176, -0.007813773345525132, 0.003364353124785835, -0.018420343659859117, -1.6653345369377348e-16, -0.0397374855
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,8))
m = np.array(range(1, len(num_list)+1))
n = np.array(num_list)


plt.plot(m, n)
plt.xlim(0, 5)
plt.ylim(0, 60)

plt.rcParams.update({'font.size': 20})

plt.title('N =20 and K =5')
plt.xlabel('Index')
plt.ylabel('Number')
plt.legend(['P', 'N', "0"])

plt.show()

# %%
# N=20 and K =10

n =len(w_effect_2010[0])

total_diff_list = []

for i in w_effect_2010:
    diff_list = []
    for j in range(1, n):
        diff_list.append(i[j]-i[j-1])
        
    total_diff_list.append(diff_list)
    
# print('1', total_diff_list)

total_each_site_2010 = []

for i in range(n-1):
    one_site = []
    for j in total_diff_list:
        one_site.append(j[i])
        
    total_each_site_2010.append(one_site)

# print('2',total_each_site_205, len(total_each_site_205))


positive = []
negative = []
zero =[]

b = np.array(total_each_site_2010[0])
num_0_p = b[b>0].size
positive.append(num_0_p)

num_0_n = b[b<0].size
negative.append(num_0_n)

num_0_0 = b[b==0].size
zero.append(num_0_0)


c = np.array(total_each_site_2010[1])
num_1_p = c[c>0].size
positive.append(num_1_p)

num_1_n = c[c<0].size
negative.append(num_1_n)

num_1_0 = c[c==0].size
zero.append(num_1_0)


d = np.array(total_each_site_2010[2])
num_2_p = d[d>0].size
positive.append(num_2_p)

num_2_n = d[d<0].size
negative.append(num_2_n)

num_2_0 = d[d==0].size
zero.append(num_2_0)


e = np.array(total_each_site_2010[3])
num_3_p = e[e>0].size
positive.append(num_3_p)

num_3_n = e[e<0].size
negative.append(num_3_n)

num_3_0 = e[e==0].size
zero.append(num_3_0)


print('p', positive)
print('n', negative)
print('z', zero)

num_list = []
for i in range(4):
    num_list.append([positive[i], negative[i], zero[i]])
    
print(num_list)
# Out:
# p [65, 61, 60, 50]
# n [35, 39, 40, 50]
# z [0, 0, 0, 0]
# [[65, 35, 0], [61, 39, 0], [60, 40, 0], [50, 50, 0]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,8))
m = np.array(range(1, len(num_list)+1))
n = np.array(num_list)


plt.plot(m, n)
plt.xlim(0, 5)
plt.ylim(0, 80)

plt.rcParams.update({'font.size': 20})

plt.title('N =20 and K =10')
plt.xlabel('Index')
plt.ylabel('Number')
plt.legend(['P', 'N', "0"])

plt.show()

# %%
# N=20 and K =115

n =len(w_effect_2015[0])

total_diff_list = []

for i in w_effect_2015:
    diff_list = []
    for j in range(1, n):
        diff_list.append(i[j]-i[j-1])
        
    total_diff_list.append(diff_list)
    
# print('1', total_diff_list)

total_each_site_2015 = []

for i in range(n-1):
    one_site = []
    for j in total_diff_list:
        one_site.append(j[i])
        
    total_each_site_2015.append(one_site)

# print('2',total_each_site_205, len(total_each_site_205))


positive = []
negative = []
zero =[]

b = np.array(total_each_site_2015[0])
num_0_p = b[b>0].size
positive.append(num_0_p)

num_0_n = b[b<0].size
negative.append(num_0_n)

num_0_0 = b[b==0].size
zero.append(num_0_0)


c = np.array(total_each_site_2015[1])
num_1_p = c[c>0].size
positive.append(num_1_p)

num_1_n = c[c<0].size
negative.append(num_1_n)

num_1_0 = c[c==0].size
zero.append(num_1_0)


d = np.array(total_each_site_2015[2])
num_2_p = d[d>0].size
positive.append(num_2_p)

num_2_n = d[d<0].size
negative.append(num_2_n)

num_2_0 = d[d==0].size
zero.append(num_2_0)


e = np.array(total_each_site_2015[3])
num_3_p = e[e>0].size
positive.append(num_3_p)

num_3_n = e[e<0].size
negative.append(num_3_n)

num_3_0 = e[e==0].size
zero.append(num_3_0)


print('p', positive)
print('n', negative)
print('z', zero)

num_list = []
for i in range(4):
    num_list.append([positive[i], negative[i], zero[i]])
    
print(num_list)
# Out:
# p [69, 62, 55, 72]
# n [31, 38, 45, 28]
# z [0, 0, 0, 0]
# [[69, 31, 0], [62, 38, 0], [55, 45, 0], [72, 28, 0]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,8))
m = np.array(range(1, len(num_list)+1))
n = np.array(num_list)


plt.plot(m, n)
plt.xlim(0, 5)
plt.ylim(0, 80)

plt.rcParams.update({'font.size': 20})

plt.title('N =20 and K =15')
plt.xlabel('Index')
plt.ylabel('Number')
plt.legend(['P', 'N', "0"])

plt.show()

# %%
# N=20 and K =19

n =len(w_effect_2019[0])

total_diff_list = []

for i in w_effect_2019:
    diff_list = []
    for j in range(1, n):
        diff_list.append(i[j]-i[j-1])
        
    total_diff_list.append(diff_list)
    
# print('1', total_diff_list)

total_each_site_2019 = []

for i in range(n-1):
    one_site = []
    for j in total_diff_list:
        one_site.append(j[i])
        
    total_each_site_2019.append(one_site)

# print('2',total_each_site_205, len(total_each_site_205))


positive = []
negative = []
zero =[]

b = np.array(total_each_site_2019[0])
num_0_p = b[b>0].size
positive.append(num_0_p)

num_0_n = b[b<0].size
negative.append(num_0_n)

num_0_0 = b[b==0].size
zero.append(num_0_0)


c = np.array(total_each_site_2019[1])
num_1_p = c[c>0].size
positive.append(num_1_p)

num_1_n = c[c<0].size
negative.append(num_1_n)

num_1_0 = c[c==0].size
zero.append(num_1_0)


d = np.array(total_each_site_2019[2])
num_2_p = d[d>0].size
positive.append(num_2_p)

num_2_n = d[d<0].size
negative.append(num_2_n)

num_2_0 = d[d==0].size
zero.append(num_2_0)


e = np.array(total_each_site_2019[3])
num_3_p = e[e>0].size
positive.append(num_3_p)

num_3_n = e[e<0].size
negative.append(num_3_n)

num_3_0 = e[e==0].size
zero.append(num_3_0)


print('p', positive)
print('n', negative)
print('z', zero)

num_list = []
for i in range(4):
    num_list.append([positive[i], negative[i], zero[i]])
    
print(num_list)
# Out:
# p [68, 59, 59, 62]
# n [32, 41, 41, 38]
# z [0, 0, 0, 0]
# [[68, 32, 0], [59, 41, 0], [59, 41, 0], [62, 38, 0]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,8))
m = np.array(range(1, len(num_list)+1))
n = np.array(num_list)


plt.plot(m, n)
plt.xlim(0, 5)
plt.ylim(0, 80)

plt.rcParams.update({'font.size': 20})

plt.title('N =20 and K =19')
plt.xlabel('Index')
plt.ylabel('Number')
plt.legend(['P', 'N', "0"])

plt.show()

# %%
import networkx as nx

# %%
G=nx.Graph()

# %%
import networkx as nx
import matplotlib.pyplot as plt

def draw_graph(graph):

    # extract nodes from graph
    nodes = set([n1 for n1, n2 in graph] + [n2 for n1, n2 in graph])

    # create networkx graph
    G=nx.Graph()

    # add nodes
    for node in nodes:
        G.add_node(node)

    # add edges
    for edge in graph:
        G.add_edge(edge[0], edge[1])

    # draw graph
    pos = nx.shell_layout(G)
    nx.draw(G, pos)

    # show graph
    plt.show()

# draw example
graph = [(20, 21),(21, 22),(22, 23), (23, 24),(24, 25), (25, 20)]
draw_graph(graph)
# Out:
# C:\Users\zhpc\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
def draw_graph(graph, labels=None, graph_layout='shell',
               node_size=1600, node_color='blue', node_alpha=0.3,
               node_text_size=12,
               edge_color='blue', edge_alpha=0.3, edge_tickness=1,
               edge_text_pos=0.3,
               text_font='sans-serif'):

    # create networkx graph
    G=nx.Graph()

    # add edges
    for edge in graph:
        G.add_edge(edge[0], edge[1])

    # these are different layouts for the network you may try
    # shell seems to work best
    if graph_layout == 'spring':
        graph_pos=nx.spring_layout(G)
    elif graph_layout == 'spectral':
        graph_pos=nx.spectral_layout(G)
    elif graph_layout == 'random':
        graph_pos=nx.random_layout(G)
    else:
        graph_pos=nx.shell_layout(G)

    # draw graph
    nx.draw_networkx_nodes(G,graph_pos,node_size=node_size, 
                           alpha=node_alpha, node_color=node_color)
    nx.draw_networkx_edges(G,graph_pos,width=edge_tickness,
                           alpha=edge_alpha,edge_color=edge_color)
    nx.draw_networkx_labels(G, graph_pos,font_size=node_text_size,
                            font_family=text_font)

    if labels is None:
        labels = range(len(graph))

    edge_labels = dict(zip(graph, labels))
    nx.draw_networkx_edge_labels(G, graph_pos, edge_labels=edge_labels, 
                                 label_pos=edge_text_pos)

    # show graph
    plt.show()

graph = [(0, 1), (1, 5), (1, 7), (4, 5), (4, 8), (1, 6), (3, 7), (5, 9),
         (2, 4), (0, 4), (2, 5), (3, 6), (8, 9)]

# you may name your edge labels
labels = map(chr, range(65, 65+len(graph)))
#draw_graph(graph, labels)

# if edge labels is not specified, numeric labels (0, 1, 2...) will be used
draw_graph(graph)
# Out:
# C:\Users\zhpc\Anaconda3\lib\site-packages\matplotlib\collections.py:650: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors_original != str('face'):
# C:\Users\zhpc\Anaconda3\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
