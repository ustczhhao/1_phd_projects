# %%
# %run E7_10_Readfile_MU.py

# %%
# N=20 and K =5

n =len(w_effect_205_mu[0])
print(n)

total_diff_list = []

for i in w_effect_205_mu:
    diff_list = []
    for j in range(1, n):
        diff_list.append(i[j]-i[j-1])
        
    total_diff_list.append(diff_list)
    
# print('1', total_diff_list)

total_each_site_205 = []

for i in range(n-1):
    one_site = []
    for j in total_diff_list:
        one_site.append(j[i])
        
    total_each_site_205.append(one_site)

print('2',len(total_each_site_205))


positive = []
negative = []
zero =[]

b = np.array(total_each_site_205[0])
num_0_p = b[b>0].size
positive.append(num_0_p)

num_0_n = b[b<0].size
negative.append(num_0_n)

num_0_0 = b[b==0].size
zero.append(num_0_0)


c = np.array(total_each_site_205[1])
num_1_p = c[c>0].size
positive.append(num_1_p)

num_1_n = c[c<0].size
negative.append(num_1_n)

num_1_0 = c[c==0].size
zero.append(num_1_0)


d = np.array(total_each_site_205[2])
num_2_p = d[d>0].size
positive.append(num_2_p)

num_2_n = d[d<0].size
negative.append(num_2_n)

num_2_0 = d[d==0].size
zero.append(num_2_0)


e = np.array(total_each_site_205[3])
num_3_p = e[e>0].size
positive.append(num_3_p)

num_3_n = e[e<0].size
negative.append(num_3_n)

num_3_0 = e[e==0].size
zero.append(num_3_0)


print('p', positive)
print('n', negative)
print('z', zero)

num_list = []
for i in range(4):
    num_list.append([positive[i], negative[i], zero[i]])
    
print(num_list)
# Out:
# 5
# 2 4
# p [811, 711, 712, 670]
# n [189, 289, 288, 330]
# z [0, 0, 0, 0]
# [[811, 189, 0], [711, 289, 0], [712, 288, 0], [670, 330, 0]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,8))
m = np.array(range(1, len(num_list)+1))
n = np.array(num_list)


plt.plot(m, n, linestyle='None', marker='^')
plt.xlim(0, 5)
plt.ylim(0, 1000)

plt.rcParams.update({'font.size': 20})

plt.title('Additive_N =20 and K =5')
plt.xlabel('Index')
plt.ylabel('Number')
plt.legend(['P', 'N', "0"])

plt.show()

# %%
# N=20 and K =10

n =len(w_effect_2010[0])

total_diff_list = []

for i in w_effect_2010:
    diff_list = []
    for j in range(1, n):
        diff_list.append(i[j]-i[j-1])
        
    total_diff_list.append(diff_list)
    
# print('1', total_diff_list)

total_each_site_2010 = []

for i in range(n-1):
    one_site = []
    for j in total_diff_list:
        one_site.append(j[i])
        
    total_each_site_2010.append(one_site)

# print('2',total_each_site_205, len(total_each_site_205))


positive = []
negative = []
zero =[]

b = np.array(total_each_site_2010[0])
num_0_p = b[b>0].size
positive.append(num_0_p)

num_0_n = b[b<0].size
negative.append(num_0_n)

num_0_0 = b[b==0].size
zero.append(num_0_0)


c = np.array(total_each_site_2010[1])
num_1_p = c[c>0].size
positive.append(num_1_p)

num_1_n = c[c<0].size
negative.append(num_1_n)

num_1_0 = c[c==0].size
zero.append(num_1_0)


d = np.array(total_each_site_2010[2])
num_2_p = d[d>0].size
positive.append(num_2_p)

num_2_n = d[d<0].size
negative.append(num_2_n)

num_2_0 = d[d==0].size
zero.append(num_2_0)


e = np.array(total_each_site_2010[3])
num_3_p = e[e>0].size
positive.append(num_3_p)

num_3_n = e[e<0].size
negative.append(num_3_n)

num_3_0 = e[e==0].size
zero.append(num_3_0)


print('p', positive)
print('n', negative)
print('z', zero)

num_list = []
for i in range(4):
    num_list.append([positive[i], negative[i], zero[i]])
    
print(num_list)
# Out:
# p [628, 594, 573, 576]
# n [372, 406, 427, 424]
# z [0, 0, 0, 0]
# [[628, 372, 0], [594, 406, 0], [573, 427, 0], [576, 424, 0]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,8))
m = np.array(range(1, len(num_list)+1))
n = np.array(num_list)


plt.plot(m, n, linestyle='None', marker='^')
plt.xlim(0, 5)
plt.ylim(0, 800)

plt.rcParams.update({'font.size': 20})

plt.title('Additive_N =20 and K =10')
plt.xlabel('Index')
plt.ylabel('Number')
plt.legend(['P', 'N', "0"])

plt.show()

# %%
# N=20 and K =115

n =len(w_effect_2015[0])

total_diff_list = []

for i in w_effect_2015:
    diff_list = []
    for j in range(1, n):
        diff_list.append(i[j]-i[j-1])
        
    total_diff_list.append(diff_list)
    
# print('1', total_diff_list)

total_each_site_2015 = []

for i in range(n-1):
    one_site = []
    for j in total_diff_list:
        one_site.append(j[i])
        
    total_each_site_2015.append(one_site)

# print('2',total_each_site_205, len(total_each_site_205))


positive = []
negative = []
zero =[]

b = np.array(total_each_site_2015[0])
num_0_p = b[b>0].size
positive.append(num_0_p)

num_0_n = b[b<0].size
negative.append(num_0_n)

num_0_0 = b[b==0].size
zero.append(num_0_0)


c = np.array(total_each_site_2015[1])
num_1_p = c[c>0].size
positive.append(num_1_p)

num_1_n = c[c<0].size
negative.append(num_1_n)

num_1_0 = c[c==0].size
zero.append(num_1_0)


d = np.array(total_each_site_2015[2])
num_2_p = d[d>0].size
positive.append(num_2_p)

num_2_n = d[d<0].size
negative.append(num_2_n)

num_2_0 = d[d==0].size
zero.append(num_2_0)


e = np.array(total_each_site_2015[3])
num_3_p = e[e>0].size
positive.append(num_3_p)

num_3_n = e[e<0].size
negative.append(num_3_n)

num_3_0 = e[e==0].size
zero.append(num_3_0)


print('p', positive)
print('n', negative)
print('z', zero)

num_list = []
for i in range(4):
    num_list.append([positive[i], negative[i], zero[i]])
    
print(num_list)
# Out:
# p [686, 553, 606, 584]
# n [314, 447, 394, 416]
# z [0, 0, 0, 0]
# [[686, 314, 0], [553, 447, 0], [606, 394, 0], [584, 416, 0]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,8))
m = np.array(range(1, len(num_list)+1))
n = np.array(num_list)


plt.plot(m, n, linestyle='None', marker='^')
plt.xlim(0, 5)
plt.ylim(0, 800)

plt.rcParams.update({'font.size': 20})

plt.title('Additive_N =20 and K =15')
plt.xlabel('Index')
plt.ylabel('Number')
plt.legend(['P', 'N', "0"])

plt.show()

# %%
# N=20 and K =19

n =len(w_effect_2019[0])

total_diff_list = []

for i in w_effect_2019:
    diff_list = []
    for j in range(1, n):
        diff_list.append(i[j]-i[j-1])
        
    total_diff_list.append(diff_list)
    
# print('1', total_diff_list)

total_each_site_2019 = []

for i in range(n-1):
    one_site = []
    for j in total_diff_list:
        one_site.append(j[i])
        
    total_each_site_2019.append(one_site)

# print('2',total_each_site_205, len(total_each_site_205))


positive = []
negative = []
zero =[]

b = np.array(total_each_site_2019[0])
num_0_p = b[b>0].size
positive.append(num_0_p)

num_0_n = b[b<0].size
negative.append(num_0_n)

num_0_0 = b[b==0].size
zero.append(num_0_0)


c = np.array(total_each_site_2019[1])
num_1_p = c[c>0].size
positive.append(num_1_p)

num_1_n = c[c<0].size
negative.append(num_1_n)

num_1_0 = c[c==0].size
zero.append(num_1_0)


d = np.array(total_each_site_2019[2])
num_2_p = d[d>0].size
positive.append(num_2_p)

num_2_n = d[d<0].size
negative.append(num_2_n)

num_2_0 = d[d==0].size
zero.append(num_2_0)


e = np.array(total_each_site_2019[3])
num_3_p = e[e>0].size
positive.append(num_3_p)

num_3_n = e[e<0].size
negative.append(num_3_n)

num_3_0 = e[e==0].size
zero.append(num_3_0)


print('p', positive)
print('n', negative)
print('z', zero)

num_list = []
for i in range(4):
    num_list.append([positive[i], negative[i], zero[i]])
    
print(num_list)
# Out:
# p [728, 596, 570, 596]
# n [272, 404, 430, 404]
# z [0, 0, 0, 0]
# [[728, 272, 0], [596, 404, 0], [570, 430, 0], [596, 404, 0]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(10,8))
m = np.array(range(1, len(num_list)+1))
n = np.array(num_list)


plt.plot(m, n)
plt.xlim(0, 5)
plt.ylim(0, 800)

plt.rcParams.update({'font.size': 20})

plt.title('N =20 and K =19')
plt.xlabel('Index')
plt.ylabel('Number')
plt.legend(['P', 'N', "0"])

plt.show()
