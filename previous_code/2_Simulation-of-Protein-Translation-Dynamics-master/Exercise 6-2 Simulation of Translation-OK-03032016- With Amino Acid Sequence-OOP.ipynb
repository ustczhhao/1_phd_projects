# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class ChemicalSpecies(object):
    
    def __init__(self, name, count):
        self.name=name
        self.count=count
        

class Reaction(object):
    
    def __init__(self, reactant_list, product_list, reconstant):
        self.reactant_list=reactant_list
        self.product_list=product_list
        self.reaction_constant=reconstant
        
    def get_propensity(self):
        k=1
        for i in self.reactant_list:
            k=k*i.count
            
        propensity=self.reaction_constant*k
        return propensity
    
    def execuate(self):
        for i in self.reactant_list:
            i-=1
        
        for j in self.product_list:
            j+=1
        return self.reactant_list, self.product_list
    

class Protein(object):
    
    def __init__(self,sequence):
        self.sequence=sequence
        
    def translate(self):
        codon_dict={'UUU':'F', 'UUC':'F', 'UUA':'L', 'UUG':'L',     
                 'UCU':'S', 'UCC':'S', 'UCA':'S', 'UCG':'S',     
                 'UAU':'Y', 'UAC':'Y', 'UAA':'STOP', 'UAG':'STOP',     
                 'UGU':'C', 'UGC':'C', 'UGA':'STOP', 'UGG':'W',     
                 'CUU':'L', 'CUC':'L', 'CUA':'L', 'CUG':'L',     
                 'CCU':'P', 'CCC':'P', 'CCA':'P', 'CCG':'P',     
                 'CAU':'H', 'CAC':'H', 'CAA':'Q', 'CAG':'Q',     
                 'CGU':'R', 'CGC':'R', 'CGA':'R', 'CGG':'R',     
                 'AUU':'I', 'AUC':'I', 'AUA':'I', 'AUG':'M',     
                 'ACU':'T', 'ACC':'T', 'ACA':'T', 'ACG':'T',     
                 'AAU':'N', 'AAC':'N', 'AAA':'K', 'AAG':'K',     
                 'AGU':'S', 'AGC':'S', 'AGA':'R', 'AGG':'R',     
                 'GUU':'V', 'GUC':'V', 'GUA':'V', 'GUG':'V',     
                 'GCU':'A', 'GCC':'A', 'GCA':'A', 'GCG':'A',     
                 'GAU':'D', 'GAC':'D', 'GAA':'E', 'GAG':'E',    
                 'GGU':'G', 'GGC':'G', 'GGA':'G', 'GGG':'G'}
    
        aa_list=[]
    
        start_point=sequence.find('AUG')
        trimmed_sequence=sequence[start_point:]
    
        codons_list = [trimmed_sequence[i:i+3] for i in range(0, len(trimmed_sequence), 3)]
    
        stop_list=['UAA', 'UAG','UGA']
    
        n=0
        for i in codons_list:
            if len(i)==1 or len(i)==2:
                pass
            elif i not in stop_list:
                n+=1
                aa_list.append(codon_dict[i])
            else:
                break
            
        return n,aa_list
    
    
class System(object):
    
    def __init__(self, reaction_list, sequence):
        self.reaction_list=reaction_list
        self.sequence=sequence
        
    def run_directmethod(self,steps=None):
        chemicalpre_list=[]
        
        for i in self.reaction_list:
            for j in i.reactant_list
                chemicalpre_list.append(j)
                
        rib=chemicalpre_list[0]
        rna_rbs=chemicalpre_list[1]
        
        precomplex_list=chemicalpre_list[2:]
        
        complex_set=set(precomplex_list)
        
        complex_list=list(complex_set)
        
        complex_list.sort(key=lambda x:x.name)
        
        prop_list=[]    
        for i in self.reaction_list:
            prop_list.append(i.get_propensity())
          
        
        if steps=None:
            new_prop = prop_list
        else:
            new_prop=[]
            for i, p in enumerate(prop_list):
                if i not in steps:
                    new_prop.append(p)
                else:
                    new_prop.append(0)
            
            
        sumprop=sum(new_prop)
        prob_list=[]
        
        if sumprop>0
