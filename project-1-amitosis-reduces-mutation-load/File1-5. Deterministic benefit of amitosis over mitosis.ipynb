0.10251, 0.102526, 0.102541, 0.102557, 0.102572, 0.102587, 0.102601, 
0.102616, 0.10263, 0.102644, 0.102657, 0.102671, 0.102684, 0.102697, 
0.10271, 0.102723, 0.102735, 0.102747, 0.10276, 0.102771, 0.102783, 
0.102795, 0.102806, 0.102817, 0.102829, 0.102839, 0.10285, 0.102861, 
0.102871, 0.102882, 0.102892, 0.102902, 0.102912, 0.102922]
e = [0.0289599, 0.0397958, 0.0465105, 0.0513133, 0.0550042, 0.0579702, 
0.0604285, 0.0625134, 0.0643131, 0.0658889, 0.0672847, 0.0685332, 
0.0696592, 0.0706818, 0.0716163, 0.072475, 0.0732676, 0.0740025, 
0.0746865, 0.0753253, 0.0759237, 0.0764859, 0.0770154, 0.0775154, 
0.0779887, 0.0784374, 0.0788636, 0.0792693, 0.0796561, 0.0800252, 
0.0803783, 0.0807163, 0.0810403, 0.0813513, 0.0816501, 0.0819376, 
0.0822144, 0.0824811, 0.0827385, 0.082987, 0.0832271, 0.0834593, 
0.083684, 0.0839017, 0.0841127, 0.0843173, 0.0845159, 0.0847087, 
0.084896, 0.0850782, 0.0852553, 0.0854277, 0.0855955, 0.085759, 
0.0859184, 0.0860737, 0.0862253, 0.0863732, 0.0865176, 0.0866586, 
0.0867963, 0.086931, 0.0870626, 0.0871913, 0.0873173, 0.0874406, 
0.0875612, 0.0876794, 0.0877951, 0.0879085, 0.0880197, 0.0881287, 
0.0882356, 0.0883404, 0.0884433, 0.0885442, 0.0886433, 0.0887406, 
0.0888362, 0.0889301, 0.0890223, 0.0891129, 0.0892019, 0.0892895, 
0.0893756, 0.0894603, 0.0895436, 0.0896255, 0.0897062, 0.0897855, 
0.0898636, 0.0899406, 0.0900163, 0.0900909, 0.0901644, 0.0902367, 
0.0903081, 0.0903783, 0.0904476, 0.0905159, 0.0905832, 0.0906496, 
0.090715, 0.0907796, 0.0908433, 0.0909061, 0.090968, 0.0910292, 
0.0910896, 0.0911491, 0.0912079, 0.091266, 0.0913233, 0.0913799, 
0.0914358, 0.091491, 0.0915455, 0.0915994, 0.0916526, 0.0917052, 
0.0917571, 0.0918085, 0.0918592, 0.0919094, 0.0919589, 0.092008, 
0.0920564]

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 25})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=10, width=5, direction='out', pad=25, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=10, width=5, direction='out', pad=25, colors='black')

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

fig = plt.figure(figsize=(10, 8), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)

ax.set_ylim(0, 25)
ax.set_xlim(1,7)

# ax.set_xscale('log',basex=2)
xmin = 2
xmax = 128
xstep = 2
rnd =1

x = np.arange(2, 129)
logx = np.log(x) / np.log(2)

a1 = np.array(a)*100
b1 = np.array(b)*100
c1 = np.array(c)*100
e1 = np.array(e)*100


ax.plot(logx,a1,color=cols[0], label=r'$0.1$',  markersize =10, linewidth=3.0)
ax.plot(logx,b1,color=cols[1], label=r'$0.2$', markersize =10, linewidth=3.0)
ax.plot(logx,c1,color=cols[3],label='$\propto\ln(n)$',markersize =10, linestyle ='--', linewidth=3.0)

# ax.plot(x,y3,'grey',label='Deterministic',marker='o', markersize =10, linestyle ='--',linewidth=2.0)

# ax.set_title('Mitosis_0.5 Fitness')

ax.set_xlabel(r'Ploidy $(n)$', fontsize =25)
ax.set_ylabel('Benefit of amitosis (%)', fontsize =25)

ax.set_xticks([1, 3, 5, 7]) # choose which x locations to have ticks
ax.set_xticklabels([2,8, 32,128]) # set the labels to display at those ticks


leg1 = ax.legend(fontsize = 20, bbox_to_anchor=(.99, .3), frameon=False)
leg1.set_title(r'$U_d$', prop = {'size': 22})
# frame.set_edgecolor('white')

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

fig = plt.figure(figsize=(10, 8), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)

ax.set_ylim(0, 25)
ax.set_xlim(1,7)

# ax.set_xscale('log',basex=2)
xmin = 2
xmax = 128
xstep = 2
rnd =1

x = np.arange(2, 129)
logx = np.log(x) / np.log(2)

a1 = np.array(a)*100
b1 = np.array(b)*100
c1 = np.array(c)*100
e1 = np.array(e)*100


ax.plot(logx,a1,color=cols[0], label=r'$0.1$',  markersize =10, linewidth=3.0)
ax.plot(logx,b1,color=cols[1], label=r'$0.2$', markersize =10, linewidth=3.0)
ax.plot(logx,c1,color=cols[3],label='$\propto\ln(n)$',markersize =10, linestyle ='--', linewidth=3.0)

# ax.plot(x,y3,'grey',label='Deterministic',marker='o', markersize =10, linestyle ='--',linewidth=2.0)

# ax.set_title('Mitosis_0.5 Fitness')

ax.set_xlabel(r'Ploidy $(n)$', fontsize =20)
ax.set_ylabel('Deterministic Benefit of amitosis (%)', fontsize =20)

ax.set_xticks([1, 3, 5, 7]) # choose which x locations to have ticks
ax.set_xticklabels([2,8, 32,128]) # set the labels to display at those ticks


leg1 = ax.legend(fontsize = 20, bbox_to_anchor=(.99, .3), frameon=False)
leg1.set_title(r'$U_d$', prop = {'size': 22})
# frame.set_edgecolor('white')

# %%
import seaborn as sns
cols = sns.color_palette()

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

fig = plt.figure(figsize=(10, 8), dpi = 300)
ax = fig.add_subplot(111)
publication_figure(ax)

ax.set_ylim(0, 25)
ax.set_xlim(1,7)

# ax.set_xscale('log',basex=2)
xmin = 2
xmax = 128
xstep = 2
rnd =1

x = np.arange(2, 129)
logx = np.log(x) / np.log(2)

a2 = np.array(a)*100
b2 = np.array(b)*100
c2 = np.array(c)*100
d2 = np.array(d)*100
e2 = np.array(e)*100


ax.plot(logx,d2,color=cols[4], label=r'$-0.01$',  markersize =10, linewidth=3.0)
ax.plot(logx,a2,color=cols[0], label=r'$-0.1$', markersize =10, linewidth=3.0)
ax.plot(logx,e2,color=cols[2],label=r'$-0.5$',markersize =10, linewidth=3.0)

# ax.plot(x,y3,'grey',label='Deterministic',marker='o', markersize =10, linestyle ='--',linewidth=2.0)

# ax.set_title('Mitosis_0.5 Fitness')

ax.set_xlabel(r'Ploidy $(n)$', fontsize =25)
ax.set_ylabel(r'Benefit of amitosis (%)', fontsize =25)

ax.set_xticks([1, 3, 5, 7]) # choose which x locations to have ticks
ax.set_xticklabels([2,8, 32,128]) # set the labels to display at those ticks


leg1 = ax.legend(fontsize = 20, bbox_to_anchor=(.99, 1), frameon=False)
leg1.set_title(r'$s_d$', prop = {'size': 22})
# frame.set_edgecolor('white')
