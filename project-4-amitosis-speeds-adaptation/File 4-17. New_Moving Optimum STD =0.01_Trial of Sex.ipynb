# %%
'''

Under no pleiotropy and moving optimum,  We compared the performance of amitosis, mitosis and sex (including RM, RME100, SF and 
SFE100) in adaptation with different ploidies. 

Setting: no pleyotropy, # of loci and dimension =10, genomic mutation rate =0.01, population size N = 500, STD =0.05.
Here the optimum move every generation along all the 10 dimension, with each movement sampled from a normal distribution with 
mean of 0 and STD of 0.01.

Here the code has been revised to include random.seed().

'''
# Out:
# '\n\nUnder no pleiotropy and fixed optimum,  We compared the performance of amitosis, mitosis and sex (including RM, RME100, SF and \nSFE100) in adaptation with different ploidies. \n\nSetting: no pleyotropy, # of loci and dimension =10, genomic mutation rate =0.01, population size N = 500, STD =0.05.\nHere the optimum move every generation along all the 10 dimension, with each movement sampled from a normal distribution with \nmean of 0 and STD of 0.01.\n\nHere the code has been revised to include random.seed().\n\n'

# %%
from __future__ import division
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import pickle
# %matplotlib inline

# %%
generation_list = []

for i in range(2002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 2002

# %%
def get_data1(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.mFit_Mean,dtype=float)))
        fit_std.extend(list(pd.Series(f.mFit_Std,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.varFit_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.varFit_Std,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %%
def get_data2(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.meanFit,dtype=float)))
        fit_std.extend(list(pd.Series(f.PopMeanFit_STD,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.PopVar_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.PopVar_STD,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %%
def read_file(data):
    with open(data, 'rb') as f:
        x = pickle.load(f)
        
    return x

# %% [markdown]
# ## N =500_Initial fitness =0.5_Dim = 10_Different Ploidy

# %% [markdown]
# ### Fitness dynamics comparison

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190102_Test of FGM_6_Trial of Moving Optimum\Data\5.1. MO STD = 0.01_Adaptation\Amito")

# %%
amito = ['Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P1_Amito_Fit_N1K_Fit05_SM005_2KG.csv', 'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P2_Amito_Fit_N1K_Fit05_SM005_2KG.csv',\
         'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P4_Amito_Fit_N1K_Fit05_SM005_2KG.csv', 'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P8_Amito_Fit_N1K_Fit05_SM005_2KG.csv', \
         'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P16_Amito_Fit_N1K_Fit05_SM005_2KG.csv', 'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P32_Amito_Fit_N1K_Fit05_SM005_2KG.csv', \
         'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P45_Amito_Fit_N1K_Fit05_SM005_2KG.csv', 'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P64_Amito_Fit_N1K_Fit05_SM005_2KG.csv', \
         'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P128_Amito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m = get_data1(amito)

amito_fit_mean =m[0]
amito_fit_std = m[1]
amito_var_mean =m[2]
amito_var_std = m[3]

# %%
amito_fit_mean_final = [amito_fit_mean[i][-1] for i in range(len(amito))]
amito_fit_std_final = [amito_fit_std[i][-1] for i in range(len(amito))]

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190102_Test of FGM_6_Trial of Moving Optimum\Data\5.1. MO STD = 0.01_Adaptation\Mito")

# %%
mito = ['Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P1_Mito_Fit_N1K_Fit05_SM005_2KG.csv', 'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P2_Mito_Fit_N1K_Fit05_SM005_2KG.csv',\
         'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P4_Mito_Fit_N1K_Fit05_SM005_2KG.csv', 'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P8_Mito_Fit_N1K_Fit05_SM005_2KG.csv', \
         'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P16_Mito_Fit_N1K_Fit05_SM005_2KG.csv', 'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P32_Mito_Fit_N1K_Fit05_SM005_2KG.csv', \
         'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P45_Mito_Fit_N1K_Fit05_SM005_2KG.csv', 'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P64_Mito_Fit_N1K_Fit05_SM005_2KG.csv', \
         'Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P128_Mito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
s = get_data1(mito)

mito_fit_mean =s[0]
mito_fit_std = s[1]
mito_var_mean =s[2]
mito_var_std = s[3]

# %%
mito_fit_mean_final = [mito_fit_mean[i][-1] for i in range(len(mito))]
mito_fit_std_final = [mito_fit_std[i][-1] for i in range(len(mito))]

# %% [markdown]
# #### RM

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190331_Test of FGM_7_Trial of Incorporating Sex\Data\2. NP_MO All Dim STD = 0.01_D = L =10\RM")

# %%
rm = ['DetermMOSM01_NP_GMU001_Dim10_P1_RM_Fit_N500_Fit05_SM005_Cor.csv', 'DetermMOSM01_NP_GMU001_Dim10_P2_RM_Fit_N500_Fit05_SM005_Cor.csv', \
      'DetermMOSM01_NP_GMU001_Dim10_P4_RM_Fit_N500_Fit05_SM005_Cor.csv', 'DetermMOSM01_NP_GMU001_Dim10_P8_RM_Fit_N500_Fit05_SM005_Cor.csv', \
      'DetermMOSM01_NP_GMU001_Dim10_P16_RM_Fit_N500_Fit05_SM005_Cor.csv', 'DetermMOSM01_NP_GMU001_Dim10_P32_RM_Fit_N500_Fit05_SM005_Cor.csv', \
      'DetermMOSM01_NP_GMU001_Dim10_P45_RM_Fit_N500_Fit05_SM005_Cor.csv', 'DetermMOSM01_NP_GMU001_Dim10_P64_RM_Fit_N500_Fit05_SM005_Cor.csv', \
      'DetermMOSM01_NP_GMU001_Dim10_P128_RM_Fit_N500_Fit05_SM005_Cor.csv']

# %%
n = get_data1(rm)

rm_fit_mean =n[0]
rm_fit_std = n[1]
rm_var_mean =n[2]
rm_var_std = n[3]

# %%
rm_fit_mean_final = [rm_fit_mean[i][-1] for i in range(len(rm))]
rm_fit_std_final = [rm_fit_std[i][-1] for i in range(len(rm))]

# %% [markdown]
# #### RME100

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190331_Test of FGM_7_Trial of Incorporating Sex\Data\2. NP_MO All Dim STD = 0.01_D = L =10\RME100")

# %%
rme = ['DetermMOSM01_NP_GMU001_Dim10_P1_RME100_Fit_N500_Fit05_SM005_Cor.csv', 'DetermMOSM01_NP_GMU001_Dim10_P2_RME100_Fit_N500_Fit05_SM005_Cor.csv', \
      'DetermMOSM01_NP_GMU001_Dim10_P4_RME100_Fit_N500_Fit05_SM005_Cor.csv', 'DetermMOSM01_NP_GMU001_Dim10_P8_RME100_Fit_N500_Fit05_SM005_Cor.csv', \
      'DetermMOSM01_NP_GMU001_Dim10_P16_RME100_Fit_N500_Fit05_SM005_Cor.csv', 'DetermMOSM01_NP_GMU001_Dim10_P32_RME100_Fit_N500_Fit05_SM005_Cor.csv', \
      'DetermMOSM01_NP_GMU001_Dim10_P45_RME100_Fit_N500_Fit05_SM005_Cor.csv', 'DetermMOSM01_NP_GMU001_Dim10_P64_RME100_Fit_N500_Fit05_SM005_Cor.csv', \
      'DetermMOSM01_NP_GMU001_Dim10_P128_RME100_Fit_N500_Fit05_SM005_Cor.csv']

# %%
n2 = get_data1(rme)

rme_fit_mean =n2[0]
rme_fit_std = n2[1]
rme_var_mean =n2[2]
rme_var_std = n2[3]

# %%
rme_fit_mean_final = [rme_fit_mean[i][-1] for i in range(len(rme))]
rme_fit_std_final = [rme_fit_std[i][-1] for i in range(len(rme))]

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 36})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(6)
    ax.spines['bottom'].set_linewidth(6)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_ylim(0, 1)
ax.set_xlim(0.8,150)

ax.set_xscale('log',basex=2)

x = [1, 2, 4, 8, 16, 32, 45, 64, 128]

a = amito_fit_mean_final
error_a = 1.98* np.array(amito_fit_std_final)/((100)**0.5)


b = mito_fit_mean_final
error_b = 1.98* np.array(mito_fit_std_final)/((100)**0.5)

c = rm_fit_mean_final
error_c = 1.98* np.array(rm_fit_std_final)/((100)**0.5)

d = rme_fit_mean_final
error_d = 1.98* np.array(rme_fit_std_final)/((100)**0.5)


ax.set_xlabel('Ploidy', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36)


ax.errorbar(x, a, yerr = error_a, label = 'Amitosis', fmt='o', color = 'b', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,a, color = 'b',ls = '--', alpha = 0.8)

ax.errorbar(x, b, yerr = error_b, label = 'Mitosis', fmt='o', color = 'deepskyblue', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,b, color = 'deepskyblue',ls = '--', alpha = 0.8)

ax.errorbar(x, c, yerr = error_c, label = 'Obligate Sex', fmt='o', color = 'r', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,c, color = 'r',ls = '--', alpha = 0.8)

ax.errorbar(x, d, yerr = error_d, label = 'Facultative Sex', fmt='o', color = 'm', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,d, color = 'm',ls = '--', alpha = 0.8)




plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

# legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =25)
# frame = legend.get_frame()
# # frame.set_framecolor('black')
# frame.set_edgecolor('black')

# extraticks=[0.45, 0.95]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

# ax.set_ylim(0.4, 1)

ax.set_xticks([1,2,4,8, 16, 32, 45, 64, 128]) # choose which x locations to have ticks
ax.set_xticklabels([1,2,4,8, 16, 32, 45, 64, 128]) # set the labels to display at those ticks

plt.legend(loc='upper left', frameon=False, prop={'size':29})


plt.show()
