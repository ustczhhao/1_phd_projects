# %%
from __future__ import division
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import pickle
# %matplotlib inline

# %%
generation_list = []

for i in range(2002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 2002

# %%
def get_data1(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.mFit_Mean,dtype=float)))
        fit_std.extend(list(pd.Series(f.mFit_Std,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.varFit_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.varFit_Std,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %% [markdown]
# ### Optimum Moving All dimension_STD =0.01

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190102_Test of FGM_6_Trial of Moving Optimum\Data\5.1. MO STD = 0.01_Adaptation\Amito")

# %%
ad_amito = ['Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P45_Amito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m1 = get_data1(ad_amito)

ad_amito_fit_mean =m1[0]
ad_amito_fit_std = m1[1]

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190102_Test of FGM_6_Trial of Moving Optimum\Data\5.1. MO STD = 0.01_Adaptation\Mito")

# %%
ad_mito = ['Cor_Rv_MoveOpt_SM01_NoPley_GMU001_Dim10_P45_Mito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
s1 = get_data1(ad_mito)

ad_mito_fit_mean =s1[0]
ad_mito_fit_std = s1[1]

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 45})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(6)
    ax.spines['bottom'].set_linewidth(6)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list


g1 = ad_amito_fit_mean[0]
error_g1 = list(1.98* np.array(ad_amito_fit_std[0])/((100)**0.5))

g2 = ad_mito_fit_mean[0]
error_g2 = list(1.98* np.array(ad_mito_fit_std[0])/((100)**0.5))


# ax.set_title('FGM_No Pley_Moving Opt_MO Deterministic and STD =0.01_Corrected', fontsize =35)
ax.set_xlabel('Time (generations)', fontsize =45)
ax.set_ylabel('Population Mean Fitness', fontsize =45)


ax.plot(t,g1,'b', label = 'Amitosis',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.3, facecolor='b')

ax.plot(t,g2,'deepskyblue', label = 'Mitosis',   linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g2)- np.array(error_g2), np.array(g2)+ np.array(error_g2), alpha =0.3, facecolor='deepskyblue')




plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()

ax.set_ylim(0.3, 0.8)

plt.legend(loc='upper left', frameon=False, prop={'size':36})

# plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/1000), ',')))

# %% [markdown]
# ### Optimum Moving One dimension_STD =0.05

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190204_Test of FGM_6_Deterministic Moving Optimum_Other Move Strategies\Data\2.2. Move Along 1 Dimension_MO STD = 0.05\Amito")

# %%
# Name of the file has been mistaken from N500 to N1K
od_amito = ['Cor_MoveOpt_OneDim_SM05_NoPley_GMU001_Dim10_P45_Amito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m2 = get_data1(od_amito)

od_amito_fit_mean =m2[0]
od_amito_fit_std = m2[1]

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190204_Test of FGM_6_Deterministic Moving Optimum_Other Move Strategies\Data\2.2. Move Along 1 Dimension_MO STD = 0.05\Mito")

# %%
od_mito =['Cor_MoveOpt_OneDim_SM05_NoPley_GMU001_Dim10_P45_Mito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
s2 = get_data1(od_mito)

od_mito_fit_mean =s2[0]
od_mito_fit_std = s2[1]

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list


g1 = od_amito_fit_mean[0]
error_g1 = list(1.98* np.array(od_amito_fit_std[0])/((100)**0.5))

g2 = od_mito_fit_mean[0]
error_g2 = list(1.98* np.array(od_mito_fit_std[0])/((100)**0.5))


# ax.set_title('FGM_No Pley_Moving Opt_MO Deterministic and STD =0.01_Corrected', fontsize =35)
ax.set_xlabel('Time (generations)', fontsize =45)
ax.set_ylabel('Population Mean Fitness', fontsize =45, color = 'white')


ax.plot(t,g1,'b', label = 'Amitosis',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.3, facecolor='b')

ax.plot(t,g2,'deepskyblue', label = 'Mitosis',   linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g2)- np.array(error_g2), np.array(g2)+ np.array(error_g2), alpha =0.3, facecolor='deepskyblue')




plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()

ax.set_ylim(0.3, 0.8)

# plt.legend(loc='upper left', frameon=False, prop={'size':28})

# plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/1000), ',')))
# Out:
# (0.3, 0.8)

# %% [markdown]
# ### Optimum Moving Along the diagonal_Rate = 0.0003

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190204_Test of FGM_6_Deterministic Moving Optimum_Other Move Strategies\Data\1.2. Cor_Move Along A Straight Line_Rate = 0.0003\Amito")

# %%
# Name of the file has been mistaken from N500 to N1K

dl_amito = ['Cor_MO_R00003_NoPley_GMU001_Dim10_P45_Amito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m3 = get_data1(dl_amito)

dl_amito_fit_mean =m3[0]
dl_amito_fit_std = m3[1]

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190204_Test of FGM_6_Deterministic Moving Optimum_Other Move Strategies\Data\1.2. Cor_Move Along A Straight Line_Rate = 0.0003\Mito")

# %%
dl_mito = ['Cor_MO_R00003_NoPley_GMU001_Dim10_P45_Mito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
s3 = get_data1(dl_mito)

dl_mito_fit_mean =s3[0]
dl_mito_fit_std = s3[1]

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list


g1 = dl_amito_fit_mean[0]
error_g1 = list(1.98* np.array(dl_amito_fit_std[0])/((100)**0.5))

g2 = dl_mito_fit_mean[0]
error_g2 = list(1.98* np.array(dl_mito_fit_std[0])/((100)**0.5))


# ax.set_title('FGM_No Pley_Moving Opt_MO Deterministic and STD =0.01_Corrected', fontsize =35)
ax.set_xlabel('Time (generations)', fontsize =45)
ax.set_ylabel('Population Mean Fitness', fontsize =45, color = 'white')


ax.plot(t,g1,'b', label = 'Amitosis',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.3, facecolor='b')

ax.plot(t,g2,'deepskyblue', label = 'Mitosis',   linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g2)- np.array(error_g2), np.array(g2)+ np.array(error_g2), alpha =0.3, facecolor='deepskyblue')




plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()

ax.set_ylim(0.3, 0.8)

# plt.legend(loc='upper left', frameon=False, prop={'size':28})

# plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/1000), ',')))
# Out:
# (0.3, 0.8)
