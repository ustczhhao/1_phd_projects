# %%
from __future__ import division
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import pickle
# %matplotlib inline

# %%
generation_list = []

for i in range(2002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 2002

# %%
def get_data1(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.mFit_Mean,dtype=float)))
        fit_std.extend(list(pd.Series(f.mFit_Std,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.varFit_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.varFit_Std,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %% [markdown]
# ## Fixed optimum

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\1.3. No Pley_Diff Ploidy_GMU = 0.01\Amito")

# %%
fix_amito = ['Cor_NoPley_GMU001_Dim10_P45_Amito_Fit_N500_Fit05_SM005.csv']

# %%
m1 = get_data1(fix_amito)
fix_amito_fit_mean =m1[0]
fix_amito_fit_std = m1[1]

# %%
fix_amito_fit_mean_final = fix_amito_fit_mean[0][-1]
fix_amito_fit_std_final = fix_amito_fit_std[0][-1]

# %%
fix_amito_fit_mean_final
# Out:
# 0.75680972665219992

# %%
fix_amito_fit_std_final
# Out:
# 0.052562746976952957

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\1.3. No Pley_Diff Ploidy_GMU = 0.01\Mito")

# %%
fix_mito = ['Cor_NoPley_GMU001_Dim10_P45_Mito_Fit_N500_Fit05_SM005.csv']

# %%
m2 = get_data1(fix_mito)
fix_mito_fit_mean =m2[0]
fix_mito_fit_std = m2[1]

# %%
fix_mito_fit_mean_final = fix_mito_fit_mean[0][-1]
fix_mito_fit_std_final = fix_mito_fit_std[0][-1]

# %%
fix_mito_fit_mean_final
# Out:
# 0.8550025655372202

# %%
fix_mito_fit_std_final
# Out:
# 0.031799512540401448

# %% [markdown]
# ### Optimum Moving STD =0.002

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190102_Test of FGM_6_Trial of Moving Optimum\Data\5.1C. MO STD = 0.002_Adaptation\Amito")

# %%
m002_amito = ['Cor_Rv_MoveOpt_SM002_NoPley_GMU001_Dim10_P45_Amito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m002_m = get_data1(m002_amito)

m002_amito_fit_mean =m002_m[0]
m002_amito_fit_std = m002_m[1]

# %%
m002_amito_fit_mean_final = m002_amito_fit_mean[0][-1]
m002_amito_fit_std_final = m002_amito_fit_std[0][-1]

# %%
m002_amito_fit_mean_final
# Out:
# 0.75016776549318009

# %%
m002_amito_fit_std_final
# Out:
# 0.05586960031784341

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190102_Test of FGM_6_Trial of Moving Optimum\Data\5.1C. MO STD = 0.002_Adaptation\Mito")

# %%
m002_mito = ['Cor_Rv_MoveOpt_SM002_NoPley_GMU001_Dim10_P45_Mito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m002_s = get_data1(m002_mito)

m002_mito_fit_mean =m002_s[0]
m002_mito_fit_std = m002_s[1]
m002_mito_var_mean =m002_s[2]
m002_mito_var_std = m002_s[3]

# %%
m002_mito_fit_mean_final = m002_mito_fit_mean[0][-1]
m002_mito_fit_std_final = m002_mito_fit_std[0][-1]

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 36})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(6)
    ax.spines['bottom'].set_linewidth(6)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')

# %% [markdown]
# ### Optimum Moving STD =0.006

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190117_Test of FGM_6_Deterministic Moving Optimum_Change MO STD\Data\1.5. MO STD = 0.006_Adaptation\Amito")

# %%
m006_amito = ['Cor_Rv_MoveOpt_SM006_NoPley_GMU001_Dim10_P45_Amito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m006_m = get_data1(m006_amito)

m006_amito_fit_mean =m006_m[0]
m006_amito_fit_std = m006_m[1]

m006_amito_fit_mean_final = m006_amito_fit_mean[0][-1]
m006_amito_fit_std_final = m006_amito_fit_std[0][-1]

# %%
print m006_amito_fit_mean_final
print m006_amito_fit_std_final
# Out:
# 0.696339786371
# 0.0761894189991

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190117_Test of FGM_6_Deterministic Moving Optimum_Change MO STD\Data\1.5. MO STD = 0.006_Adaptation\Mito")

# %%
m006_mito = ['Cor_Rv_MoveOpt_SM006_NoPley_GMU001_Dim10_P45_Mito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m006_m2 = get_data1(m006_mito)

m006_mito_fit_mean =m006_m2[0]
m006_mito_fit_std = m006_m2[1]

m006_mito_fit_mean_final = m006_mito_fit_mean[0][-1]
m006_mito_fit_std_final = m006_mito_fit_std[0][-1]

# %%
print m006_mito_fit_mean_final
print m006_mito_fit_std_final
# Out:
# 0.725799972685
# 0.0969323850614

# %% [markdown]
# ### Optimum Moving STD =0.021

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190117_Test of FGM_6_Deterministic Moving Optimum_Change MO STD\Data\1.9. MO STD = 0.021_Adaptation\Amito")

# %%
m021_amito = ['Cor_Rv_MoveOpt_SM021_NoPley_GMU001_Dim10_P45_Amito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m021_m = get_data1(m021_amito)

m021_amito_fit_mean =m021_m[0]
m021_amito_fit_std = m021_m[1]

m021_amito_fit_mean_final = m021_amito_fit_mean[0][-1]
m021_amito_fit_std_final = m021_amito_fit_std[0][-1]

# %%
print m021_amito_fit_mean_final
print m021_amito_fit_std_final
# Out:
# 0.509925733924
# 0.109460440432

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190117_Test of FGM_6_Deterministic Moving Optimum_Change MO STD\Data\1.9. MO STD = 0.021_Adaptation\Mito")

# %%
m021_mito = ['Cor_Rv_MoveOpt_SM021_NoPley_GMU001_Dim10_P45_Mito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m021_m2 = get_data1(m021_mito)

m021_mito_fit_mean =m021_m2[0]
m021_mito_fit_std = m021_m2[1]

m021_mito_fit_mean_final = m021_mito_fit_mean[0][-1]
m021_mito_fit_std_final = m021_mito_fit_std[0][-1]

# %%
print m021_mito_fit_mean_final
print m021_mito_fit_std_final
# Out:
# 0.136010097318
# 0.126025001907

# %% [markdown]
# ### Optimum Moving STD =0.05

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190102_Test of FGM_6_Trial of Moving Optimum\Data\6.1. MO STD = 0.05_Adaptation\Amito")

# %%
m05_amito = ['Cor_Rv_MoveOpt_SM05_NoPley_GMU001_Dim10_P45_Amito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m05_m = get_data1(m05_amito)

m05_amito_fit_mean =m05_m[0]
m05_amito_fit_std = m05_m[1]
m05_amito_var_mean =m05_m[2]
m05_amito_var_std = m05_m[3]

# %%
m05_amito_fit_mean_final = m05_amito_fit_mean[0][-1]
m05_amito_fit_std_final = m05_amito_fit_std[0][-1]

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190102_Test of FGM_6_Trial of Moving Optimum\Data\6.1. MO STD = 0.05_Adaptation\Mito")

# %%
m05_mito = ['Cor_Rv_MoveOpt_SM05_NoPley_GMU001_Dim10_P45_Mito_Fit_N1K_Fit05_SM005_2KG.csv']

# %%
m05_s = get_data1(m05_mito)

m05_mito_fit_mean =m05_s[0]
m05_mito_fit_std = m05_s[1]
m05_mito_var_mean =m05_s[2]
m05_mito_var_std = m05_s[3]

# %%
m05_mito_fit_mean_final = m05_mito_fit_mean[0][-1]
m05_mito_fit_std_final = m05_mito_fit_std[0][-1]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_ylim(-0.05, 1)
ax.set_xlim(0.5,5.5)


x = [1,2, 3, 4, 5]

a = [fix_amito_fit_mean_final]+ [m002_amito_fit_mean_final]+[m006_amito_fit_mean_final]+\
[m021_amito_fit_mean_final]+ [m05_amito_fit_mean_final]

error_a = 1.98* np.array([fix_amito_fit_std_final]+ [m002_amito_fit_std_final]+[m006_amito_fit_std_final]+\
[m021_amito_fit_std_final]+ [m05_amito_fit_std_final])/((100)**0.5)


b = [fix_mito_fit_mean_final]+ [m002_mito_fit_mean_final]+[m006_mito_fit_mean_final]+\
[m021_mito_fit_mean_final]+ [m05_mito_fit_mean_final]

error_b = 1.98* np.array([fix_mito_fit_std_final]+ [m002_mito_fit_std_final]+[m006_mito_fit_std_final]+\
[m021_mito_fit_std_final]+ [m05_mito_fit_std_final])/((100)**0.5)



ax.set_xlabel('SD of Optimum Movement', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36)


ax.errorbar(x, a, yerr = error_a, label = 'Amitosis', fmt='o', color = 'b', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,a, color = 'b',ls = '--', alpha = 0.8)

ax.errorbar(x, b, yerr = error_b, label = 'Mitosis', fmt='o', color = 'deepskyblue', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,b, color = 'deepskyblue',ls = '--', alpha = 0.8)





plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

# legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =25)
# frame = legend.get_frame()
# # frame.set_framecolor('black')
# frame.set_edgecolor('black')

# extraticks=[0.45, 0.95]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

# ax.set_ylim(0.4, 1)

ax.set_xticks([1, 2, 3, 4, 5]) # choose which x locations to have ticks
ax.set_xticklabels([0, 0.002, 0.006, 0.021, 0.05]) # set the labels to display at those ticks

plt.legend(loc='upper right', frameon=False, prop={'size':29})


plt.show()

# %% [markdown]
# ## Revised_Dele SD = 0, make x axis log scale

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_ylim(-0.05, 1)
ax.set_xlim(0.0015,0.055)

x = [0.002, 0.006, 0.021, 0.05]
ax.set_xscale('log',basex=2)

# x = [1,2, 3, 4, 5]

a = [m002_amito_fit_mean_final]+[m006_amito_fit_mean_final]+[m021_amito_fit_mean_final]+ [m05_amito_fit_mean_final]

error_a = 1.98* np.array([m002_amito_fit_std_final]+[m006_amito_fit_std_final]+\
[m021_amito_fit_std_final]+ [m05_amito_fit_std_final])/((100)**0.5)


b = [m002_mito_fit_mean_final]+[m006_mito_fit_mean_final]+[m021_mito_fit_mean_final]+ [m05_mito_fit_mean_final]

error_b = 1.98* np.array([m002_mito_fit_std_final]+[m006_mito_fit_std_final]+\
[m021_mito_fit_std_final]+ [m05_mito_fit_std_final])/((100)**0.5)



ax.set_xlabel('SD of Optimum Movement', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36)


ax.errorbar(x, a, yerr = error_a, label = 'Amitosis', fmt='o', color = 'b', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,a, color = 'b',ls = '--', alpha = 0.8)

ax.errorbar(x, b, yerr = error_b, label = 'Mitosis', fmt='o', color = 'deepskyblue', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,b, color = 'deepskyblue',ls = '--', alpha = 0.8)





plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

# legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =25)
# frame = legend.get_frame()
# # frame.set_framecolor('black')
# frame.set_edgecolor('black')

# extraticks=[0.45, 0.95]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

# ax.set_ylim(0.4, 1)

ax.set_xticks([0.002, 0.006, 0.021, 0.05]) # choose which x locations to have ticks
ax.set_xticklabels([0.002, 0.006, 0.021, 0.05]) # set the labels to display at those ticks

plt.legend(loc='upper right', frameon=False, prop={'size':29})


plt.show()

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_ylim(-0.05, 1)
ax.set_xlim(0.5,2.5)


x = [1,2]

a = [w_amito_fit_mean_final]+ [s_amito_fit_mean_final]
error_a = 1.98* np.array([w_amito_fit_std_final]+ [s_amito_fit_std_final])/((100)**0.5)


b = [w_mito_fit_mean_final]+ [s_mito_fit_mean_final]
error_b = 1.98* np.array([w_mito_fit_std_final]+ [s_mito_fit_std_final])/((100)**0.5)



ax.set_xlabel('SD of Optimum Movement', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36)


ax.errorbar(x, a, yerr = error_a, label = 'Amitosis', fmt='o', color = 'b', markersize =14, lw=2, capsize=10, capthick=2)
# ax.plot(x,a, color = 'b',ls = '--', alpha = 0.8)

ax.errorbar(x, b, yerr = error_b, label = 'Mitosis', fmt='o', color = 'deepskyblue', markersize =14, lw=2, capsize=10, capthick=2)
# ax.plot(x,b, color = 'deepskyblue',ls = '--', alpha = 0.8)





plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

# legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =25)
# frame = legend.get_frame()
# # frame.set_framecolor('black')
# frame.set_edgecolor('black')

# extraticks=[0.45, 0.95]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

# ax.set_ylim(0.4, 1)

ax.set_xticks([1, 2]) # choose which x locations to have ticks
ax.set_xticklabels([0.002, 0.05]) # set the labels to display at those ticks

plt.legend(loc='upper right', prop={'size':29})


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-73bb1b981038> in <module>()
#      10 x = [1,2]
#      11
# ---> 12 a = [w_amito_fit_mean_final]+ [s_amito_fit_mean_final]
#      13 error_a = 1.98* np.array([w_amito_fit_std_final]+ [s_amito_fit_std_final])/((100)**0.5)
#      14
#
# NameError: name 'w_amito_fit_mean_final' is not defined

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_ylim(-0.05, 1)
ax.set_xlim(0.5,2.5)


x = [1,2]

a = [w_amito_fit_mean_final]+ [s_amito_fit_mean_final]
error_a = 1.98* np.array([w_amito_fit_std_final]+ [s_amito_fit_std_final])/((100)**0.5)


b = [w_mito_fit_mean_final]+ [s_mito_fit_mean_final]
error_b = 1.98* np.array([w_mito_fit_std_final]+ [s_mito_fit_std_final])/((100)**0.5)



ax.set_xlabel('SD of Optimum Movement', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36)


ax.errorbar(x, a, yerr = error_a, label = 'Amitosis', fmt='o', color = 'b', markersize =14, lw=2, capsize=10, capthick=2)
# ax.plot(x,a, color = 'b',ls = '--', alpha = 0.8)

ax.errorbar(x, b, yerr = error_b, label = 'Mitosis', fmt='o', color = 'deepskyblue', markersize =14, lw=2, capsize=10, capthick=2)
# ax.plot(x,b, color = 'deepskyblue',ls = '--', alpha = 0.8)





plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =32)
frame = legend.get_frame()
# frame.set_framecolor('grey')
frame.set_edgecolor('grey')

# extraticks=[0.45, 0.95]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

# ax.set_ylim(0.4, 1)

ax.set_xticks([1, 2]) # choose which x locations to have ticks
ax.set_xticklabels([0.002, 0.05]) # set the labels to display at those ticks

# plt.legend(loc='upper right', prop={'size':29})


plt.show()

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_ylim(-0.05, 1)
ax.set_xlim(0.5,5.5)


x = [1,2, 3, 4, 5]

a = [fix_amito_fit_mean_final]+ [m002_amito_fit_mean_final]+[m006_amito_fit_mean_final]+\
[m021_amito_fit_mean_final]+ [m05_amito_fit_mean_final]

error_a = 1.98* np.array([fix_amito_fit_std_final]+ [m002_amito_fit_std_final]+[m006_amito_fit_std_final]+\
[m021_amito_fit_std_final]+ [m05_amito_fit_std_final])/((100)**0.5)


b = [fix_mito_fit_mean_final]+ [m002_mito_fit_mean_final]+[m006_mito_fit_mean_final]+\
[m021_mito_fit_mean_final]+ [m05_mito_fit_mean_final]

error_b = 1.98* np.array([fix_mito_fit_std_final]+ [m002_mito_fit_std_final]+[m006_mito_fit_std_final]+\
[m021_mito_fit_std_final]+ [m05_mito_fit_std_final])/((100)**0.5)



ax.set_xlabel('SD of Optimum Movement', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36)


ax.errorbar(x, a, yerr = error_a, label = 'Amitosis', fmt='o', color = 'b', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,a, color = 'b',ls = '--', alpha = 0.8)

ax.errorbar(x, b, yerr = error_b, label = 'Mitosis', fmt='o', color = 'deepskyblue', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,b, color = 'deepskyblue',ls = '--', alpha = 0.8)





plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =32)
frame = legend.get_frame()
# frame.set_framecolor('black')
frame.set_edgecolor('black')

# extraticks=[0.45, 0.95]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

# ax.set_ylim(0.4, 1)

ax.set_xticks([1, 2, 3, 4, 5]) # choose which x locations to have ticks
ax.set_xticklabels([0, 0.002, 0.006, 0.021, 0.05]) # set the labels to display at those ticks

# plt.legend(loc='upper right', frameon=False, prop={'size':29})


plt.show()

# %%
fig = plt.figure(figsize=(16, 12), dpi = 300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_ylim(-0.05, 1)
ax.set_xlim(0.0015,0.055)

x = [0.002, 0.006, 0.021, 0.05]
ax.set_xscale('log',basex=2)

# x = [1,2, 3, 4, 5]

a = [m002_amito_fit_mean_final]+[m006_amito_fit_mean_final]+[m021_amito_fit_mean_final]+ [m05_amito_fit_mean_final]

error_a = 1.98* np.array([m002_amito_fit_std_final]+[m006_amito_fit_std_final]+\
[m021_amito_fit_std_final]+ [m05_amito_fit_std_final])/((100)**0.5)


b = [m002_mito_fit_mean_final]+[m006_mito_fit_mean_final]+[m021_mito_fit_mean_final]+ [m05_mito_fit_mean_final]

error_b = 1.98* np.array([m002_mito_fit_std_final]+[m006_mito_fit_std_final]+\
[m021_mito_fit_std_final]+ [m05_mito_fit_std_final])/((100)**0.5)



ax.set_xlabel('SD of Optimum Movement', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36)


ax.errorbar(x, a, yerr = error_a, label = 'Amitosis', fmt='o', color = 'b', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,a, color = 'b',ls = '--', alpha = 0.8)

ax.errorbar(x, b, yerr = error_b, label = 'Mitosis', fmt='o', color = 'deepskyblue', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,b, color = 'deepskyblue',ls = '--', alpha = 0.8)





plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =32)
frame = legend.get_frame()
# frame.set_framecolor('black')
frame.set_edgecolor('black')

ax.set_xticks([0.002, 0.006, 0.021, 0.05]) # choose which x locations to have ticks
ax.set_xticklabels([0.002, 0.006, 0.021, 0.05]) # set the labels to display at those ticks

# plt.legend(loc='upper right', frameon=False, prop={'size':29})


plt.show()

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_ylim(-0.05, 1)
ax.set_xlim(0.5,5.5)

logx = np.log(x) / np.log(2)


x = [0, 0.002, 0.006, 0.021, 0.05]

a = [fix_amito_fit_mean_final]+ [m002_amito_fit_mean_final]+[m006_amito_fit_mean_final]+\
[m021_amito_fit_mean_final]+ [m05_amito_fit_mean_final]

error_a = 1.98* np.array([fix_amito_fit_std_final]+ [m002_amito_fit_std_final]+[m006_amito_fit_std_final]+\
[m021_amito_fit_std_final]+ [m05_amito_fit_std_final])/((100)**0.5)


b = [fix_mito_fit_mean_final]+ [m002_mito_fit_mean_final]+[m006_mito_fit_mean_final]+\
[m021_mito_fit_mean_final]+ [m05_mito_fit_mean_final]

error_b = 1.98* np.array([fix_mito_fit_std_final]+ [m002_mito_fit_std_final]+[m006_mito_fit_std_final]+\
[m021_mito_fit_std_final]+ [m05_mito_fit_std_final])/((100)**0.5)



ax.set_xlabel('SD of Optimum Movement', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36)


ax.errorbar(x, a, yerr = error_a, label = 'Amitosis', fmt='o', color = 'b', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,a, color = 'b',ls = '--', alpha = 0.8)

ax.errorbar(x, b, yerr = error_b, label = 'Mitosis', fmt='o', color = 'deepskyblue', markersize =14, lw=2, capsize=10, capthick=2)
ax.plot(x,b, color = 'deepskyblue',ls = '--', alpha = 0.8)





plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =29)
frame = legend.get_frame()
# frame.set_framecolor('black')
frame.set_edgecolor('black')

# extraticks=[0.45, 0.95]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

# ax.set_ylim(0.4, 1)

ax.set_xticks([1, 2, 3, 4, 5]) # choose which x locations to have ticks
ax.set_xticklabels([0, 0.002, 0.006, 0.021, 0.05]) # set the labels to display at those ticks

# plt.legend(loc='upper right', frameon=False, prop={'size':29})


plt.show()
