# %%
import numpy as np
import scipy.spatial as spa
import random
import pandas as pd 
from scipy.linalg import hadamard
import itertools as it 
import scipy.stats as stat
import scipy.integrate as integrate
import math
import argparse
import os

# %%
generation_list = []

for i in range(1002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 1002

# %%
# N =20
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20170929_Both Beneficial and Deleterious Mutations (Same S_1% Beneficial)_N =20, 50 and 100_Stride =1\Data\N =20")

# %%
file_20 = ['T7_Fitness_Amito_20_10K_E1.csv', 'T7_Fitness_Mito_20_10K_E1.csv', 'T7_Fitness_SF_20_10K_E1.csv', \
         'T7_Fitness_RM_20_10K_E1.csv', 'T7_Fitness_SF_E100_20_10K_E1.csv', 'T7_Fitness_RM_E100_20_10K_E1.csv']

mfit_20 = []
log_mfit_20 = []

varfit_20 = []
varlog_fit_20 =[]

for i in file_20:
    f = pd.read_csv(i,dtype=str)
    
    mfit = []
    log_mfit = []
    
    varfit = []
    varlog_fit =[]
    
    mfit.extend(list(pd.Series(f.meanFit,dtype=float)))
    log_mfit.extend(list(pd.Series(f.log_meanFit,dtype=float)))
    
    varfit.extend(list(pd.Series(f.varFit,dtype=float)))
    varlog_fit.extend(list(pd.Series(f.varlog_Fit,dtype=float)))
    
    mfit_20.append(mfit)
    log_mfit_20.append(log_mfit)
    
    varfit_20.append(varfit)
    varlog_fit_20.append(varlog_fit)

# %%
# N =50
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20170929_Both Beneficial and Deleterious Mutations (Same S_1% Beneficial)_N =20, 50 and 100_Stride =1\Data\N =50")

# %%
file_50 = ['T7_Fitness_Amito_50_10K_E1.csv', 'T7_Fitness_Mito_50_10K_E1.csv', 'T7_Fitness_SF_50_10K_E1.csv', \
         'T7_Fitness_RM_50_10K_E1.csv', 'T7_Fitness_SF_E100_50_10K_E1.csv', 'T7_Fitness_RM_E100_50_10K_E1.csv']

mfit_50 = []
log_mfit_50 = []

varfit_50 = []
varlog_fit_50 =[]

for i in file_50:
    f = pd.read_csv(i,dtype=str)
    
    mfit = []
    log_mfit = []
    
    varfit = []
    varlog_fit =[]
    
    mfit.extend(list(pd.Series(f.meanFit,dtype=float)))
    log_mfit.extend(list(pd.Series(f.log_meanFit,dtype=float)))

    varfit.extend(list(pd.Series(f.varFit,dtype=float)))
    varlog_fit.extend(list(pd.Series(f.varlog_Fit,dtype=float)))
    
    mfit_50.append(mfit)
    log_mfit_50.append(log_mfit)
    
    varfit_50.append(varfit)
    varlog_fit_50.append(varlog_fit)

# %%
# N =100
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20170929_Both Beneficial and Deleterious Mutations (Same S_1% Beneficial)_N =20, 50 and 100_Stride =1\Data\N =100")

# %%
file_100 = ['T7_Fitness_Amito_100_10K_E1.csv', 'T7_Fitness_Mito_100_10K_E1.csv', 'T7_Fitness_SF_100_10K_E1.csv', \
         'T7_Fitness_RM_100_10K_E1.csv', 'T7_Fitness_SF_E100_100_10K_E1.csv', 'T7_Fitness_RM_E100_100_10K_E1.csv']

mfit_100 = []
log_mfit_100 = []

varfit_100 = []
varlog_fit_100 =[]

for i in file_100:
    f = pd.read_csv(i,dtype=str)
    
    mfit = []
    log_mfit = []
    
    varfit = []
    varlog_fit =[]
    
    mfit.extend(list(pd.Series(f.meanFit,dtype=float)))
    log_mfit.extend(list(pd.Series(f.log_meanFit,dtype=float)))

    varfit.extend(list(pd.Series(f.varFit,dtype=float)))
    varlog_fit.extend(list(pd.Series(f.varlog_Fit,dtype=float)))
    
    mfit_100.append(mfit)
    log_mfit_100.append(log_mfit)
    
    varfit_100.append(varfit)
    varlog_fit_100.append(varlog_fit)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = log_mfit_20[0][:1002]
b = log_mfit_20[1][:1002]
c = log_mfit_20[2][:1002]
d = log_mfit_20[3][:1002]
e = log_mfit_20[4][:1002]
f = log_mfit_20[5][:1002]



plt.title('Soma_ln_MeanFit_MUL_N =20_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('ln Mean Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=-1,linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.plot(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.plot(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.plot(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.plot(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.plot(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)


plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)
plt.axhline(y=0, xmin=0, xmax=10000, ls ='dashed', color ='black', linewidth=1.5)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='lower left', frameon=False, prop={'size':23})

plt.ylim(-1, 0)
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = log_mfit_50[0][:1002]
b = log_mfit_50[1][:1002]
c = log_mfit_50[2][:1002]
d = log_mfit_50[3][:1002]
e = log_mfit_50[4][:1002]
f = log_mfit_50[5][:1002]



plt.title('Soma_ln_MeanFit_MUL_N =50_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('ln Mean Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=-1,linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.plot(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.plot(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.plot(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.plot(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.plot(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)


plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)
plt.axhline(y=0, xmin=0, xmax=10000, ls ='dashed', color ='black', linewidth=1.5)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc=3, frameon=False, prop={'size':23})

plt.ylim(-1, 0.2)
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
np.log(1.817074355)
# Out:
# 0.59722771042596001

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = log_mfit_100[0][:1002]
b = log_mfit_100[1][:1002]
c = log_mfit_100[2][:1002]
d = log_mfit_100[3][:1002]
e = log_mfit_100[4][:1002]
f = log_mfit_100[5][:1002]



plt.title('Soma_ln_MeanFit_MUL_N =100_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('ln Mean Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=-1,linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.plot(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.plot(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.plot(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.plot(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.plot(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)


plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)
plt.axhline(y=0, xmin=0, xmax=10000, ls ='dashed', color ='black', linewidth=1.5)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc=3, frameon=False, prop={'size':23})

plt.ylim(-1, 0.2)
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = mfit_20[0][:1002]
b = mfit_20[1][:1002]
c = mfit_20[2][:1002]
d = mfit_20[3][:1002]
e = mfit_20[4][:1002]
f = mfit_20[5][:1002]



plt.title('Soma_MeanFit_MUL_N =20_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('lg Mean Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=10**(-1),linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.semilogy(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.semilogy(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.semilogy(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.semilogy(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.semilogy(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.semilogy(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)

plt.minorticks_off()

plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)

plt.axhline(y=1, xmin=0, xmax=10000, ls ='dashed', color ='black', linewidth=1.5)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc=3, frameon=False, prop={'size':23})

plt.ylim(10**(-1), 1)
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = mfit_50[0][:1002]
b = mfit_50[1][:1002]
c = mfit_50[2][:1002]
d = mfit_50[3][:1002]
e = mfit_50[4][:1002]
f = mfit_50[5][:1002]



plt.title('Soma_MeanFit_MUL_N =50_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('lg Mean Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=10**(-1),linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.semilogy(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.semilogy(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.semilogy(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.semilogy(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.semilogy(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.semilogy(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)

plt.minorticks_off()

plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)
plt.axhline(y=1, xmin=0, xmax=10000, ls ='dashed', color ='black', linewidth=1.5)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc=3, frameon=False, prop={'size':23})

plt.ylim(10**(-1), 1.2)
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = mfit_100[0][:1002]
b = mfit_100[1][:1002]
c = mfit_100[2][:1002]
d = mfit_100[3][:1002]
e = mfit_100[4][:1002]
f = mfit_100[5][:1002]



plt.title('Soma_MeanFit_MUL_N =100_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('lg Mean Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=10**(-1),linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.semilogy(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.semilogy(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.semilogy(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.semilogy(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.semilogy(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.semilogy(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)

plt.minorticks_off()

plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)
plt.axhline(y=1, xmin=0, xmax=10000, ls ='dashed', color ='black', linewidth=1.5)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc=3, frameon=False, prop={'size':23})

plt.ylim(10**(-1), 1.5)
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = varfit_20[0][:1002]
b = varfit_20[1][:1002]
c = varfit_20[2][:1002]
d = varfit_20[3][:1002]
e = varfit_20[4][:1002]
f = varfit_20[5][:1002]



plt.title('Soma_VarFit_MUL_N =20_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('Var Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=0,linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.plot(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.plot(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.plot(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.plot(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.plot(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)

plt.minorticks_off()

plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)



# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc=2, frameon=False, prop={'size':16})

plt.ylim(0, 0.0035)
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = varfit_50[0][:1002]
b = varfit_50[1][:1002]
c = varfit_50[2][:1002]
d = varfit_50[3][:1002]
e = varfit_50[4][:1002]
f = varfit_50[5][:1002]



plt.title('Soma_VarFit_MUL_N =50_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('Var Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=0,linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.plot(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.plot(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.plot(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.plot(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.plot(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)

plt.minorticks_off()

plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)



# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='upper left', frameon=False, prop={'size':21})

plt.ylim(0, 0.006)
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = varfit_100[0][:1002]
b = varfit_100[1][:1002]
c = varfit_100[2][:1002]
d = varfit_100[3][:1002]
e = varfit_100[4][:1002]
f = varfit_100[5][:1002]



plt.title('Soma_VarFit_MUL_N =100_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('Var Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=0,linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.plot(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.plot(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.plot(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.plot(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.plot(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)

plt.minorticks_off()

plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)



# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='upper left', frameon=False, prop={'size':23})

plt.ylim(0, 0.007)
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = varfit_20[0][:1002]
b = varfit_20[1][:1002]
c = varfit_20[2][:1002]
d = varfit_20[3][:1002]
e = varfit_20[4][:1002]
f = varfit_20[5][:1002]



plt.title('Soma_lg_VarFit_MUL_N =20_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('lg Var Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=10**(-6),linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.semilogy(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.semilogy(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.semilogy(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.semilogy(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.semilogy(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.semilogy(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)

plt.minorticks_off()

plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)



# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc=3, frameon=False, prop={'size':23})

plt.ylim(10**(-6), 0.01)
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = varfit_50[0][:1002]
b = varfit_50[1][:1002]
c = varfit_50[2][:1002]
d = varfit_50[3][:1002]
e = varfit_50[4][:1002]
f = varfit_50[5][:1002]



plt.title('Soma_lg_VarFit_MUL_N =50_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('lg Var Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=10**(-6),linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.semilogy(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.semilogy(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.semilogy(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.semilogy(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.semilogy(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.semilogy(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)

plt.minorticks_off()

plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)



# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc=3, frameon=False, prop={'size':23})

plt.ylim(10**(-6), 10**(-2))
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = varfit_100[0][:1002]
b = varfit_100[1][:1002]
c = varfit_100[2][:1002]
d = varfit_100[3][:1002]
e = varfit_100[4][:1002]
f = varfit_100[5][:1002]



plt.title('Soma_lg_VarFit_MUL_N =100_B and D_P =1%_S =0.1', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('lg Var Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y=10**(-6),linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')     

plt.tick_params(axis='both', which='major', labelsize=25)

plt.semilogy(t,a,'r', label = 'Amito', ls = 'solid',linewidth=3.0) # plotting t,a separately 
plt.semilogy(t,b,'b', label = 'Mito', ls= 'solid', linewidth=3.0) # plotting t,b separately 
plt.semilogy(t,c,'y', label = 'SF_E1', ls = 'solid', linewidth=3.0) # plotting t,c separately 
plt.semilogy(t,d,'g', label = 'RM_E1',ls = 'solid', linewidth=3.0)
plt.semilogy(t,e,'m', label = 'SF_E100', ls = 'solid', linewidth=3.0)
plt.semilogy(t,f,'c', label = 'RM_E100',ls= 'solid', linewidth=3.0)

plt.minorticks_off()

plt.xlim(0, 1005)
# plt.axhline(y=-12)
# plt.axvline(x=0)



# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc=3, frameon=False, prop={'size':23})

plt.ylim(10**(-6), 10**(-2))
# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()
