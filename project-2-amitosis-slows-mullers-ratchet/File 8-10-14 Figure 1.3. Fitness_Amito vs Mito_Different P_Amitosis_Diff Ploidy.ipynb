# %%
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import seaborn as sns
# %matplotlib inline

# %%
def get_data(file_list):
    total_fit_mean = []
    total_fit_std = []

    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
       
        fit_mean.extend(list(pd.Series(f.meanFit,dtype=float)))
        fit_std.extend(list(pd.Series(f.PopMeanFit_STD,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
        
    return total_fit_mean, total_fit_std

# %%
generation_list = []

for i in range(10002):
    generation_list.append(i)

# %% [markdown]
# Mitosis

# %%
# N =10
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20180426_Collect new data for paper figures_Global U =0.1_S =-10%\Data\180828 New Data\Figure 3. Amto vs Mito_P =2 and 45\Mito\N10")

# %%
m10_file = ['Fitness_WF_Mito_10_P2_L1_180827_10KG.csv', 'Fitness_WF_Mito_10_P45_L1_180827_10KG.csv']

m10_result = get_data(m10_file)

m10_fit_mean = np.array(m10_result[0])
m10_fit_std = np.array(m10_result[1])

# %%
m10_fit_upper = m10_fit_mean +1.98*m10_fit_std/(100**0.5)
m10_fit_lower = m10_fit_mean -1.98*m10_fit_std/(100**0.5)

m10_fit_mean_log = np.log10(m10_fit_mean)
m10_fit_upper_log = np.log10(m10_fit_upper)
m10_fit_lower_log = np.log10(m10_fit_lower)

# %%
# N =100
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20180426_Collect new data for paper figures_Global U =0.1_S =-10%\Data\180828 New Data\Figure 3. Amto vs Mito_P =2 and 45\Mito\N100")

# %%
m100_file = ['Fitness_WF_Mito_100_P2_L1_180425_10KG.csv', 'Fitness_WF_Mito_100_P45_L1_180425_10KG.csv']

m100_result = get_data(m100_file)

m100_fit_mean = np.array(m100_result[0])
m100_fit_std = np.array(m100_result[1])

# %%
m100_fit_upper = m100_fit_mean +1.98*m100_fit_std/(100**0.5)
m100_fit_lower = m100_fit_mean -1.98*m100_fit_std/(100**0.5)

m100_fit_mean_log = np.log10(m100_fit_mean)
m100_fit_upper_log = np.log10(m100_fit_upper)
m100_fit_lower_log = np.log10(m100_fit_lower)

# %%
# N =1000
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20180426_Collect new data for paper figures_Global U =0.1_S =-10%\Data\180828 New Data\Figure 3. Amto vs Mito_P =2 and 45\Mito\N1K")

# %%
m1k_file = ['Fitness_WF_Mito_1K_P2_L1_180505_10KG_24.csv', 'Fitness_WF_Mito_1K_P45_L1_180425_10KG.csv']

m1k_result = get_data(m1k_file)

m1k_fit_mean = np.array(m1k_result[0])
m1k_fit_std = np.array(m1k_result[1])

# %%
m1k_fit_upper = m1k_fit_mean +1.98*m1k_fit_std/(100**0.5)
m1k_fit_lower = m1k_fit_mean -1.98*m1k_fit_std/(100**0.5)

m1k_fit_mean_log = np.log10(m1k_fit_mean)
m1k_fit_upper_log = np.log10(m1k_fit_upper)
m1k_fit_lower_log = np.log10(m1k_fit_lower)

# %%
# N =10K
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20180426_Collect new data for paper figures_Global U =0.1_S =-10%\Data\180828 New Data\Figure 3. Amto vs Mito_P =2 and 45\Mito\N10K")

# %%
m10k_file = ['Fitness_WF_Mito_10K_P2_L1_180425.csv', 'Fitness_WF_Mito_10K_P45_L1_180425.csv']

m10k_result = get_data(m10k_file)

m10k_fit_mean = np.array(m10k_result[0])
m10k_fit_std = np.array(m10k_result[1])

# %%
m10k_fit_upper = m10k_fit_mean +1.98*m10k_fit_std/(100**0.5)
m10k_fit_lower = m10k_fit_mean -1.98*m10k_fit_std/(100**0.5)

m10k_fit_mean_log = np.log10(m10k_fit_mean)
m10k_fit_upper_log = np.log10(m10k_fit_upper)
m10k_fit_lower_log = np.log10(m10k_fit_lower)

# %% [markdown]
# Amitosis

# %%
# N =10
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20180426_Collect new data for paper figures_Global U =0.1_S =-10%\Data\180828 New Data\Figure 3. Amto vs Mito_P =2 and 45\Amito\N10")

# %%
a10_file = ['Fitness_WF_Amito_10_P2_L1_180827_10KG.csv', 'Fitness_WF_Amito_10_P45_L1_180827_10KG.csv']

# %%
a10_result = get_data(a10_file)

a10_fit_mean = np.array(a10_result[0])
a10_fit_std = np.array(a10_result[1])

# %%
a10_fit_upper = a10_fit_mean +1.98*a10_fit_std/(100**0.5)
a10_fit_lower = a10_fit_mean -1.98*a10_fit_std/(100**0.5)

a10_fit_mean_log = np.log10(a10_fit_mean)
a10_fit_upper_log = np.log10(a10_fit_upper)
a10_fit_lower_log = np.log10(a10_fit_lower)

# %%
# N =100
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20180426_Collect new data for paper figures_Global U =0.1_S =-10%\Data\180828 New Data\Figure 3. Amto vs Mito_P =2 and 45\Amito\N100")

# %%
a100_file = ['Fitness_WF_Amito_100_P2_L1_180425_10KG.csv', 'Fitness_WF_Amito_100_P45_L1_180425_10KG.csv']

# %%
a100_result = get_data(a100_file)

a100_fit_mean = np.array(a100_result[0])
a100_fit_std = np.array(a100_result[1])

# %%
a100_fit_upper = a100_fit_mean +1.98*a100_fit_std/(100**0.5)
a100_fit_lower = a100_fit_mean -1.98*a100_fit_std/(100**0.5)

a100_fit_mean_log = np.log10(a100_fit_mean)
a100_fit_upper_log = np.log10(a100_fit_upper)
a100_fit_lower_log = np.log10(a100_fit_lower)

# %%
# N =1000
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20180426_Collect new data for paper figures_Global U =0.1_S =-10%\Data\180828 New Data\Figure 3. Amto vs Mito_P =2 and 45\Amito\N1K")

# %%
a1k_file = ['Fitness_WF_Amito_1K_P2_L1_180425_10KG.csv', 'Fitness_WF_Amito_1K_P45_L1_180425_10KG.csv']

# %%
a1k_result = get_data(a1k_file)

a1k_fit_mean = np.array(a1k_result[0])
a1k_fit_std = np.array(a1k_result[1])

# %%
a1k_fit_upper = a1k_fit_mean +1.98*a1k_fit_std/(100**0.5)
a1k_fit_lower = a1k_fit_mean -1.98*a1k_fit_std/(100**0.5)

a1k_fit_mean_log = np.log10(a1k_fit_mean)
a1k_fit_upper_log = np.log10(a1k_fit_upper)
a1k_fit_lower_log = np.log10(a1k_fit_lower)

# %%
def set_up_axes(ax, xmin, xmax, xstep, ymin, ymax, ystep, rnd, xlabel='', ylabel='', part_label=''):
    xtx = np.arange(xmin, xmax + xstep / 2, xstep).round(rnd)
    xrg = xtx.max() - xtx.min()
    ax.set_xlim(xtx.min(), xtx.max())
    ax.set_xticks(xtx)
    ax.set_xticklabels(xtx)
    ytx = np.arange(ymin, ymax + ystep / 2, ystep).round(rnd)
    yrg = ytx.max() - ytx.min()
    ax.set_ylim(ytx.min(), ytx.max())
    ax.set_yticks(ytx)
    ax.set_yticklabels(ytx)
    ax.text(xtx.min() - .016 * xrg, ytx.max() + .15 * yrg, part_label, \
        size=24, fontweight='bold', ha='center', va='center')
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    sns.despine(offset=10)
    sns.set_context("talk")

# %%
t = generation_list

# %%
a10_fit_mean_log[0][-1]
# Out:
# -3.8302364007825496

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(8, 8), dpi =300)



cols = sns.color_palette("Blues", 5)

fig.subplots_adjust()

set_up_axes(ax1, xmin=0, xmax=800, xstep=200, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='', ylabel='Fitness', part_label='A')
set_up_axes(ax2, xmin=0, xmax=800, xstep=200, ymin= -1, ymax=0, ystep=0.2, rnd=1, xlabel='', ylabel='', part_label='B')

set_up_axes(ax3, xmin=0, xmax=10000, xstep=2000, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='Fitness', part_label='C')
set_up_axes(ax4, xmin=0, xmax=10000, xstep=2000, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='', part_label='D')

print ax1.get_position()
print ax2.get_position()
print ax3.get_position()
print ax4.get_position()

ax1.set_position([.11, .59, .37, .32])
ax2.set_position([.60, .59, .37, .32])
ax3.set_position([.11, .10, .37, .32])
ax4.set_position([.60, .10, .37, .32])

ax1.plot(t[:801], m10_fit_mean_log[0][:801], clip_on=False, color='g', label="10")
ax1.fill_between(t[:801], m10_fit_lower_log[0][:801], m10_fit_upper_log[0][:801], alpha =0.2, facecolor='g')

ax1.plot(t[:801], m100_fit_mean_log[0][:801], clip_on=False, color='b', label="100")
ax1.fill_between(t[:801], m100_fit_lower_log[0][:801], m100_fit_upper_log[0][:801], alpha =0.2, facecolor='b')

ax1.plot(t[:801], m1k_fit_mean_log[0][:801], clip_on=False, color='m', label="1,000")
ax1.fill_between(t[:801], m1k_fit_lower_log[0][:801], m1k_fit_upper_log[0][:801], alpha =0.2, facecolor='m')

ax1.plot(t[:801], m10k_fit_mean_log[0][:801], clip_on=False, color='r', label="10,000")
ax1.fill_between(t[:801], m10k_fit_lower_log[0][:801], m10k_fit_upper_log[0][:801], alpha =0.2, facecolor='r')

ax1.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax1.set_ylim(-1, 0)
ax1.set_yticklabels(['0.1', '0.2', '0.5', '1'])



ax2.plot(t[:801], a10_fit_mean_log[0][:801], clip_on=False, color='g', label="10")
ax2.fill_between(t[:801], a10_fit_lower_log[0][:801], a10_fit_upper_log[0][:801], alpha =0.2, facecolor='g')

ax2.plot(t[:801], a100_fit_mean_log[0][:801], clip_on=False, color='b', label="100")
ax2.fill_between(t[:801], a100_fit_lower_log[0][:801], a100_fit_upper_log[0][:801], alpha =0.2, facecolor='b')

ax2.plot(t[:801], a1k_fit_mean_log[0][:801], clip_on=False, color='m', label="1,000")
ax2.fill_between(t[:801], a1k_fit_lower_log[0][:801], a1k_fit_upper_log[0][:801], alpha =0.2, facecolor='m')

ax2.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax2.set_ylim(-1, 0)
ax2.set_yticklabels(['0.1', '0.2', '0.5', '1'])



ax3.plot(t, m10_fit_mean_log[1], clip_on=False,   color='g', label="10")
ax3.fill_between(t, m10_fit_lower_log[1], m10_fit_upper_log[1], alpha =0.2, facecolor='g')

ax3.plot(t, m100_fit_mean_log[1], clip_on=False,   color='b', label="100")
ax3.fill_between(t, m100_fit_lower_log[1], m100_fit_upper_log[1], alpha =0.2, facecolor='b')

ax3.plot(t, m1k_fit_mean_log[1], clip_on=False,   color='m', label="1,000")
ax3.fill_between(t, m1k_fit_lower_log[1], m1k_fit_upper_log[1], alpha =0.2, facecolor='m')

ax3.plot(t, m10k_fit_mean_log[1], clip_on=False,   color='r', label="10,000")
ax3.fill_between(t, m10k_fit_lower_log[1], m10k_fit_upper_log[1], alpha =0.2, facecolor='r')

ax3.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax3.set_ylim(-1, 0)
ax3.set_yticklabels(['0.1', '0.2', '0.5', '1'])





ax4.plot(t, a10_fit_mean_log[1], clip_on=False, color='g', label="10")
ax4.fill_between(t, a10_fit_lower_log[1], a10_fit_upper_log[1], alpha =0.2, facecolor='g')

ax4.plot(t, a100_fit_mean_log[1], clip_on=False, color='b', label="100")
ax4.fill_between(t, a100_fit_lower_log[1], a100_fit_upper_log[1], alpha =0.2, facecolor='b')

ax4.plot(t, a1k_fit_mean_log[1], clip_on=False, color='m', label="1,000")
ax4.fill_between(t, a1k_fit_lower_log[1], a1k_fit_upper_log[1], alpha =0.2, facecolor='m')


ax4.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax4.set_ylim(-1, 0)
ax4.set_yticklabels(['0.1', '0.2', '0.5', '1'])


# ax1.legend(title=r"$\mathit{N}$", fontsize = 10)

leg = ax1.legend(fontsize = 12, frameon=False)
leg.set_title(r"$\mathit{N}$", prop = {'size':12})


# plt.savefig('test.pdf')
# ax1
# Out:
# Bbox(x0=0.125, y0=0.536818181818, x1=0.477272727273, y1=0.88)
# Bbox(x0=0.547727272727, y0=0.536818181818, x1=0.9, y1=0.88)
# Bbox(x0=0.125, y0=0.125, x1=0.477272727273, y1=0.468181818182)
# Bbox(x0=0.547727272727, y0=0.125, x1=0.9, y1=0.468181818182)

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 20})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(1.5)
    ax.spines['bottom'].set_linewidth(1.5)
    ax.spines['left'].set_position(('outward', 6))
    ax.spines['bottom'].set_position(('outward', 6))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=6, width=2, direction='out', pad=10, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=6, width=2, direction='out', pad=10, colors='black')

# %%
fig, ((ax1, ax2)) = plt.subplots(2, figsize=(8, 8), dpi = 300)

publication_figure(ax1)
publication_figure(ax2)

# cols = sns.color_palette("Blues", 5)

fig.subplots_adjust()

set_up_axes(ax1, xmin=0, xmax=800, xstep=200, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='Fitness', part_label='A')
set_up_axes(ax2, xmin=0, xmax=800, xstep=200, ymin= -1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='', part_label='B')

# set_up_axes(ax3, xmin=0, xmax=10000, xstep=2000, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='Fitness', part_label='C')
# set_up_axes(ax4, xmin=0, xmax=10000, xstep=2000, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='', part_label='D')

print ax1.get_position()
print ax2.get_position()
# print ax3.get_position()
# print ax4.get_position()

ax1.set_position([.11, .59, .37, .32])
ax2.set_position([.60, .59, .37, .32])
# ax3.set_position([.11, .10, .37, .32])
# ax4.set_position([.60, .10, .37, .32])

ax1.plot(t[:801], m10_fit_mean_log[0][:801], clip_on=False, color='g', label="10")
ax1.fill_between(t[:801], m10_fit_lower_log[0][:801], m10_fit_upper_log[0][:801], alpha =0.2, facecolor='g')

ax1.plot(t[:801], m100_fit_mean_log[0][:801], clip_on=False, color='b', label="100")
ax1.fill_between(t[:801], m100_fit_lower_log[0][:801], m100_fit_upper_log[0][:801], alpha =0.2, facecolor='b')

ax1.plot(t[:801], m1k_fit_mean_log[0][:801], clip_on=False, color='m', label="1,000")
ax1.fill_between(t[:801], m1k_fit_lower_log[0][:801], m1k_fit_upper_log[0][:801], alpha =0.2, facecolor='m')

ax1.plot(t[:801], m10k_fit_mean_log[0][:801], clip_on=False, color='r', label="10,000")
ax1.fill_between(t[:801], m10k_fit_lower_log[0][:801], m10k_fit_upper_log[0][:801], alpha =0.2, facecolor='r')

ax1.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax1.set_ylim(-1, 0)
ax1.set_yticklabels(['0.1', '0.2', '0.5', '1'])



ax2.plot(t[:801], a10_fit_mean_log[0][:801], clip_on=False, color='g', label="10")
ax2.fill_between(t[:801], a10_fit_lower_log[0][:801], a10_fit_upper_log[0][:801], alpha =0.2, facecolor='g')

ax2.plot(t[:801], a100_fit_mean_log[0][:801], clip_on=False, color='b', label="100")
ax2.fill_between(t[:801], a100_fit_lower_log[0][:801], a100_fit_upper_log[0][:801], alpha =0.2, facecolor='b')

ax2.plot(t[:801], a1k_fit_mean_log[0][:801], clip_on=False, color='m', label="1,000")
ax2.fill_between(t[:801], a1k_fit_lower_log[0][:801], a1k_fit_upper_log[0][:801], alpha =0.2, facecolor='m')

ax2.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax2.set_ylim(-1, 0)
ax2.set_yticklabels(['0.1', '0.2', '0.5', '1'])



# ax3.plot(t, m10_fit_mean_log[1], clip_on=False,   color='g', label="10")
# ax3.fill_between(t, m10_fit_lower_log[1], m10_fit_upper_log[1], alpha =0.2, facecolor='g')

# ax3.plot(t, m100_fit_mean_log[1], clip_on=False,   color='b', label="100")
# ax3.fill_between(t, m100_fit_lower_log[1], m100_fit_upper_log[1], alpha =0.2, facecolor='b')

# ax3.plot(t, m1k_fit_mean_log[1], clip_on=False,   color='m', label="1,000")
# ax3.fill_between(t, m1k_fit_lower_log[1], m1k_fit_upper_log[1], alpha =0.2, facecolor='m')

# ax3.plot(t, m10k_fit_mean_log[1], clip_on=False,   color='c', label="10,000")
# ax3.fill_between(t, m10k_fit_lower_log[1], m10k_fit_upper_log[1], alpha =0.2, facecolor='c')

# ax3.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
# ax3.set_ylim(-1, 0)
# ax3.set_yticklabels(['0.1', '0.2', '0.5', '1'])





# ax4.plot(t, a10_fit_mean_log[1], clip_on=False, color='g', label="10")
# ax4.fill_between(t, a10_fit_lower_log[1], a10_fit_upper_log[1], alpha =0.2, facecolor='g')

# ax4.plot(t, a100_fit_mean_log[1], clip_on=False, color='b', label="100")
# ax4.fill_between(t, a100_fit_lower_log[1], a100_fit_upper_log[1], alpha =0.2, facecolor='b')

# ax4.plot(t, a1k_fit_mean_log[1], clip_on=False, color='m', label="1,000")
# ax4.fill_between(t, a1k_fit_lower_log[1], a1k_fit_upper_log[1], alpha =0.2, facecolor='m')


# ax4.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
# ax4.set_ylim(-1, 0)
# ax4.set_yticklabels(['0.1', '0.2', '0.5', '1'])


# ax1.legend(title=r"$\mathit{N}$", fontsize = 10)

leg = ax1.legend(fontsize = 12, frameon=False)
leg.set_title(r"$\mathit{N}$", prop = {'size':12})


# plt.savefig('test.pdf')
# ax1
# Out:
# Bbox(x0=0.125, y0=0.536818181818, x1=0.9, y1=0.88)
# Bbox(x0=0.125, y0=0.125, x1=0.9, y1=0.468181818182)

# %%
fig, ((ax3, ax4)) = plt.subplots(2, figsize=(8, 8), dpi =300)

publication_figure(ax3)
publication_figure(ax4)


# cols = sns.color_palette("Blues", 5)

fig.subplots_adjust()

set_up_axes(ax3, xmin=0, xmax=10000, xstep=2000, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='Fitness', part_label='A')
set_up_axes(ax4, xmin=0, xmax=10000, xstep=2000, ymin= -1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='', part_label='B')

# set_up_axes(ax3, xmin=0, xmax=10000, xstep=2000, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='Fitness', part_label='C')
# set_up_axes(ax4, xmin=0, xmax=10000, xstep=2000, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='', part_label='D')

print ax3.get_position()
print ax4.get_position()
# print ax3.get_position()
# print ax4.get_position()

ax3.set_position([.11, .59, .37, .32])
ax4.set_position([.60, .59, .37, .32])
# ax3.set_position([.11, .10, .37, .32])
# ax4.set_position([.60, .10, .37, .32])

# ax1.plot(t[:801], m10_fit_mean_log[0][:801], clip_on=False, color='g', label="10")
# ax1.fill_between(t[:801], m10_fit_lower_log[0][:801], m10_fit_upper_log[0][:801], alpha =0.2, facecolor='g')

# ax1.plot(t[:801], m100_fit_mean_log[0][:801], clip_on=False, color='b', label="100")
# ax1.fill_between(t[:801], m100_fit_lower_log[0][:801], m100_fit_upper_log[0][:801], alpha =0.2, facecolor='b')

# ax1.plot(t[:801], m1k_fit_mean_log[0][:801], clip_on=False, color='m', label="1,000")
# ax1.fill_between(t[:801], m1k_fit_lower_log[0][:801], m1k_fit_upper_log[0][:801], alpha =0.2, facecolor='m')

# ax1.plot(t[:801], m10k_fit_mean_log[0][:801], clip_on=False, color='r', label="10,000")
# ax1.fill_between(t[:801], m10k_fit_lower_log[0][:801], m10k_fit_upper_log[0][:801], alpha =0.2, facecolor='r')

# ax1.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
# ax1.set_ylim(-1, 0)
# ax1.set_yticklabels(['0.1', '0.2', '0.5', '1'])



# ax2.plot(t[:801], a10_fit_mean_log[0][:801], clip_on=False, color='g', label="10")
# ax2.fill_between(t[:801], a10_fit_lower_log[0][:801], a10_fit_upper_log[0][:801], alpha =0.2, facecolor='g')

# ax2.plot(t[:801], a100_fit_mean_log[0][:801], clip_on=False, color='b', label="100")
# ax2.fill_between(t[:801], a100_fit_lower_log[0][:801], a100_fit_upper_log[0][:801], alpha =0.2, facecolor='b')

# ax2.plot(t[:801], a1k_fit_mean_log[0][:801], clip_on=False, color='m', label="1,000")
# ax2.fill_between(t[:801], a1k_fit_lower_log[0][:801], a1k_fit_upper_log[0][:801], alpha =0.2, facecolor='m')

# ax2.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
# ax2.set_ylim(-1, 0)
# ax2.set_yticklabels(['0.1', '0.2', '0.5', '1'])



ax3.plot(t, m10_fit_mean_log[1], clip_on=False,   color='g', label="10")
ax3.fill_between(t, m10_fit_lower_log[1], m10_fit_upper_log[1], alpha =0.2, facecolor='g')

ax3.plot(t, m100_fit_mean_log[1], clip_on=False,   color='b', label="100")
ax3.fill_between(t, m100_fit_lower_log[1], m100_fit_upper_log[1], alpha =0.2, facecolor='b')

ax3.plot(t, m1k_fit_mean_log[1], clip_on=False,   color='m', label="1,000")
ax3.fill_between(t, m1k_fit_lower_log[1], m1k_fit_upper_log[1], alpha =0.2, facecolor='m')

ax3.plot(t, m10k_fit_mean_log[1], clip_on=False,   color='r', label="10,000")
ax3.fill_between(t, m10k_fit_lower_log[1], m10k_fit_upper_log[1], alpha =0.2, facecolor='r')

ax3.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax3.set_ylim(-1, 0)
ax3.set_yticklabels(['0.1', '0.2', '0.5', '1'])





ax4.plot(t, a10_fit_mean_log[1], clip_on=False, color='g', label="10")
ax4.fill_between(t, a10_fit_lower_log[1], a10_fit_upper_log[1], alpha =0.2, facecolor='g')

ax4.plot(t, a100_fit_mean_log[1], clip_on=False, color='b', label="100")
ax4.fill_between(t, a100_fit_lower_log[1], a100_fit_upper_log[1], alpha =0.2, facecolor='b')

ax4.plot(t, a1k_fit_mean_log[1], clip_on=False, color='m', label="1,000")
ax4.fill_between(t, a1k_fit_lower_log[1], a1k_fit_upper_log[1], alpha =0.2, facecolor='m')


ax4.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax4.set_ylim(-1, 0)
ax4.set_yticklabels(['0.1', '0.2', '0.5', '1'])


# ax1.legend(title=r"$\mathit{N}$", fontsize = 10)

leg = ax3.legend(fontsize = 12, frameon=False)
leg.set_title(r"$\mathit{N}$", prop = {'size':12})


# plt.savefig('test.pdf')
# ax1
# Out:
# Bbox(x0=0.125, y0=0.536818181818, x1=0.9, y1=0.88)
# Bbox(x0=0.125, y0=0.125, x1=0.9, y1=0.468181818182)

# %%
# For Symposium

# %%
fig, ((ax3, ax4)) = plt.subplots(2, figsize=(8, 8), dpi =300)


fig.subplots_adjust()

set_up_axes(ax3, xmin=0, xmax=10000, xstep=2000, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='Fitness', part_label='A')
set_up_axes(ax4, xmin=0, xmax=10000, xstep=2000, ymin= -1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='', part_label='B')


print ax3.get_position()
print ax4.get_position()


ax3.set_position([.11, .59, .37, .32])
ax4.set_position([.60, .59, .37, .32])


ax3.plot(t, m10_fit_mean_log[1], clip_on=False,   color='g', label="10")
ax3.fill_between(t, m10_fit_lower_log[1], m10_fit_upper_log[1], alpha =0.2, facecolor='g')

ax3.plot(t, m100_fit_mean_log[1], clip_on=False,   color='b', label="100")
ax3.fill_between(t, m100_fit_lower_log[1], m100_fit_upper_log[1], alpha =0.2, facecolor='b')

ax3.plot(t, m1k_fit_mean_log[1], clip_on=False,   color='m', label="1,000")
ax3.fill_between(t, m1k_fit_lower_log[1], m1k_fit_upper_log[1], alpha =0.2, facecolor='m')

ax3.plot(t, m10k_fit_mean_log[1], clip_on=False,   color='r', label="10,000")
ax3.fill_between(t, m10k_fit_lower_log[1], m10k_fit_upper_log[1], alpha =0.2, facecolor='r')

ax3.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax3.set_ylim(-1, 0)
ax3.set_yticklabels(['0.1', '0.2', '0.5', '1'])





ax4.plot(t, a10_fit_mean_log[1], clip_on=False, color='g', label="10")
ax4.fill_between(t, a10_fit_lower_log[1], a10_fit_upper_log[1], alpha =0.2, facecolor='g')

ax4.plot(t, a100_fit_mean_log[1], clip_on=False, color='b', label="100")
ax4.fill_between(t, a100_fit_lower_log[1], a100_fit_upper_log[1], alpha =0.2, facecolor='b')

ax4.plot(t, a1k_fit_mean_log[1], clip_on=False, color='m', label="1,000")
ax4.fill_between(t, a1k_fit_lower_log[1], a1k_fit_upper_log[1], alpha =0.2, facecolor='m')


ax4.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax4.set_ylim(-1, 0)
ax4.set_yticklabels(['0.1', '0.2', '0.5', '1'])



leg = ax3.legend(fontsize = 12, frameon=False)
leg.set_title(r"$\mathit{N}$", prop = {'size':12})
# Out:
# Bbox(x0=0.125, y0=0.536818181818, x1=0.9, y1=0.88)
# Bbox(x0=0.125, y0=0.125, x1=0.9, y1=0.468181818182)

# %% [markdown]
# Supplementary Figure_P =2 for amitosis and mitosis

# %%
fig, ((ax1, ax2)) = plt.subplots(2,1, figsize=(8, 8), dpi =1200)

cols = sns.color_palette("Blues", 5)

fig.subplots_adjust()

set_up_axes(ax1, xmin=0, xmax=10000, xstep=2000, ymin=np.log10(0.7), ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='Fitness', part_label='A')
set_up_axes(ax2, xmin=0, xmax=10000, xstep=2000, ymin=np.log10(0.7), ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='', part_label='B')


print ax1.get_position()
print ax2.get_position()


ax1.set_position([.11, .59, .37, .32])
ax2.set_position([.60, .59, .37, .32])


ax1.plot(t, m10k_fit_mean_log[0], clip_on=False, color=cols[4], label="10,000")
ax1.fill_between(t, m10k_fit_lower_log[0], m10k_fit_upper_log[0], alpha =0.2, facecolor=cols[4])

ax1.set_yticks([np.log10(0.7), np.log10(0.8), np.log10(0.9), np.log10(1)])
ax1.set_ylim(np.log10(0.7), 0)
ax1.set_yticklabels(['0.7','0.8', '0.9','1'])


ax2.plot(t, a1k_fit_mean_log[0], clip_on=False, color=cols[3], label="1,000")
ax2.fill_between(t, a1k_fit_lower_log[0], a1k_fit_upper_log[0], alpha =0.2, facecolor=cols[3])

ax2.set_yticks([np.log10(0.7), np.log10(0.8), np.log10(0.9), np.log10(1)])
ax2.set_ylim(np.log10(0.7), 0)
ax2.set_yticklabels(['0.7','0.8', '0.9','1'])




# ax1.legend(title=r"$\mathit{N}$", fontsize = 10)

# leg = ax1.legend(fontsize = 12, frameon=False)
# leg.set_title(r"$\mathit{N}$", prop = {'size':12})

# leg2 = ax2.legend(loc =3, fontsize = 12, frameon=False)
# leg2.set_title(r"$\mathit{N}$", prop = {'size':12})

# plt.savefig('test.pdf')
# ax1
# Out:
# Bbox(x0=0.125, y0=0.536818181818, x1=0.9, y1=0.88)
# Bbox(x0=0.125, y0=0.125, x1=0.9, y1=0.468181818182)
# ...

# %%
fig, ((ax1, ax2)) = plt.subplots(2,1, figsize=(8, 8), dpi =300)

# cols = sns.color_palette("Blues", 5)

fig.subplots_adjust()

set_up_axes(ax1, xmin=0, xmax=10000, xstep=2000, ymin=np.log10(0.7), ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='Fitness', part_label='A')
set_up_axes(ax2, xmin=0, xmax=10000, xstep=2000, ymin=np.log10(0.7), ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='', part_label='B')


print ax1.get_position()
print ax2.get_position()


ax1.set_position([.11, .59, .37, .32])
ax2.set_position([.60, .59, .37, .32])


ax1.plot(t, m10k_fit_mean_log[0], clip_on=False, color='r', label="10,000")
ax1.fill_between(t, m10k_fit_lower_log[0], m10k_fit_upper_log[0], alpha =0.2, facecolor='r')

ax1.set_yticks([np.log10(0.7), np.log10(0.8), np.log10(0.9), np.log10(1)])
ax1.set_ylim(np.log10(0.7), 0)
ax1.set_yticklabels(['0.7','0.8', '0.9','1'])


ax2.plot(t, a1k_fit_mean_log[0], clip_on=False, color='m', label="1,000")
ax2.fill_between(t, a1k_fit_lower_log[0], a1k_fit_upper_log[0], alpha =0.2, facecolor='m')

ax2.set_yticks([np.log10(0.7), np.log10(0.8), np.log10(0.9), np.log10(1)])
ax2.set_ylim(np.log10(0.7), 0)
ax2.set_yticklabels(['0.7','0.8', '0.9','1'])




# ax1.legend(title=r"$\mathit{N}$", fontsize = 10)

leg = ax1.legend(loc = 3, fontsize = 12, frameon=False)
leg.set_title(r"$\mathit{N}$", prop = {'size':12})

leg2 = ax2.legend(loc =3, fontsize = 12, frameon=False)
leg2.set_title(r"$\mathit{N}$", prop = {'size':12})

# plt.savefig('test.pdf')
# ax1
# Out:
# Bbox(x0=0.125, y0=0.536818181818, x1=0.9, y1=0.88)
# Bbox(x0=0.125, y0=0.125, x1=0.9, y1=0.468181818182)
