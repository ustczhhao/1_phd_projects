# %%
import numpy as np
import scipy.spatial as spa
import random
import pandas as pd 
import statsmodels.formula.api as smf
import statsmodels.api as sm
from scipy.linalg import hadamard
import itertools as it 
import scipy.stats as stat
import scipy.integrate as integrate
import math
import argparse
import os

# %%
generation_list = []

for i in range(10001):
    generation_list.append(10*i)
    
print(len(generation_list))
# Out:
# 10001

# %%
os.chdir(r"F:\Prof. Azevedo\Simulation of Ciliate Evolution\1224_Test of RM and Selfing Ver2 Code\MUL\Fitness")

# %%
v1_rm = pd.read_csv('V1_Fitness_WF_RM_2_MUL_E_100K.csv',dtype=str)
fit_v1_rm = []
fit_v1_rm.extend(list(pd.Series(v1_rm.meanFit,dtype=float)))

log_mean_fit_v1_rm = []
log_mean_fit_v1_rm.extend(list(pd.Series(v1_rm.log_meanFit,dtype=float)))

# mean_log_fit_v1_rm = []
# mean_log_fit_v1_rm.extend(list(pd.Series(v1_rm.mean_logFit,dtype=float)))

# %%
v2_rm = pd.read_csv('V2_Fitness_WF_RM_2_MUL_E_100K.csv',dtype=str)
fit_v2_rm = []
fit_v2_rm.extend(list(pd.Series(v2_rm.meanFit,dtype=float)))

log_mean_fit_v2_rm = []
log_mean_fit_v2_rm.extend(list(pd.Series(v2_rm.log_meanFit,dtype=float)))

# mean_log_fit_v1_rm = []
# mean_log_fit_v1_rm.extend(list(pd.Series(v1_rm.mean_logFit,dtype=float)))

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = fit_v1_rm
b = fit_v2_rm


plt.title('MeanFit_MUL_Ver1 Vs Ver2_100K')
plt.xlabel('Time (generations)')
plt.ylabel('Mean Fitness')
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a,'r', label = 'Ver1', linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Ver2', linewidth=3.0) # plotting t,b separately 




# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='upper right', frameon=False, prop={'size':23})

# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = log_mean_fit_v1_rm
b = log_mean_fit_v2_rm


plt.title('log_MeanFit_MUL_Ver1 Vs Ver2_100K')
plt.xlabel('Time (generations)')
plt.ylabel('Mean Fitness')
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a,'r', label = 'Ver1', linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Ver2', linewidth=3.0) # plotting t,b separately 




# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='upper right', frameon=False, prop={'size':23})

# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
v1_sf = pd.read_csv('V1_Fitness_WF_SF_2_MUL_E_100K.csv',dtype=str)
fit_v1_sf = []
fit_v1_sf.extend(list(pd.Series(v1_sf.meanFit,dtype=float)))

log_mean_fit_v1_sf = []
log_mean_fit_v1_sf.extend(list(pd.Series(v1_sf.log_meanFit,dtype=float)))

# mean_log_fit_v1_rm = []
# mean_log_fit_v1_rm.extend(list(pd.Series(v1_rm.mean_logFit,dtype=float)))

# %%
v2_sf = pd.read_csv('V2_Fitness_WF_SELF_2_MUL_E_100K.csv',dtype=str)
fit_v2_sf = []
fit_v2_sf.extend(list(pd.Series(v2_sf.meanFit,dtype=float)))

log_mean_fit_v2_sf = []
log_mean_fit_v2_sf.extend(list(pd.Series(v2_sf.log_meanFit,dtype=float)))

# mean_log_fit_v1_rm = []
# mean_log_fit_v1_rm.extend(list(pd.Series(v1_rm.mean_logFit,dtype=float)))

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = fit_v1_sf
b = fit_v2_sf


plt.title('MeanFit_MUL_Ver1 Vs Ver2_SELFING_100K')
plt.xlabel('Time (generations)')
plt.ylabel('Mean Fitness')
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a,'r', label = 'Ver1', linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Ver2', linewidth=3.0) # plotting t,b separately 




# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='upper right', frameon=False, prop={'size':23})

# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = log_mean_fit_v1_sf
b = log_mean_fit_v2_sf


plt.title('log_MeanFit_MUL_Ver1 Vs Ver2_SELF_100K')
plt.xlabel('Time (generations)')
plt.ylabel('Mean Fitness')
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a,'r', label = 'Ver1', linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Ver2', linewidth=3.0) # plotting t,b separately 




# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='upper right', frameon=False, prop={'size':23})

# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
os.chdir(r"F:\Prof. Azevedo\Simulation of Ciliate Evolution\1224_Test of RM and Selfing Ver2 Code\ADD\Fitness")

# %%
generation_list = []

for i in range(1001):
    generation_list.append(10*i)
    
print(len(generation_list))
# Out:
# 1001

# %%
v1_rm = pd.read_csv('V1_Fitness_WF_RM_50_ADD_E_10K.csv',dtype=str)
fit_v1_rm = []
fit_v1_rm.extend(list(pd.Series(v1_rm.meanFit,dtype=float)))

log_mean_fit_v1_rm = []
log_mean_fit_v1_rm.extend(list(pd.Series(v1_rm.log_meanFit,dtype=float)))

# %%
v2_rm = pd.read_csv('V2_Fitness_WF_RM_50_ADD_E_10K.csv',dtype=str)
fit_v2_rm = []
fit_v2_rm.extend(list(pd.Series(v2_rm.meanFit,dtype=float)))

log_mean_fit_v2_rm = []
log_mean_fit_v2_rm.extend(list(pd.Series(v2_rm.log_meanFit,dtype=float)))

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = fit_v1_rm
b = fit_v2_rm


plt.title('MeanFit_ADD_Ver1 Vs Ver2_RM_50_10K')
plt.xlabel('Time (generations)')
plt.ylabel('Mean Fitness')
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a,'r', label = 'Ver1', linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Ver2', linewidth=3.0) # plotting t,b separately 




# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='upper right', frameon=False, prop={'size':23})

# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()

# %%
v1_sf_10 = pd.read_csv('V1_Fitness_WF_SF_50_ADD_E10_10K.csv',dtype=str)
fit_v1_sf_10 = []
fit_v1_sf_10.extend(list(pd.Series(v1_sf_10.meanFit,dtype=float)))

log_mean_fit_v1_sf_10 = []
log_mean_fit_v1_sf_10.extend(list(pd.Series(v1_sf_10.log_meanFit,dtype=float)))

# %%
v2_sf_10 = pd.read_csv('V2_Fitness_WF_SF_50_ADD_E10_10K.csv',dtype=str)
fit_v2_sf_10 = []
fit_v2_sf_10.extend(list(pd.Series(v2_sf_10.meanFit,dtype=float)))

log_mean_fit_v2_sf_10 = []
log_mean_fit_v2_sf_10.extend(list(pd.Series(v2_sf_10.log_meanFit,dtype=float)))

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = fit_v1_sf_10
b = fit_v2_sf_10


plt.title('MeanFit_ADD_Ver1 Vs Ver2_RM_50_Every 10G Sex_10K')
plt.xlabel('Time (generations)')
plt.ylabel('Mean Fitness')
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a,'r', label = 'Ver1', linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'Ver2', linewidth=3.0) # plotting t,b separately 




# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='upper right', frameon=False, prop={'size':23})

# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()
