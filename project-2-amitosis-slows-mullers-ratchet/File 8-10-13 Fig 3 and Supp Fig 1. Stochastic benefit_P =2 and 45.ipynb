# %%
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import seaborn as sns
# %matplotlib inline

# %%
def get_data(file_list):
    total_fit_mean = []
    total_fit_std = []

    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
       
        fit_mean.extend(list(pd.Series(f.meanFit,dtype=float)))
        fit_std.extend(list(pd.Series(f.PopMeanFit_STD,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
        
    return total_fit_mean, total_fit_std

# %%
generation_list = []

for i in range(10002):
    generation_list.append(i)

# %%
import os
os.chdir(r"D:\Dissertation\Figures\Chapter 2\Figure 2.2\Data")

# %% [markdown]
# ## Get the results of Mitosis

# %% [markdown]
# ### N = 10

# %%
m10_file = ['Fit_Mito_N10_P2.csv', 'Fit_Mito_N10_P45.csv']

m10_result = get_data(m10_file)

m10_fit_mean = np.array(m10_result[0])
m10_fit_std = np.array(m10_result[1])

# %%
m10_fit_upper = m10_fit_mean +1.984*m10_fit_std/(100**0.5)
m10_fit_lower = m10_fit_mean -1.984*m10_fit_std/(100**0.5)

m10_fit_mean_log = np.log10(m10_fit_mean)
m10_fit_upper_log = np.log10(m10_fit_upper)
m10_fit_lower_log = np.log10(m10_fit_lower)

# %% [markdown]
# ### N = 100

# %%
m100_file = ['Fit_Mito_N100_P2.csv', 'Fit_Mito_N100_P45.csv']

m100_result = get_data(m100_file)

m100_fit_mean = np.array(m100_result[0])
m100_fit_std = np.array(m100_result[1])

# %%
m100_fit_upper = m100_fit_mean +1.984*m100_fit_std/(100**0.5)
m100_fit_lower = m100_fit_mean -1.984*m100_fit_std/(100**0.5)

m100_fit_mean_log = np.log10(m100_fit_mean)
m100_fit_upper_log = np.log10(m100_fit_upper)
m100_fit_lower_log = np.log10(m100_fit_lower)

# %% [markdown]
# ### N = 1K

# %%
m1k_file = ['Fit_Mito_N1K_P2.csv', 'Fit_Mito_N1K_P45.csv']

m1k_result = get_data(m1k_file)

m1k_fit_mean = np.array(m1k_result[0])
m1k_fit_std = np.array(m1k_result[1])

# %%
m1k_fit_upper = m1k_fit_mean +1.984*m1k_fit_std/(100**0.5)
m1k_fit_lower = m1k_fit_mean -1.984*m1k_fit_std/(100**0.5)

m1k_fit_mean_log = np.log10(m1k_fit_mean)
m1k_fit_upper_log = np.log10(m1k_fit_upper)
m1k_fit_lower_log = np.log10(m1k_fit_lower)

# %% [markdown]
# ### N = 10K

# %%
m10k_file = ['Fit_Mito_N10K_P2.csv', 'Fit_Mito_N10K_P45.csv']

m10k_result = get_data(m10k_file)

m10k_fit_mean = np.array(m10k_result[0])
m10k_fit_std = np.array(m10k_result[1])

# %%
m10k_fit_upper = m10k_fit_mean +1.984*m10k_fit_std/(100**0.5)
m10k_fit_lower = m10k_fit_mean -1.984*m10k_fit_std/(100**0.5)

m10k_fit_mean_log = np.log10(m10k_fit_mean)
m10k_fit_upper_log = np.log10(m10k_fit_upper)
m10k_fit_lower_log = np.log10(m10k_fit_lower)

# %% [markdown]
# ## Get the results of Amitosis

# %% [markdown]
# ### N = 10

# %%
a10_file = ['Fit_Amito_N10_P2.csv', 'Fit_Amito_N10_P45.csv']

# %%
a10_result = get_data(a10_file)

a10_fit_mean = np.array(a10_result[0])
a10_fit_std = np.array(a10_result[1])

# %%
a10_fit_upper = a10_fit_mean +1.984*a10_fit_std/(100**0.5)
a10_fit_lower = a10_fit_mean -1.984*a10_fit_std/(100**0.5)

a10_fit_mean_log = np.log10(a10_fit_mean)
a10_fit_upper_log = np.log10(a10_fit_upper)
a10_fit_lower_log = np.log10(a10_fit_lower)

# %% [markdown]
# ### N = 100

# %%
a100_file = ['Fit_Amito_N100_P2.csv', 'Fit_Amito_N100_P45.csv']

# %%
a100_result = get_data(a100_file)

a100_fit_mean = np.array(a100_result[0])
a100_fit_std = np.array(a100_result[1])

# %%
a100_fit_upper = a100_fit_mean +1.984*a100_fit_std/(100**0.5)
a100_fit_lower = a100_fit_mean -1.984*a100_fit_std/(100**0.5)

a100_fit_mean_log = np.log10(a100_fit_mean)
a100_fit_upper_log = np.log10(a100_fit_upper)
a100_fit_lower_log = np.log10(a100_fit_lower)

# %% [markdown]
# ### N = 1K

# %%
a1k_file = ['Fit_Amito_N1K_P2.csv', 'Fit_Amito_N1K_P45.csv']

# %%
a1k_result = get_data(a1k_file)

a1k_fit_mean = np.array(a1k_result[0])
a1k_fit_std = np.array(a1k_result[1])

# %%
a1k_fit_upper = a1k_fit_mean +1.984*a1k_fit_std/(100**0.5)
a1k_fit_lower = a1k_fit_mean -1.984*a1k_fit_std/(100**0.5)

a1k_fit_mean_log = np.log10(a1k_fit_mean)
a1k_fit_upper_log = np.log10(a1k_fit_upper)
a1k_fit_lower_log = np.log10(a1k_fit_lower)

# %%
def set_up_axes(ax, xmin, xmax, xstep, ymin, ymax, ystep, rnd, xlabel='', ylabel='', part_label=''):
    xtx = np.arange(xmin, xmax + xstep / 2, xstep).round(rnd)
    xrg = xtx.max() - xtx.min()
    ax.set_xlim(xtx.min(), xtx.max())
    ax.set_xticks(xtx)
    ax.set_xticklabels(xtx)
    ytx = np.arange(ymin, ymax + ystep / 2, ystep).round(rnd)
    yrg = ytx.max() - ytx.min()
    ax.set_ylim(ytx.min(), ytx.max())
    ax.set_yticks(ytx)
    ax.set_yticklabels(ytx)
    ax.text(xtx.min() - .016 * xrg, ytx.max() + .15 * yrg, part_label, \
        size=20, fontweight='bold', ha='center', va='center')
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    sns.despine(offset=10)
    sns.set_context("talk")

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 20})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(3)
    ax.spines['bottom'].set_linewidth(3)
#     ax.spines['left'].set_position(('outward', 15))
#     ax.spines['bottom'].set_position(('outward', 15))
#     #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=10, width=3, direction='out', pad=10, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=10, width=3, direction='out', pad=10, colors='black')

# %%
t = generation_list

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(8, 8), dpi =300)

axes = [ax1, ax2, ax3, ax4]

for i in axes:
    publication_figure(i)
    
cols = sns.color_palette()

fig.subplots_adjust()

set_up_axes(ax1, xmin=0, xmax=600, xstep=200, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='', ylabel='Fitness', part_label='(a)')
set_up_axes(ax2, xmin=0, xmax=10000, xstep=2000, ymin= -1, ymax=0, ystep=0.2, rnd=1, xlabel='', ylabel='', part_label='(b)')
set_up_axes(ax3, xmin=0, xmax=600, xstep=200, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='Fitness', part_label='(c)')
set_up_axes(ax4, xmin=0, xmax=10000, xstep=2000, ymin=-1, ymax=0, ystep=0.2, rnd=1, xlabel='Time (generations)', ylabel='', part_label='(d)')

print ax1.get_position()
print ax2.get_position()
print ax3.get_position()
print ax4.get_position()

ax1.set_position([.11, .59, .37, .32])
ax2.set_position([.60, .59, .37, .32])
ax3.set_position([.11, .10, .37, .32])
ax4.set_position([.60, .10, .37, .32])

ax1.plot(t[:601], m10_fit_mean_log[0][:601], clip_on=False, color=cols[0], label="10")
ax1.fill_between(t[:601], m10_fit_lower_log[0][:601], m10_fit_upper_log[0][:601], alpha =0.2, facecolor=cols[0])

ax1.plot(t[:601], m100_fit_mean_log[0][:601], clip_on=False, color=cols[1], label="100")
ax1.fill_between(t[:601], m100_fit_lower_log[0][:601], m100_fit_upper_log[0][:601], alpha =0.2, facecolor=cols[1])

ax1.plot(t[:601], m1k_fit_mean_log[0][:601], clip_on=False, color=cols[2], label="1,000")
ax1.fill_between(t[:601], m1k_fit_lower_log[0][:601], m1k_fit_upper_log[0][:601], alpha =0.2, facecolor=cols[2])

ax1.plot(t[:601], m10k_fit_mean_log[0][:601], clip_on=False, color=cols[3], label="10,000")
ax1.fill_between(t[:601], m10k_fit_lower_log[0][:601], m10k_fit_upper_log[0][:601], alpha =0.2, facecolor=cols[3])

ax1.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax1.set_ylim(-1, 0)
ax1.set_yticklabels(['0.1', '0.2', '0.5', '1'])



ax2.plot(t, m10_fit_mean_log[1], clip_on=False, color=cols[0], label="10")
ax2.fill_between(t, m10_fit_lower_log[1], m10_fit_upper_log[1], alpha =0.2, facecolor=cols[0])

ax2.plot(t, m100_fit_mean_log[1], clip_on=False, color=cols[1], label="100")
ax2.fill_between(t, m100_fit_lower_log[1], m100_fit_upper_log[1], alpha =0.2, facecolor=cols[1])

ax2.plot(t, m1k_fit_mean_log[1], clip_on=False, color=cols[2], label="1,000")
ax2.fill_between(t, m1k_fit_lower_log[1], m1k_fit_upper_log[1], alpha =0.2, facecolor=cols[2])

ax2.plot(t, m10k_fit_mean_log[1], clip_on=False, color=cols[3], label="10,000")
ax2.fill_between(t, m10k_fit_lower_log[1], m10k_fit_upper_log[1], alpha =0.2, facecolor=cols[3])

ax2.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax2.set_ylim(-1, 0)
ax2.set_yticklabels(['0.1', '0.2', '0.5', '1'])


ax3.plot(t[:601], a10_fit_mean_log[0][:601], clip_on=False, color=cols[0], label="10")
ax3.fill_between(t[:601], a10_fit_lower_log[0][:601], a10_fit_upper_log[0][:601], alpha =0.2, facecolor=cols[0])

ax3.plot(t[:601], a100_fit_mean_log[0][:601], clip_on=False, color=cols[1], label="100")
ax3.fill_between(t[:601], a100_fit_lower_log[0][:601], a100_fit_upper_log[0][:601], alpha =0.2, facecolor=cols[1])

ax3.plot(t[:601], a1k_fit_mean_log[0][:601], clip_on=False, color=cols[2], label="1,000")
ax3.fill_between(t[:601], a1k_fit_lower_log[0][:601], a1k_fit_upper_log[0][:601], alpha =0.2, facecolor=cols[2])

ax3.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax3.set_ylim(-1, 0)
ax3.set_yticklabels(['0.1', '0.2', '0.5', '1'])



ax4.plot(t, a10_fit_mean_log[1], clip_on=False, color=cols[0], label="10")
ax4.fill_between(t, a10_fit_lower_log[1], a10_fit_upper_log[1], alpha =0.2, facecolor=cols[0])

ax4.plot(t, a100_fit_mean_log[1], clip_on=False, color=cols[1], label="100")
ax4.fill_between(t, a100_fit_lower_log[1], a100_fit_upper_log[1], alpha =0.2, facecolor=cols[1])

ax4.plot(t, a1k_fit_mean_log[1], clip_on=False, color=cols[2], label="1,000")
ax4.fill_between(t, a1k_fit_lower_log[1], a1k_fit_upper_log[1], alpha =0.2, facecolor=cols[2])


ax4.set_yticks([np.log10(0.1), np.log10(0.2), np.log10(0.5), np.log10(1)])
ax4.set_ylim(-1, 0)
ax4.set_yticklabels(['0.1', '0.2', '0.5', '1'])


# ax1.legend(title=r"$\mathit{N}$", fontsize = 10)

leg = ax2.legend(fontsize = 12, bbox_to_anchor=(.408, .555), frameon = False)
leg.set_title(r'$N$', prop = {'size': 12})

ax1.text(300, 0.14, r'$n = 2$', ha='center', va='center', size=16)
ax2.text(5000, 0.14, r'$n = 45$', ha='center', va='center', size=16)
ax2.text(11600, -0.5, 'Mitosis', ha='center', va='center', size=16, rotation=-90)
ax4.text(11600, -0.5, 'Amitosis', ha='center', va='center', size=16, rotation=-90)


# plt.savefig('test.pdf')
# ax1
# Out:
# Bbox(x0=0.125, y0=0.536818181818, x1=0.477272727273, y1=0.88)
# Bbox(x0=0.547727272727, y0=0.536818181818, x1=0.9, y1=0.88)
# Bbox(x0=0.125, y0=0.125, x1=0.477272727273, y1=0.468181818182)
# Bbox(x0=0.547727272727, y0=0.125, x1=0.9, y1=0.468181818182)

# %%
def publication_figure_2(axis):
    plt.rcParams.update({'font.size': 36})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(6)
    ax.spines['bottom'].set_linewidth(6)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure_2(ax)
# ax.scatter(0,0)

cols = sns.color_palette()

ax.set_xlim(0,600)
ax.set_ylim(0.1, 1)

ax.set_yscale('log')

t = generation_list[:601]

g1 = m10_fit_mean[0][:601]
error_g1 = list(1.984* np.array(m10_fit_std[0][:601])/((100)**0.5))

g2 = m100_fit_mean[0][:601]
error_g2 = list(1.984* np.array(m100_fit_std[0][:601])/((100)**0.5))


g3 = m1k_fit_mean[0][:601]
error_g3 = list(1.984* np.array(m1k_fit_std[0][:601])/((100)**0.5))

g4 = m10k_fit_mean[0][:601]
error_g4 = list(1.984* np.array(m10k_fit_std[0][:601])/((100)**0.5))


ax.set_xlabel(r'Time ($\times 10^2$ generations)', fontsize =45, color = 'w')
ax.set_ylabel('Fitness', fontsize =45)



ax.plot(t,g1,color = cols[0], label = '10',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.2, facecolor=cols[0])

ax.plot(t,g2,color = cols[1], label = r"$10^2$", linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g2)- np.array(error_g1), np.array(g2)+ np.array(error_g2), alpha =0.2, facecolor=cols[1])

ax.plot(t,g3,color = cols[2], label = r"$10^3$",  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g3)- np.array(error_g3), np.array(g3)+ np.array(error_g3), alpha =0.2, facecolor=cols[2])

ax.plot(t,g4,color = cols[3], label = r"$10^4$", linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g4)- np.array(error_g4), np.array(g4)+ np.array(error_g4), alpha =0.2, facecolor=cols[3])


# plt.legend(loc='lower left', frameon=False, prop={'size':30})

ax.set_yticks([0.1, 0.2, 0.5, 1]) # choose which x locations to have ticks
ax.set_yticklabels([0.1, 0.2, 0.5, 1]) # set the labels to display at those ticks

ax.set_xticks([0, 200, 400, 600]) # choose which x locations to have ticks
ax.set_xticklabels([0, 2, 4, 6]) # set the labels to display at those ticks

ax.minorticks_off()


# plt.legend(loc='upper left', frameon=False, prop={'size':27})


plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/100), ',')))

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure_2(ax)
# ax.scatter(0,0)

cols = sns.color_palette()

ax.set_xlim(0,10000)
ax.set_ylim(0.1, 1)

ax.set_yscale('log')

t = generation_list

g1 = m10_fit_mean[1]
error_g1 = list(1.984* np.array(m10_fit_std[1])/((100)**0.5))

g2 = m100_fit_mean[1]
error_g2 = list(1.984* np.array(m100_fit_std[1])/((100)**0.5))


g3 = m1k_fit_mean[1]
error_g3 = list(1.984* np.array(m1k_fit_std[1])/((100)**0.5))

g4 = m10k_fit_mean[1]
error_g4 = list(1.984* np.array(m10k_fit_std[1])/((100)**0.5))


ax.set_xlabel(r'Time ($\times 10^3$ generations)', fontsize =45, color = 'w')
ax.set_ylabel('Fitness', fontsize =45, color = 'w')



ax.plot(t,g1,color = cols[0], label = '10',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.2, facecolor=cols[0])

ax.plot(t,g2,color = cols[1], label = r"$10^2$", linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g2)- np.array(error_g1), np.array(g2)+ np.array(error_g2), alpha =0.2, facecolor=cols[1])

ax.plot(t,g3,color = cols[2], label = r"$10^3$",  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g3)- np.array(error_g3), np.array(g3)+ np.array(error_g3), alpha =0.2, facecolor=cols[2])

ax.plot(t,g4,color = cols[3], label = r"$10^4$", linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g4)- np.array(error_g4), np.array(g4)+ np.array(error_g4), alpha =0.2, facecolor=cols[3])


# plt.legend(loc='lower left', frameon=False, prop={'size':30})

ax.set_yticks([0.1, 0.2, 0.5, 1]) # choose which x locations to have ticks
ax.set_yticklabels([0.1, 0.2, 0.5, 1]) # set the labels to display at those ticks

ax.set_xticks([0, 2000, 4000, 6000, 8000, 10000]) # choose which x locations to have ticks
ax.set_xticklabels([0, 2, 4, 6, 8, 10]) # set the labels to display at those ticks

ax.minorticks_off()

leg1 = ax.legend(fontsize = 30, bbox_to_anchor=(0.25, 0.4), frameon=False)
leg1.set_title(r'$N$', prop = {'size': 30})


plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/100), ',')))

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure_2(ax)
# ax.scatter(0,0)

cols = sns.color_palette()

ax.set_xlim(0,600)
ax.set_ylim(0.1, 1)

ax.set_yscale('log')

t = generation_list[:601]

g1 = a10_fit_mean[0][:601]
error_g1 = list(1.984* np.array(a10_fit_std[0][:601])/((100)**0.5))

g2 = a100_fit_mean[0][:601]
error_g2 = list(1.984* np.array(a100_fit_std[0][:601])/((100)**0.5))


g3 = a1k_fit_mean[0][:601]
error_g3 = list(1.984* np.array(a1k_fit_std[0][:601])/((100)**0.5))

# g4 = m10k_fit_mean[0][:601]
# error_g4 = list(1.984* np.array(m10k_fit_std[0][:601])/((100)**0.5))


ax.set_xlabel(r'Time ($\times 10^2$ generations)', fontsize =45)
ax.set_ylabel('Fitness', fontsize =45)



ax.plot(t,g1,color = cols[0], label = '10',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.2, facecolor=cols[0])

ax.plot(t,g2,color = cols[1], label = r"$10^2$", linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g2)- np.array(error_g1), np.array(g2)+ np.array(error_g2), alpha =0.2, facecolor=cols[1])

ax.plot(t,g3,color = cols[2], label = r"$10^3$",  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g3)- np.array(error_g3), np.array(g3)+ np.array(error_g3), alpha =0.2, facecolor=cols[2])

# ax.plot(t,g4,color = cols[3], label = r"$10^4$", linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(g4)- np.array(error_g4), np.array(g4)+ np.array(error_g4), alpha =0.2, facecolor=cols[3])


# plt.legend(loc='lower left', frameon=False, prop={'size':30})

ax.set_yticks([0.1, 0.2, 0.5, 1]) # choose which x locations to have ticks
ax.set_yticklabels([0.1, 0.2, 0.5, 1]) # set the labels to display at those ticks

ax.set_xticks([0, 200, 400, 600]) # choose which x locations to have ticks
ax.set_xticklabels([0, 2, 4, 6]) # set the labels to display at those ticks

ax.minorticks_off()


# plt.legend(loc='upper left', frameon=False, prop={'size':27})


plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/100), ',')))

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure_2(ax)
# ax.scatter(0,0)

cols = sns.color_palette()

ax.set_xlim(0,10000)
ax.set_ylim(0.1, 1)

ax.set_yscale('log')

t = generation_list

g1 = a10_fit_mean[1]
error_g1 = list(1.984* np.array(a10_fit_std[1])/((100)**0.5))

g2 = a100_fit_mean[1]
error_g2 = list(1.984* np.array(a100_fit_std[1])/((100)**0.5))


g3 = a1k_fit_mean[1]
error_g3 = list(1.984* np.array(a1k_fit_std[1])/((100)**0.5))

# g4 = m10k_fit_mean[0][:601]
# error_g4 = list(1.984* np.array(m10k_fit_std[0][:601])/((100)**0.5))


ax.set_xlabel(r'Time ($\times 10^3$ generations)', fontsize =45)
ax.set_ylabel('Fitness', fontsize =45, color = 'w')



ax.plot(t,g1,color = cols[0], label = '10',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.2, facecolor=cols[0])

ax.plot(t,g2,color = cols[1], label = r"$10^2$", linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g2)- np.array(error_g1), np.array(g2)+ np.array(error_g2), alpha =0.2, facecolor=cols[1])

ax.plot(t,g3,color = cols[2], label = r"$10^3$",  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g3)- np.array(error_g3), np.array(g3)+ np.array(error_g3), alpha =0.2, facecolor=cols[2])

# ax.plot(t,g4,color = cols[3], label = r"$10^4$", linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(g4)- np.array(error_g4), np.array(g4)+ np.array(error_g4), alpha =0.2, facecolor=cols[3])


# plt.legend(loc='lower left', frameon=False, prop={'size':30})

ax.set_yticks([0.1, 0.2, 0.5, 1]) # choose which x locations to have ticks
ax.set_yticklabels([0.1, 0.2, 0.5, 1]) # set the labels to display at those ticks

ax.set_xticks([0, 2000, 4000, 6000, 8000, 10000]) # choose which x locations to have ticks
ax.set_xticklabels([0, 2, 4, 6, 8, 10]) # set the labels to display at those ticks

ax.minorticks_off()


# plt.legend(loc='upper left', frameon=False, prop={'size':27})


plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/100), ',')))
