# %%
import numpy as np
import scipy.spatial as spa
import random
import pandas as pd 
from scipy.linalg import hadamard
import itertools as it 
import scipy.stats as stat
import scipy.integrate as integrate
import math
import argparse
import os

# %%
generation_list = []

for i in range(10001):
    generation_list.append(10*i)
    
print(len(generation_list))
# Out:
# 10001

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\1215_Monitor Mutation Dynamics_Pop and Ind level_Add Multiplicative Version to Calculate Fitness and Check Equilibrium\Data\Evolve for 100K")

# %%
amito_5 = pd.read_csv('Fitness_WF_Amito_5_MUL_E.csv',dtype=str)
fitness_5 = []
fitness_5.extend(list(pd.Series(amito_5.meanFit,dtype=float)))

log_mean_fit_5 = []
log_mean_fit_5.extend(list(pd.Series(amito_5.log_meanFit,dtype=float)))

mean_log_fit_5 = []
mean_log_fit_5.extend(list(pd.Series(amito_5.mean_logFit,dtype=float)))

# %%
amito_10 = pd.read_csv('Fitness_WF_Amito_10_MUL_E.csv',dtype=str)
fitness_10 = []
fitness_10.extend(list(pd.Series(amito_10.meanFit,dtype=float)))

log_mean_fit_10 = []
log_mean_fit_10.extend(list(pd.Series(amito_10.log_meanFit,dtype=float)))

mean_log_fit_10 = []
mean_log_fit_10.extend(list(pd.Series(amito_10.mean_logFit,dtype=float)))

# %%
amito_20 = pd.read_csv('Fitness_WF_Amito_20_MUL_E.csv',dtype=str)
fitness_20 = []
fitness_20.extend(list(pd.Series(amito_20.meanFit,dtype=float)))

log_mean_fit_20 = []
log_mean_fit_20.extend(list(pd.Series(amito_20.log_meanFit,dtype=float)))

mean_log_fit_20 = []
mean_log_fit_20.extend(list(pd.Series(amito_20.mean_logFit,dtype=float)))

# %%
amito_50 = pd.read_csv('Fitness_WF_Amito_50_MUL_E.csv',dtype=str)
fitness_50 = []
fitness_50.extend(list(pd.Series(amito_50.meanFit,dtype=float)))

log_mean_fit_50 = []
log_mean_fit_50.extend(list(pd.Series(amito_50.log_meanFit,dtype=float)))

mean_log_fit_50 = []
mean_log_fit_50.extend(list(pd.Series(amito_50.mean_logFit,dtype=float)))

# %%
amito_100 = pd.read_csv('Fitness_WF_Amito_100_MUL_E_100K.csv',dtype=str)
fitness_100 = []
fitness_100.extend(list(pd.Series(amito_100.meanFit,dtype=float)))

log_mean_fit_100 = []
log_mean_fit_100.extend(list(pd.Series(amito_100.log_meanFit,dtype=float)))

mean_log_fit_100 = []
mean_log_fit_100.extend(list(pd.Series(amito_100.mean_logFit,dtype=float)))

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\1219_Monitor Mutation Dynamics_Pop and Ind level_MUL Version_Mitosis with N =5, 10, 20, 50 and 100 for 100K G\Data")

# %%
mito_5 = pd.read_csv('Fitness_WF_Mito_5_MUL_E.csv',dtype=str)
m_fitness_5 = []
m_fitness_5.extend(list(pd.Series(mito_5.meanFit,dtype=float)))

m_log_mean_fit_5 = []
m_log_mean_fit_5.extend(list(pd.Series(mito_5.log_meanFit,dtype=float)))

m_mean_log_fit_5 = []
m_mean_log_fit_5.extend(list(pd.Series(mito_5.mean_logFit,dtype=float)))

# %%
mito_10 = pd.read_csv('Fitness_WF_Mito_10_MUL_E.csv',dtype=str)
m_fitness_10 = []
m_fitness_10.extend(list(pd.Series(mito_10.meanFit,dtype=float)))

m_log_mean_fit_10 = []
m_log_mean_fit_10.extend(list(pd.Series(mito_10.log_meanFit,dtype=float)))

m_mean_log_fit_10 = []
m_mean_log_fit_10.extend(list(pd.Series(mito_10.mean_logFit,dtype=float)))

# %%
mito_20 = pd.read_csv('Fitness_WF_Mito_20_MUL_E.csv',dtype=str)
m_fitness_20 = []
m_fitness_20.extend(list(pd.Series(mito_20.meanFit,dtype=float)))

m_log_mean_fit_20 = []
m_log_mean_fit_20.extend(list(pd.Series(mito_20.log_meanFit,dtype=float)))

m_mean_log_fit_20 = []
m_mean_log_fit_20.extend(list(pd.Series(mito_20.mean_logFit,dtype=float)))

# %%
mito_50 = pd.read_csv('Fitness_WF_Mito_50_MUL_E.csv',dtype=str)
m_fitness_50 = []
m_fitness_50.extend(list(pd.Series(mito_50.meanFit,dtype=float)))

m_log_mean_fit_50 = []
m_log_mean_fit_50.extend(list(pd.Series(mito_50.log_meanFit,dtype=float)))

m_mean_log_fit_50 = []
m_mean_log_fit_50.extend(list(pd.Series(mito_50.mean_logFit,dtype=float)))

# %%
mito_100 = pd.read_csv('Fitness_WF_Mito_100_MUL_E.csv',dtype=str)
m_fitness_100 = []
m_fitness_100.extend(list(pd.Series(mito_100.meanFit,dtype=float)))

m_log_mean_fit_100 = []
m_log_mean_fit_100.extend(list(pd.Series(mito_100.log_meanFit,dtype=float)))

m_mean_log_fit_100 = []
m_mean_log_fit_100.extend(list(pd.Series(mito_100.mean_logFit,dtype=float)))

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = fitness_10

c=  log_mean_fit_20
d = log_mean_fit_50
e = log_mean_fit_100

plt.title('Amitosis')
plt.xlabel('Time (generations)')
plt.ylabel('log Mean Fitness')
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(y =-15, linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a,'r', label = 'N =5', linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'N =10', linewidth=3.0) # plotting t,c separately 
plt.plot(t,c,'g', label = 'N =20', linewidth=3.0)
plt.plot(t,d,'y', label = 'N =50', linewidth=3.0)
plt.plot(t,e,'m', label = 'N =100', linewidth=3.0)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='lower left', frameon=False, prop={'size':23})

# plt.savefig('1', dpi=300, bbox_inches='tight')
plt.ylim(-15, 0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-976658853644> in <module>()
#      12 c=  log_mean_fit_20
#      13 d = log_mean_fit_50
# ---> 14 e = log_mean_fit_100
#      15
#      16 plt.title('Amitosis')
#
# NameError: name 'log_mean_fit_100' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = log_mean_fit_10
c=  log_mean_fit_20
d = log_mean_fit_50
e = log_mean_fit_100

plt.title('Amitosis')
plt.xlabel('Time (generations)')
plt.ylabel('log Mean Fitness')
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(y =-15, linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a,'r', label = 'N =5', linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'N =10', linewidth=3.0) # plotting t,c separately 
plt.plot(t,c,'g', label = 'N =20', linewidth=3.0)
plt.plot(t,d,'y', label = 'N =50', linewidth=3.0)
plt.plot(t,e,'m', label = 'N =100', linewidth=3.0)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='lower left', frameon=False, prop={'size':23})

# plt.savefig('1', dpi=300, bbox_inches='tight')
plt.ylim(-15, 0)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a = m_log_mean_fit_5
b = m_log_mean_fit_10
c=  m_log_mean_fit_20
d = m_log_mean_fit_50
e = m_log_mean_fit_100

plt.title('Mitosis')
plt.xlabel('Time (generations)')
plt.ylabel('log Mean Fitness')
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(y =-12, linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a,'r', label = 'N =5', linewidth=3.0) # plotting t,a separately 
plt.plot(t,b,'b', label = 'N =10', linewidth=3.0) # plotting t,c separately 
plt.plot(t,c,'g', label = 'N =20', linewidth=3.0)
plt.plot(t,d,'y', label = 'N =50', linewidth=3.0)
plt.plot(t,e,'m', label = 'N =100', linewidth=3.0)


# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='lower left', frameon=False, prop={'size':23})

# plt.savefig('1', dpi=300, bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-493677700bad> in <module>()
#       9 t = generation_list
#      10 a = m_log_mean_fit_5
# ---> 11 b = m_log_mean_fit_10
#      12 c=  m_log_mean_fit_20
#      13 d = m_log_mean_fit_50
#
# NameError: name 'm_log_mean_fit_10' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a1 = log_mean_fit_5
a2 = m_log_mean_fit_5
# b1 = log_mean_fit_10
# b2 = m_log_mean_fit_10
c1=  log_mean_fit_20
c2=  m_log_mean_fit_20
d1 = log_mean_fit_50
d2 = m_log_mean_fit_50
# e1 = log_mean_fit_100
# e2 = m_log_mean_fit_100

plt.title('Amitosis vs Mitosis')
plt.xlabel('Time (generations)')
plt.ylabel('log Mean Fitness')
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(y =-16, linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a1,'r', label = 'Amito_N =5', linewidth=3.0) # plotting t,a separately 
plt.plot(t,a2,'r', label = 'Mito_N =5', ls = '--', linewidth=3.0) # plotting t,a separately
# plt.plot(t,b1,'b', label = 'Amito_N =10', linewidth=3.0) # plotting t,c separately 
# plt.plot(t,b2,'b', label = 'Mito_N =10', ls = '--', linewidth=3.0) # plotting t,c separately 
plt.plot(t,c1,'g', label = 'Amito_N =20', linewidth=3.0)
plt.plot(t,c2,'g', label = 'Mito_N =20', ls = '--',linewidth=3.0)
plt.plot(t,d1,'y', label = 'Amito_N =50', linewidth=3.0)
plt.plot(t,d2,'y', label = 'Mito_N =50', ls = '--',linewidth=3.0)
# plt.plot(t,e1,'m', label = 'Amito_N =100', linewidth=3.0)
# plt.plot(t,e2,'m', label = 'Mito_N =100', ls = '--',linewidth=3.0)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='lower left', frameon=False, prop={'size':23})

# plt.savefig('1', dpi=300, bbox_inches='tight')
plt.ylim(-16,0)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a1 = log_mean_fit_5
a2 = m_log_mean_fit_5
# b1 = log_mean_fit_10
# b2 = m_log_mean_fit_10
c1=  log_mean_fit_20
c2=  m_log_mean_fit_20
d1 = log_mean_fit_50
d2 = m_log_mean_fit_50


plt.title('Amitosis vs Mitosis', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('log Mean Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})



# plt.show()
ax = plt.subplot(111)
ax.axhline(y =-15, linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

# plt.plot(t,a1,'r', label = 'Amito_N =5', linewidth=3.0) # plotting t,a separately 
# plt.plot(t,a2,'r', label = 'Mito_N =5', ls = '--', linewidth=3.0) # plotting t,a separately
# plt.plot(t,b1,'b', label = 'Amito_N =10', linewidth=3.0) # plotting t,c separately 
# plt.plot(t,b2,'b', label = 'Mito_N =10', ls = '--', linewidth=3.0) # plotting t,c separately 
plt.plot(t,c1,'r', label = 'Amito_20', linewidth=3.0)
plt.plot(t,c2,'r', label = 'Mito_20', ls = '--',linewidth=3.0)
plt.plot(t,d1,'b', label = 'Amito_50', linewidth=3.0)
plt.plot(t,d2,'b', label = 'Mito_50', ls = '--',linewidth=3.0)
# plt.plot(t,c1,'r', linewidth=3.0)
# plt.plot(t,c2,'r', ls = '--',linewidth=3.0)
# plt.plot(t,d1,'b', linewidth=3.0)
# plt.plot(t,d2,'b', ls = '--',linewidth=3.0)

plt.tick_params(axis='both', which='major', labelsize=25)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)


plt.legend(loc='lower left', frameon=False, prop={'size':30})


# plt.savefig('1', dpi=300, bbox_inches='tight')
plt.xlim(0, 100005)
plt.ylim(-15,0)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a1 = log_meanfit_5
a2 = m_log_mean_fit_5
# b1 = log_mean_fit_10
# b2 = m_log_mean_fit_10
c1=  log_mean_fit_20
c2=  m_log_mean_fit_20
d1 = log_mean_fit_50
d2 = m_log_mean_fit_50


plt.title('Amitosis vs Mitosis', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('log Mean Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(y =-15, linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

# plt.plot(t,a1,'r', label = 'Amito_N =5', linewidth=3.0) # plotting t,a separately 
# plt.plot(t,a2,'r', label = 'Mito_N =5', ls = '--', linewidth=3.0) # plotting t,a separately
# plt.plot(t,b1,'b', label = 'Amito_N =10', linewidth=3.0) # plotting t,c separately 
# plt.plot(t,b2,'b', label = 'Mito_N =10', ls = '--', linewidth=3.0) # plotting t,c separately 
plt.plot(t,c1,'r', label = 'Amito_20', linewidth=3.0)
plt.plot(t,c2,'r', label = 'Mito_20', ls = '--',linewidth=3.0)
plt.plot(t,d1,'b', label = 'Amito_50', linewidth=3.0)
plt.plot(t,d2,'b', label = 'Mito_50', ls = '--',linewidth=3.0)
# plt.plot(t,c1,'r', linewidth=3.0)
# plt.plot(t,c2,'r', ls = '--',linewidth=3.0)
# plt.plot(t,d1,'b', linewidth=3.0)
# plt.plot(t,d2,'b', ls = '--',linewidth=3.0)

plt.tick_params(axis='both', which='major', labelsize=25)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)


plt.legend(loc='lower left', frameon=False, prop={'size':30})


# plt.savefig('1', dpi=300, bbox_inches='tight')
plt.xlim(0, 100005)
plt.ylim(-15,0)
plt.show()

# %%
len(generation_list)
# Out:
# 10001

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list[:1001]
a1 = log_mean_fit_5[:1001]
a2 = m_log_mean_fit_5[:1001]
b1 = log_mean_fit_10[:1001]
b2 = m_log_mean_fit_10[:1001]
c1=  log_mean_fit_20[:1001]
c2=  m_log_mean_fit_20[:1001]
d1 = log_mean_fit_50[:1001]
d2 = m_log_mean_fit_50[:1001]


plt.title('Amitosis vs Mitosis', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('log Mean Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(y =-16, linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

plt.plot(t,a1,'r', label = 'Amito_N =5', linewidth=3.0) # plotting t,a separately 
plt.plot(t,a2,'r', label = 'Mito_N =5', ls = '--', linewidth=3.0) # plotting t,a separately
plt.plot(t,b1,'b', label = 'Amito_N =10', linewidth=3.0) # plotting t,c separately 
plt.plot(t,b2,'b', label = 'Mito_N =10', ls = '--', linewidth=3.0) # plotting t,c separately 
plt.plot(t,c1,'g', label = 'Amito_N =20', linewidth=3.0)
plt.plot(t,c2,'g', label = 'Mito_N =20', ls = '--',linewidth=3.0)
plt.plot(t,d1,'y', label = 'Amito_N =50', linewidth=3.0)
plt.plot(t,d2,'y', label = 'Mito_N =50', ls = '--',linewidth=3.0)

plt.tick_params(axis='both', which='major', labelsize=25)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)

# plt.legend(loc='upper right', frameon=False)
plt.legend(loc='lower left', frameon=False, prop={'size':20})

# plt.savefig('1', dpi=300, bbox_inches='tight')
plt.xlim(0, 10005)
plt.ylim(-16,0)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pylab

# %matplotlib inline

plt.figure(figsize=(16,12))

t = generation_list
a1 = log_mean_fit_5
a2 = m_log_mean_fit_5
# b1 = log_mean_fit_10
# b2 = m_log_mean_fit_10
c1=  log_mean_fit_20
c2=  m_log_mean_fit_20
d1 = log_mean_fit_50
d2 = m_log_mean_fit_50


plt.title('Amitosis vs Mitosis', fontsize =30)
plt.xlabel('Time (generations)', fontsize =30)
plt.ylabel('log Mean Fitness', fontsize =30)
# plt.legend(['N =1', 'N =10', 'N =100', 'N =1000' ])
plt.rcParams.update({'font.size': 30})


# plt.show()
ax = plt.subplot(111)
ax.axhline(y =-12, linewidth=8, color ='black')       
ax.axvline(linewidth=8, color = 'black')        

# plt.plot(t,a1,'r', label = 'Amito_N =5', linewidth=3.0) # plotting t,a separately 
# plt.plot(t,a2,'r', label = 'Mito_N =5', ls = '--', linewidth=3.0) # plotting t,a separately
# plt.plot(t,b1,'b', label = 'Amito_N =10', linewidth=3.0) # plotting t,c separately 
# plt.plot(t,b2,'b', label = 'Mito_N =10', ls = '--', linewidth=3.0) # plotting t,c separately 

plt.plot(t,d1,'b', label = 'Amitosis', linewidth=3.0)
plt.plot(t,d2,'b', label = 'Mitosis', ls = '--',linewidth=3.0)
# plt.plot(t,c1,'r', linewidth=3.0)
# plt.plot(t,c2,'r', ls = '--',linewidth=3.0)
# plt.plot(t,d1,'b', linewidth=3.0)
# plt.plot(t,d2,'b', ls = '--',linewidth=3.0)

plt.tick_params(axis='both', which='major', labelsize=25)

# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.xaxis.set_tick_params(width=5, length =7)
ax.yaxis.set_tick_params(width=5, length =7)


plt.legend(loc='lower left', frameon=False, prop={'size':30})


# plt.savefig('1', dpi=300, bbox_inches='tight')
plt.xlim(0, 100005)
plt.ylim(-12,0)
plt.show()
