# %%
'''

Under no pleiotropy and fixed optimum,  We compared the performance of amitosis, mitosis and sex (including RM, RME100, SF and 
SFE100) in adaptation with different ploidies. 

Setting: no pleyotropy, # of loci and dimension =10, genomic mutation rate =0.01, population size N = 500, STD =0.05.
Fixed optimum.

Here the code has been revised to include random.seed().

'''
# Out:
# '\n\nUnder no pleiotropy and fixed optimum,  We compared the performance of amitosis, mitosis and sex (including RM, RME100, SF and \nSFE100) in adaptation with different ploidies. \n\nSetting: no pleyotropy, # of loci and dimension =10, genomic mutation rate =0.01, population size N = 500, STD =0.05.\nFixed optimum.\n\nHere the code has been revised to include random.seed().\n\n'

# %%
from __future__ import division
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import pickle
# %matplotlib inline

# %%
generation_list = []

for i in range(2002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 2002

# %%
def get_data1(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.mFit_Mean,dtype=float)))
        fit_std.extend(list(pd.Series(f.mFit_Std,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.varFit_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.varFit_Std,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %%
def get_data2(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.meanFit,dtype=float)))
        fit_std.extend(list(pd.Series(f.PopMeanFit_STD,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.PopVar_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.PopVar_STD,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %%
def read_file(data):
    with open(data, 'rb') as f:
        x = pickle.load(f)
        
    return x

# %% [markdown]
# ## N =500_Initial fitness =0.5_Dim = 10_Different Ploidy

# %% [markdown]
# ### Fitness dynamics comparison

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\1.3. No Pley_Diff Ploidy_GMU = 0.01\Amito")

# %%
amito = ['Cor_NoPley_GMU001_Dim10_P1_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P2_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P4_Amito_Fit_N500_Fit05_SM005.csv', \
         'Cor_NoPley_GMU001_Dim10_P8_Amito_Fit_N500_Fit05_SM005.csv',  'Cor_NoPley_GMU001_Dim10_P16_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P32_Amito_Fit_N500_Fit05_SM005.csv', \
        'Cor_NoPley_GMU001_Dim10_P45_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P64_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P128_Amito_Fit_N500_Fit05_SM005.csv']

# %%
m = get_data1(amito)

amito_fit_mean =m[0]
amito_fit_std = m[1]
amito_var_mean =m[2]
amito_var_std = m[3]

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\1.3. No Pley_Diff Ploidy_GMU = 0.01\Mito")

# %%
mito = ['Cor_NoPley_GMU001_Dim10_P1_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P2_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P4_Mito_Fit_N500_Fit05_SM005.csv', \
         'Cor_NoPley_GMU001_Dim10_P8_Mito_Fit_N500_Fit05_SM005.csv',  'Cor_NoPley_GMU001_Dim10_P16_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P32_Mito_Fit_N500_Fit05_SM005.csv', \
        'Cor_NoPley_GMU001_Dim10_P45_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P64_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P128_Mito_Fit_N500_Fit05_SM005.csv']

# %%
s = get_data1(mito)

mito_fit_mean =s[0]
mito_fit_std = s[1]
mito_var_mean =s[2]
mito_var_std = s[3]

# %% [markdown]
# #### RM

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190331_Test of FGM_7_Trial of Incorporating Sex\Data\1. NP_FO_D =L =10\RM")

# %%
rm = ['FO_NP_GMU001_Dim10_P1_RM_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P2_RM_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P4_RM_Fit_N500_Fit05_SM005_Cor.csv', \
         'FO_NP_GMU001_Dim10_P8_RM_Fit_N500_Fit05_SM005_Cor.csv',  'FO_NP_GMU001_Dim10_P16_RM_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P32_RM_Fit_N500_Fit05_SM005_Cor.csv', \
        'FO_NP_GMU001_Dim10_P45_RM_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P64_RM_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P128_RM_Fit_N500_Fit05_SM005_Cor.csv']

# %%
n = get_data1(rm)

rm_fit_mean =n[0]
rm_fit_std = n[1]
rm_var_mean =n[2]
rm_var_std = n[3]

# %% [markdown]
# #### RME100

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190331_Test of FGM_7_Trial of Incorporating Sex\Data\1. NP_FO_D =L =10\RME100")

# %%
rme = ['FO_NP_GMU001_Dim10_P1_RME100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P2_RME100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P4_RME100_Fit_N500_Fit05_SM005_Cor.csv', \
         'FO_NP_GMU001_Dim10_P8_RME100_Fit_N500_Fit05_SM005_Cor.csv',  'FO_NP_GMU001_Dim10_P16_RME100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P32_RME100_Fit_N500_Fit05_SM005_Cor.csv', \
        'FO_NP_GMU001_Dim10_P45_RME100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P64_RME100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P128_RME100_Fit_N500_Fit05_SM005_Cor.csv']

# %%
n2 = get_data1(rme)

rme_fit_mean =n2[0]
rme_fit_std = n2[1]
rme_var_mean =n2[2]
rme_var_std = n2[3]

# %% [markdown]
# #### SF

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190331_Test of FGM_7_Trial of Incorporating Sex\Data\1. NP_FO_D =L =10\SF")

# %%
sf = ['FO_NP_GMU001_Dim10_P1_SF_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P2_SF_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P4_SF_Fit_N500_Fit05_SM005_Cor.csv', \
         'FO_NP_GMU001_Dim10_P8_SF_Fit_N500_Fit05_SM005_Cor.csv',  'FO_NP_GMU001_Dim10_P16_SF_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P32_SF_Fit_N500_Fit05_SM005_Cor.csv', \
        'FO_NP_GMU001_Dim10_P45_SF_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P64_SF_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P128_SF_Fit_N500_Fit05_SM005_Cor.csv']

# %%
t = get_data1(sf)

sf_fit_mean =t[0]
sf_fit_std = t[1]
sf_var_mean =t[2]
sf_var_std = t[3]

# %% [markdown]
# #### SFE100

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190331_Test of FGM_7_Trial of Incorporating Sex\Data\1. NP_FO_D =L =10\SFE100")

# %%
sfe = ['FO_NP_GMU001_Dim10_P1_SFE100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P2_SFE100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P4_SFE100_Fit_N500_Fit05_SM005_Cor.csv', \
         'FO_NP_GMU001_Dim10_P8_SFE100_Fit_N500_Fit05_SM005_Cor.csv',  'FO_NP_GMU001_Dim10_P16_SFE100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P32_SFE100_Fit_N500_Fit05_SM005_Cor.csv', \
        'FO_NP_GMU001_Dim10_P45_SFE100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P64_SFE100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P128_SFE100_Fit_N500_Fit05_SM005_Cor.csv']

# %%
t2 = get_data1(sfe)

sfe_fit_mean =t2[0]
sfe_fit_std = t2[1]
sfe_var_mean =t2[2]
sfe_var_std = t2[3]

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 30})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(6)
    ax.spines['bottom'].set_linewidth(6)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')

# %%
p_list = [1,2,4,8,16,32,45,64,128]    
    
for i in range(4,5):    
    fig = plt.figure(figsize=(16, 12))
    ax = fig.add_subplot(111)
    publication_figure(ax)

    ax.set_xlim(0,2000)

    t = generation_list

    a1 = amito_fit_mean[i]
    error_a1 = list(1.98* np.array(amito_fit_std[i])/((100)**0.5))

    a2 = mito_fit_mean[i]
    error_a2 = list(1.98* np.array(mito_fit_std[i])/((100)**0.5))

    a3 = rm_fit_mean[i]
    error_a3 = list(1.98* np.array(rm_fit_std[i])/((100)**0.5))

    a4 = rme_fit_mean[i]
    error_a4 = list(1.98* np.array(rme_fit_std[i])/((100)**0.5))


    a5 = sf_fit_mean[i]
    error_a5 = list(1.98* np.array(sf_fit_std[i])/((100)**0.5))

    a6 = sfe_fit_mean[i]
    error_a6 = list(1.98* np.array(sfe_fit_std[i])/((100)**0.5))

    ax.set_xlabel('Time (generations)', fontsize =40)
    ax.set_ylabel('Mean Fitness', fontsize =40)

    print 'Ploidy', p_list[i]

    ax.plot(t,a1,'b', label = 'Amitosis',  linewidth=2.0, alpha =1)
    ax.fill_between(t, np.array(a1)- np.array(error_a1), np.array(a1)+ np.array(error_a1), alpha =0.3, facecolor='b')

    ax.plot(t,a2,'deepskyblue', label = 'Mitosis', linewidth=2.0, alpha =1)
    ax.fill_between(t, np.array(a2)- np.array(error_a2), np.array(a2)+ np.array(error_a2), alpha =0.3, facecolor='deepskyblue')


    ax.plot(t,a3,'r', label = 'Sex Every Gen',  linewidth=2.0, alpha =1)
    ax.fill_between(t, np.array(a3)- np.array(error_a3), np.array(a3)+ np.array(error_a3), alpha =0.3, facecolor='r')

    ax.plot(t,a4,'m', label = 'Sex Every 100 Gens', linewidth=2.0, alpha =1)
    ax.fill_between(t, np.array(a4)- np.array(error_a4), np.array(a4)+ np.array(error_a4), alpha =0.3, facecolor='m')


  
    plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

    ax.minorticks_off()

    ax.set_ylim(0.4, 1)

    plt.legend(loc='upper left', frameon=False, prop={'size':26})
# Out:
# Ploidy 16

# %%
print 'RM Fit Mean', rm_fit_mean[4][-1]
print 'RM Fit 95CI_Lower', rm_fit_mean[4][-1]-1.98*rm_fit_std[4][-1]/10
print 'RM Fit 95CI_Upper', rm_fit_mean[4][-1]+1.98*rm_fit_std[4][-1]/10
# Out:
# RM Fit Mean 0.893425511122
# RM Fit 95CI_Lower 0.886997383598
# RM Fit 95CI_Upper 0.899853638645

# %%
print 'Amito Fit Mean', amito_fit_mean[4][-1]
print 'Amito Fit 95CI_Lower', amito_fit_mean[4][-1]-1.98*amito_fit_std[4][-1]/10
print 'Amito Fit 95CI_Upper', amito_fit_mean[4][-1]+1.98*amito_fit_std[4][-1]/10
# Out:
# Amito Fit Mean 0.858378533646
# Amito Fit 95CI_Lower 0.848464297335
# Amito Fit 95CI_Upper 0.868292769957

# %%
p_list = [1,2,4,8,16,32,45,64,128]    
    
for i in range(8,9):    
    fig = plt.figure(figsize=(16, 12), dpi =300)
    ax = fig.add_subplot(111)
    publication_figure(ax)

    ax.set_xlim(0,2000)

    t = generation_list

    a1 = amito_fit_mean[i]
    error_a1 = list(1.98* np.array(amito_fit_std[i])/((100)**0.5))

    a2 = mito_fit_mean[i]
    error_a2 = list(1.98* np.array(mito_fit_std[i])/((100)**0.5))

    a3 = rm_fit_mean[i]
    error_a3 = list(1.98* np.array(rm_fit_std[i])/((100)**0.5))

    a4 = rme_fit_mean[i]
    error_a4 = list(1.98* np.array(rme_fit_std[i])/((100)**0.5))


    a5 = sf_fit_mean[i]
    error_a5 = list(1.98* np.array(sf_fit_std[i])/((100)**0.5))

    a6 = sfe_fit_mean[i]
    error_a6 = list(1.98* np.array(sfe_fit_std[i])/((100)**0.5))

    ax.set_xlabel('Time (generations)', fontsize =40)
    ax.set_ylabel('Mean Fitness', fontsize =40)

    print 'Ploidy', p_list[i]

    ax.plot(t,a1,'b', label = 'Amitosis',  linewidth=2.0, alpha =1)
    ax.fill_between(t, np.array(a1)- np.array(error_a1), np.array(a1)+ np.array(error_a1), alpha =0.3, facecolor='b')

    ax.plot(t,a2,'deepskyblue', label = 'Mitosis', linewidth=2.0, alpha =1)
    ax.fill_between(t, np.array(a2)- np.array(error_a2), np.array(a2)+ np.array(error_a2), alpha =0.3, facecolor='deepskyblue')


    ax.plot(t,a3,'r', label = 'Sex Every Gen',  linewidth=2.0, alpha =1)
    ax.fill_between(t, np.array(a3)- np.array(error_a3), np.array(a3)+ np.array(error_a3), alpha =0.3, facecolor='r')

    ax.plot(t,a4,'m', label = 'Sex Every 100 Gens', linewidth=2.0, alpha =1)
    ax.fill_between(t, np.array(a4)- np.array(error_a4), np.array(a4)+ np.array(error_a4), alpha =0.3, facecolor='m')


  
    plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

    ax.minorticks_off()

    ax.set_ylim(0.4, 1)

    plt.legend(loc='upper left', frameon=False, prop={'size':26})
# Out:
# Ploidy 128

# %%
print 'RM Fit Mean', rm_fit_mean[8][-1]
print 'RM Fit 95CI_Lower', rm_fit_mean[8][-1]-1.98*rm_fit_std[8][-1]/10
print 'RM Fit 95CI_Upper', rm_fit_mean[8][-1]+1.98*rm_fit_std[8][-1]/10
# Out:
# RM Fit Mean 0.557653437018
# RM Fit 95CI_Lower 0.544028024573
# RM Fit 95CI_Upper 0.571278849462

# %%
print 'Amito Fit Mean', amito_fit_mean[8][-1]
print 'Amito Fit 95CI_Lower', amito_fit_mean[8][-1]-1.98*amito_fit_std[8][-1]/10
print 'Amito Fit 95CI_Upper', amito_fit_mean[8][-1]+1.98*amito_fit_std[8][-1]/10
# Out:
# Amito Fit Mean 0.741077233895
# Amito Fit 95CI_Lower 0.732320848996
# Amito Fit 95CI_Upper 0.749833618794

# %%
print 'Mito Fit Mean', mito_fit_mean[8][-1]
print 'Mito Fit 95CI_Lower', mito_fit_mean[8][-1]-1.98*mito_fit_std[8][-1]/10
print 'Mito Fit 95CI_Upper', mito_fit_mean[8][-1]+1.98*mito_fit_std[8][-1]/10
# Out:
# Mito Fit Mean 0.845177912763
# Mito Fit 95CI_Lower 0.838559642417
# Mito Fit 95CI_Upper 0.851796183108
