# %%
'''
Note that this setting (dim =10, genomic mutation rate =0.01) is what we used in our further analyses.

Here we further tested the reduction of loci and dimenation # from 100 to 10. Here we scalely reduce the genomic mutation rate 
to be 0.01 (which mutaiton rate per site per generation is the same as that in 100 loci system). We compared the performance of
amitosis and mitosis in adaptation with different ploidies. Also, we analyzed the mutation statistics here.

Setting: universal pleyotropy, # of loci and dimension =10, genomic mutation rate =0.01, population size N = 500, STD =0.05.

Here using the corrected data of random.seed()

'''
# Out:
# '\nNote that this setting (dim =10, genomic mutation rate =0.01) is what we used in our further analyses.\n\nHere we further tested the reduction of loci and dimenation # from 100 to 10. Here we scalely reduce the genomic mutation rate \nto be 0.01 (which mutaiton rate per site per generation is the same as that in 100 loci system). We compared the performance of\namitosis and mitosis in adaptation with different ploidies. Also, we analyzed the mutation statistics here.\n\nSetting: universal pleyotropy, # of loci and dimension =10, genomic mutation rate =0.01, population size N = 500, STD =0.05.\n\nHere using the corrected data of random.seed()\n\n'

# %%
from __future__ import division
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import pickle
# %matplotlib inline

# %%
generation_list = []

for i in range(2002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 2002

# %%
def get_data1(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.mFit_Mean,dtype=float)))
        fit_std.extend(list(pd.Series(f.mFit_Std,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.varFit_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.varFit_Std,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %%
def get_data2(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.meanFit,dtype=float)))
        fit_std.extend(list(pd.Series(f.PopMeanFit_STD,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.PopVar_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.PopVar_STD,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %%
def read_file(data):
    with open(data, 'rb') as f:
        x = pickle.load(f)
        
    return x

# %% [markdown]
# ## N =500_Initial fitness =0.5_Dim = 10_Different Ploidy

# %% [markdown]
# ### 1. Fitness dynamics comparison

# %%
## Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\2.3. Universal Pley_Diff Ploidy_GMU = 0.01\Amito")

# %%
amito = ['Cor_UvPley_GMU001_Dim10_P1_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_UvPley_GMU001_Dim10_P2_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_UvPley_GMU001_Dim10_P4_Amito_Fit_N500_Fit05_SM005.csv', \
         'Cor_UvPley_GMU001_Dim10_P8_Amito_Fit_N500_Fit05_SM005.csv',  'Cor_UvPley_GMU001_Dim10_P16_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_UvPley_GMU001_Dim10_P32_Amito_Fit_N500_Fit05_SM005.csv', \
        'Cor_UvPley_GMU001_Dim10_P45_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_UvPley_GMU001_Dim10_P64_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_UvPley_GMU001_Dim10_P128_Amito_Fit_N500_Fit05_SM005.csv']

# %%
m = get_data1(amito)

amito_fit_mean =m[0]
amito_fit_std = m[1]
amito_var_mean =m[2]
amito_var_std = m[3]

# %%
## Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\2.3. Universal Pley_Diff Ploidy_GMU = 0.01\Mito")

# %%
mito = ['Cor_UvPley_GMU001_Dim10_P1_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_UvPley_GMU001_Dim10_P2_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_UvPley_GMU001_Dim10_P4_Mito_Fit_N500_Fit05_SM005.csv', \
         'Cor_UvPley_GMU001_Dim10_P8_Mito_Fit_N500_Fit05_SM005.csv',  'Cor_UvPley_GMU001_Dim10_P16_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_UvPley_GMU001_Dim10_P32_Mito_Fit_N500_Fit05_SM005.csv', \
        'Cor_UvPley_GMU001_Dim10_P45_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_UvPley_GMU001_Dim10_P64_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_UvPley_GMU001_Dim10_P128_Mito_Fit_N500_Fit05_SM005.csv']

# %%
s = get_data1(mito)

mito_fit_mean =s[0]
mito_fit_std = s[1]
mito_var_mean =s[2]
mito_var_std = s[3]

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 30})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(8)
    ax.spines['bottom'].set_linewidth(8)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=10, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=10, direction='out', pad=50, colors='black')

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list

a1 = amito_fit_mean[0]
error_a1 = list(1.96* np.array(amito_fit_std[0])/((100)**0.5))

a2 = mito_fit_mean[0]
error_a2 = list(1.96* np.array(mito_fit_std[0])/((100)**0.5))


b1 = amito_fit_mean[1]
error_b1 = list(1.96* np.array(amito_fit_std[1])/((100)**0.5))

b2 = mito_fit_mean[1]
error_b2 = list(1.96* np.array(mito_fit_std[1])/((100)**0.5))


c1 = amito_fit_mean[2]
error_c1 = list(1.96* np.array(amito_fit_std[2])/((100)**0.5))

c2 = mito_fit_mean[2]
error_c2 = list(1.96* np.array(mito_fit_std[2])/((100)**0.5))


d1 = amito_fit_mean[3]
error_d1 = list(1.96* np.array(amito_fit_std[3])/((100)**0.5))

d2 = mito_fit_mean[3]
error_d2 = list(1.96* np.array(mito_fit_std[3])/((100)**0.5))


e1 = amito_fit_mean[4]
error_e1 = list(1.96* np.array(amito_fit_std[4])/((100)**0.5))

e2 = mito_fit_mean[4]
error_e2 = list(1.96* np.array(mito_fit_std[4])/((100)**0.5))


f1 = amito_fit_mean[5]
error_f1 = list(1.96* np.array(amito_fit_std[5])/((100)**0.5))

f2 = mito_fit_mean[5]
error_f2 = list(1.96* np.array(mito_fit_std[5])/((100)**0.5))


g1 = amito_fit_mean[6]
error_g1 = list(1.96* np.array(amito_fit_std[6])/((100)**0.5))

g2 = mito_fit_mean[6]
error_g2 = list(1.96* np.array(mito_fit_std[6])/((100)**0.5))


h1 = amito_fit_mean[7]
error_h1 = list(1.96* np.array(amito_fit_std[7])/((100)**0.5))

h2 = mito_fit_mean[7]
error_h2 = list(1.96* np.array(mito_fit_std[7])/((100)**0.5))

i1 = amito_fit_mean[8]
error_i1 = list(1.96* np.array(amito_fit_std[8])/((100)**0.5))

i2 = mito_fit_mean[8]
error_i2 = list(1.96* np.array(mito_fit_std[8])/((100)**0.5))




ax.set_title('FGM_Uv Pley_N =500_IF =0.5_Dim = 10_GMU = 0.01_Diff P_Corrected', fontsize =35)
ax.set_xlabel('Time (generations)', fontsize =30)
ax.set_ylabel('Mean Fitness', fontsize =30)


# ax.semilogy(t, a, )

# ax.set_yscale('log')

# ax.plot(t,a1,'y', label = 'Amito_P =1',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(a1)- np.array(error_a1), np.array(a1)+ np.array(error_a1), alpha =0.45, facecolor='y')

# ax.plot(t,a2,'y', label = 'Mito_P =1', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(a2)- np.array(error_a2), np.array(a2)+ np.array(error_a2), alpha =0.25, facecolor='y')


# ax.plot(t,b1,'b', label = 'Amito_P =2',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(b1)- np.array(error_b1), np.array(b1)+ np.array(error_b1), alpha =0.3, facecolor='b')

# ax.plot(t,b2,'b', label = 'Mito_P =2', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(b2)- np.array(error_b2), np.array(b2)+ np.array(error_b2), alpha =0.1, facecolor='b')


# ax.plot(t,c1,'navy', label = 'Amito_P =4',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(c1)- np.array(error_c1), np.array(c1)+ np.array(error_c1), alpha =0.3, facecolor='navy')

# ax.plot(t,c2,'navy', label = 'Mito_P =4', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(c2)- np.array(error_c2), np.array(c2)+ np.array(error_c2), alpha =0.1, facecolor='navy')



# ax.plot(t,d1,'g', label = 'Amito_P =8',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(d1)- np.array(error_d1), np.array(d1)+ np.array(error_d1), alpha =0.3, facecolor='g')

# ax.plot(t,d2,'g', label = 'Mito_P =8', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(d2)- np.array(error_d2), np.array(d2)+ np.array(error_d2), alpha =0.1, facecolor='g')


# ax.plot(t,e1,'m', label = 'Amito_P =16',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(e1)- np.array(error_e1), np.array(e1)+ np.array(error_e1), alpha =0.3, facecolor='m')

# ax.plot(t,e2,'m', label = 'Mito_P =16', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(e2)- np.array(error_e2), np.array(e2)+ np.array(error_e2), alpha =0.1, facecolor='m')


# ax.plot(t,f1,'c', label = 'Amito_P =32',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(f1)- np.array(error_f1), np.array(f1)+ np.array(error_f1), alpha =0.3, facecolor='c')

# ax.plot(t,f2,'c', label = 'Mito_P =32', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(f2)- np.array(error_f2), np.array(f2)+ np.array(error_f2), alpha =0.1, facecolor='c')


# ax.plot(t,g1,'r', label = 'Amito_P =45',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.3, facecolor='r')

# ax.plot(t,g2,'r', label = 'Mito_P =45', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(g2)- np.array(error_g2), np.array(g2)+ np.array(error_g2), alpha =0.1, facecolor='r')


# ax.plot(t,h1,'maroon', label = 'Amito_P =64',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(h1)- np.array(error_h1), np.array(h1)+ np.array(error_h1), alpha =0.3, facecolor='maroon')

# ax.plot(t,h2,'maroon', label = 'Mito_P =64', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(h2)- np.array(error_h2), np.array(h2)+ np.array(error_h2), alpha =0.1, facecolor='maroon')

ax.plot(t,i1,'k', label = 'Amito_P =128',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(i1)- np.array(error_i1), np.array(i1)+ np.array(error_i1), alpha =0.3, facecolor='k')

ax.plot(t,i2,'k', label = 'Mito_P =128', ls ='--',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(i2)- np.array(error_i2), np.array(i2)+ np.array(error_i2), alpha =0.1, facecolor='k')




plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =25)
frame = legend.get_frame()
# frame.set_framecolor('black')
frame.set_edgecolor('black')

# extraticks=[0.45]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

ax.set_ylim(0.45, 1)



# plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/1000), ',')))
# Out:
# (0.45, 1)

# %% [markdown]
# ### 2. Selection coefficient comparison

# %% [markdown]
# #### (1) Mean effect of new generating mutations in each generation within each population (s_mean in file)

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\2.3. Universal Pley_Diff Ploidy_GMU = 0.01\Amito")

# %%
amito_f1 = ['Cor_UvPley_GMU001_Dim10_P1_Amito_MutMeanS_N500_Fit05_SM005', 'Cor_UvPley_GMU001_Dim10_P2_Amito_MutMeanS_N500_Fit05_SM005', 'Cor_UvPley_GMU001_Dim10_P4_Amito_MutMeanS_N500_Fit05_SM005', \
           'Cor_UvPley_GMU001_Dim10_P8_Amito_MutMeanS_N500_Fit05_SM005', 'Cor_UvPley_GMU001_Dim10_P16_Amito_MutMeanS_N500_Fit05_SM005', 'Cor_UvPley_GMU001_Dim10_P32_Amito_MutMeanS_N500_Fit05_SM005', \
           'Cor_UvPley_GMU001_Dim10_P45_Amito_MutMeanS_N500_Fit05_SM005', 'Cor_UvPley_GMU001_Dim10_P64_Amito_MutMeanS_N500_Fit05_SM005', \
           'Cor_UvPley_GMU001_Dim10_P128_Amito_MutMeanS_N500_Fit05_SM005']

# %%
amito_s1 = []

for i in amito_f1:
    amito_s1.append(read_file(i))

# %%
np.nanmean(amito_s1[-2][-3])
# Out:
# 5.7578124986050694e-05

# %%
total_amito_s1_mean = []
total_amito_s1_std = []
for i in range(len(amito_s1)):
    amito_sm_mean = []
    amito_sm_std = []
    for j in range(len(amito_s1[0])):
        amito_sm_mean.append(np.nanmean(amito_s1[i][j]))
        amito_sm_std.append(np.nanstd(amito_s1[i][j]))
    
    total_amito_s1_mean.append(amito_sm_mean)
    total_amito_s1_std.append(amito_sm_std)

# %%
total_amito_s1_mean[-3][-1]
# Out:
# 0.00028245489474116545

# %%
len(total_amito_s1_mean[2])
# Out:
# 21

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\2.3. Universal Pley_Diff Ploidy_GMU = 0.01\Mito")

# %%
mito_f1 = ['Cor_UvPley_GMU001_Dim10_P1_Mito_MutMeanS_N500_Fit05_SM005', 'Cor_UvPley_GMU001_Dim10_P2_Mito_MutMeanS_N500_Fit05_SM005', 'Cor_UvPley_GMU001_Dim10_P4_Mito_MutMeanS_N500_Fit05_SM005', \
           'Cor_UvPley_GMU001_Dim10_P8_Mito_MutMeanS_N500_Fit05_SM005', 'Cor_UvPley_GMU001_Dim10_P16_Mito_MutMeanS_N500_Fit05_SM005', 'Cor_UvPley_GMU001_Dim10_P32_Mito_MutMeanS_N500_Fit05_SM005', \
           'Cor_UvPley_GMU001_Dim10_P45_Mito_MutMeanS_N500_Fit05_SM005', 'Cor_UvPley_GMU001_Dim10_P64_Mito_MutMeanS_N500_Fit05_SM005', \
           'Cor_UvPley_GMU001_Dim10_P128_Mito_MutMeanS_N500_Fit05_SM005']

# %%
mito_s1 = []

for i in mito_f1:
    mito_s1.append(read_file(i))

# %%
total_mito_s1_mean = []
total_mito_s1_std = []
for i in range(len(mito_s1)):
    mito_sm_mean = []
    mito_sm_std = []
    for j in range(len(mito_s1[0])):
        mito_sm_mean.append(np.nanmean(mito_s1[i][j]))
        mito_sm_std.append(np.nanstd(mito_s1[i][j]))
    
    total_mito_s1_mean.append(mito_sm_mean)
    total_mito_s1_std.append(mito_sm_std)

# %%
generation_list2 = []

for i in range(21):
    generation_list2.append(100*i)
    
print(len(generation_list2))
# Out:
# 21

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list2

a1 = total_amito_s1_mean[0]
error_a1 = list(1.96* np.array(total_amito_s1_std[0])/((100)**0.5))

a2 = total_mito_s1_mean[0]
error_a2 = list(1.96* np.array(total_mito_s1_std[0])/((100)**0.5))


b1 = total_amito_s1_mean[1]
error_b1 = list(1.96* np.array(total_amito_s1_std[1])/((100)**0.5))

b2 = total_mito_s1_mean[1]
error_b2 = list(1.96* np.array(total_mito_s1_std[1])/((100)**0.5))


c1 = total_amito_s1_mean[2]
error_c1 = list(1.96* np.array(total_amito_s1_std[2])/((100)**0.5))

c2 = total_mito_s1_mean[2]
error_c2 = list(1.96* np.array(total_mito_s1_std[2])/((100)**0.5))


d1 = total_amito_s1_mean[3]
error_d1 = list(1.96* np.array(total_amito_s1_std[3])/((100)**0.5))

d2 = total_mito_s1_mean[3]
error_d2 = list(1.96* np.array(total_mito_s1_std[3])/((100)**0.5))


e1 = total_amito_s1_mean[4]
error_e1 = list(1.96* np.array(total_amito_s1_std[4])/((100)**0.5))

e2 = total_mito_s1_mean[4]
error_e2 = list(1.96* np.array(total_mito_s1_std[4])/((100)**0.5))


f1 = total_amito_s1_mean[5]
error_f1 = list(1.96* np.array(total_amito_s1_std[5])/((100)**0.5))

f2 = total_mito_s1_mean[5]
error_f2 = list(1.96* np.array(total_mito_s1_std[5])/((100)**0.5))


g1 = total_amito_s1_mean[6]
error_g1 = list(1.96* np.array(total_amito_s1_std[6])/((100)**0.5))

g2 = total_mito_s1_mean[6]
error_g2 = list(1.96* np.array(total_mito_s1_std[6])/((100)**0.5))


h1 = total_amito_s1_mean[7]
error_h1 = list(1.96* np.array(total_amito_s1_std[7])/((100)**0.5))

h2 = total_mito_s1_mean[7]
error_h2 = list(1.96* np.array(total_mito_s1_std[7])/((100)**0.5))


i1 = total_amito_s1_mean[8]
error_i1 = list(1.96* np.array(total_amito_s1_std[8])/((100)**0.5))

i2 = total_mito_s1_mean[8]
error_i2 = list(1.96* np.array(total_mito_s1_std[8])/((100)**0.5))


ax.set_title('FGM_Uv Pley_N =500_IF =0.5_Dim = 10_GMU = 0.01_Diff P_Mean S of Mut Generated Each Gen_Corrected', fontsize =25)
ax.set_xlabel('Time (generations)', fontsize =30)
ax.set_ylabel('Mean Fitness', fontsize =30)


# ax.semilogy(t, a, )

# ax.set_yscale('log')

# ax.plot(t,a1,'y', label = 'Amito_P =1',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(a1)- np.array(error_a1), np.array(a1)+ np.array(error_a1), alpha =0.45, facecolor='y')

# ax.plot(t,a2,'y', label = 'Mito_P =1', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(a2)- np.array(error_a2), np.array(a2)+ np.array(error_a2), alpha =0.25, facecolor='y')


# ax.plot(t,b1,'b', label = 'Amito_P =2',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(b1)- np.array(error_b1), np.array(b1)+ np.array(error_b1), alpha =0.3, facecolor='b')

# ax.plot(t,b2,'b', label = 'Mito_P =2', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(b2)- np.array(error_b2), np.array(b2)+ np.array(error_b2), alpha =0.1, facecolor='b')


# ax.plot(t,c1,'navy', label = 'Amito_P =4',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(c1)- np.array(error_c1), np.array(c1)+ np.array(error_c1), alpha =0.3, facecolor='navy')

# ax.plot(t,c2,'navy', label = 'Mito_P =4', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(c2)- np.array(error_c2), np.array(c2)+ np.array(error_c2), alpha =0.1, facecolor='navy')



# ax.plot(t,d1,'g', label = 'Amito_P =8',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(d1)- np.array(error_d1), np.array(d1)+ np.array(error_d1), alpha =0.3, facecolor='g')

# ax.plot(t,d2,'g', label = 'Mito_P =8', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(d2)- np.array(error_d2), np.array(d2)+ np.array(error_d2), alpha =0.1, facecolor='g')


# ax.plot(t,e1,'m', label = 'Amito_P =16',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(e1)- np.array(error_e1), np.array(e1)+ np.array(error_e1), alpha =0.3, facecolor='m')

# ax.plot(t,e2,'m', label = 'Mito_P =16', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(e2)- np.array(error_e2), np.array(e2)+ np.array(error_e2), alpha =0.1, facecolor='m')


# ax.plot(t,f1,'c', label = 'Amito_P =32',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(f1)- np.array(error_f1), np.array(f1)+ np.array(error_f1), alpha =0.3, facecolor='c')

# ax.plot(t,f2,'c', label = 'Mito_P =32', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(f2)- np.array(error_f2), np.array(f2)+ np.array(error_f2), alpha =0.1, facecolor='c')


# ax.plot(t,g1,'r', label = 'Amito_P =45',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.3, facecolor='r')

# ax.plot(t,g2,'r', label = 'Mito_P =45', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(g2)- np.array(error_g2), np.array(g2)+ np.array(error_g2), alpha =0.1, facecolor='r')


# ax.plot(t,h1,'maroon', label = 'Amito_P =64',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(h1)- np.array(error_h1), np.array(h1)+ np.array(error_h1), alpha =0.3, facecolor='maroon')

# ax.plot(t,h2,'maroon', label = 'Mito_P =64', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(h2)- np.array(error_h2), np.array(h2)+ np.array(error_h2), alpha =0.1, facecolor='maroon')

ax.plot(t,i1,'k', label = 'Amito_P =128',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(i1)- np.array(error_i1), np.array(i1)+ np.array(error_i1), alpha =0.3, facecolor='k')

ax.plot(t,i2,'k', label = 'Mito_P =128', ls ='--',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(i2)- np.array(error_i2), np.array(i2)+ np.array(error_i2), alpha =0.1, facecolor='k')



# plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =25)
frame = legend.get_frame()
# frame.set_framecolor('black')
frame.set_edgecolor('black')

# extraticks=[0.95]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

# ax.set_ylim(-0.01, 0.004)



# plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/1000), ',')))

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list2

a1 = np.array(total_amito_s1_mean[0])*1
error_a1 = list(1.96* np.array(total_amito_s1_std[0])*1/((100)**0.5))

a2 = np.array(total_mito_s1_mean[0])*1
error_a2 = list(1.96* np.array(total_mito_s1_std[0])*1/((100)**0.5))


b1 = np.array(total_amito_s1_mean[1])*2
error_b1 = list(1.96* np.array(total_amito_s1_std[1])*2/((100)**0.5))

b2 = np.array(total_mito_s1_mean[1])*2
error_b2 = list(1.96* np.array(total_mito_s1_std[1])*2/((100)**0.5))


c1 = np.array(total_amito_s1_mean[2])*4
error_c1 = list(1.96* np.array(total_amito_s1_std[2])*4/((100)**0.5))

c2 = np.array(total_mito_s1_mean[2])*4
error_c2 = list(1.96* np.array(total_mito_s1_std[2])*4/((100)**0.5))


d1 = np.array(total_amito_s1_mean[3])*8
error_d1 = list(1.96* np.array(total_amito_s1_std[3])*8/((100)**0.5))

d2 = np.array(total_mito_s1_mean[3])*8
error_d2 = list(1.96* np.array(total_mito_s1_std[3])*8/((100)**0.5))


e1 = np.array(total_amito_s1_mean[4])*16
error_e1 = list(1.96* np.array(total_amito_s1_std[4])*16/((100)**0.5))

e2 = np.array(total_mito_s1_mean[4])*16
error_e2 = list(1.96* np.array(total_mito_s1_std[4])*16/((100)**0.5))


f1 = np.array(total_amito_s1_mean[5])*32
error_f1 = list(1.96* np.array(total_amito_s1_std[5])*32/((100)**0.5))

f2 = np.array(total_mito_s1_mean[5])*32
error_f2 = list(1.96* np.array(total_mito_s1_std[5])*32/((100)**0.5))


g1 = np.array(total_amito_s1_mean[6])*45
error_g1 = list(1.96* np.array(total_amito_s1_std[6])*45/((100)**0.5))

g2 = np.array(total_mito_s1_mean[6])*45
error_g2 = list(1.96* np.array(total_mito_s1_std[6])*45/((100)**0.5))


h1 = np.array(total_amito_s1_mean[7])*64
error_h1 = list(1.96* np.array(total_amito_s1_std[7])*64/((100)**0.5))

h2 = np.array(total_mito_s1_mean[7])*64
error_h2 = list(1.96* np.array(total_mito_s1_std[7])*64/((100)**0.5))


i1 = np.array(total_amito_s1_mean[8])*128
error_i1 = list(1.96* np.array(total_amito_s1_std[8])*128/((100)**0.5))

i2 = np.array(total_mito_s1_mean[8])*128
error_i2 = list(1.96* np.array(total_mito_s1_std[8])*128/((100)**0.5))


ax.set_title('FGM_Uv Pley_N =500_IF =0.5_Dim = 10_GMU = 0.001_Diff P_Mean S of Mut Generated Each Gen_Fixed_Cor', fontsize =25)
ax.set_xlabel('Time (generations)', fontsize =30)
ax.set_ylabel('Mean Fitness', fontsize =30)


# ax.semilogy(t, a, )

# ax.set_yscale('log')

# ax.plot(t,a1,'y', label = 'Amito_P =1',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(a1)- np.array(error_a1), np.array(a1)+ np.array(error_a1), alpha =0.45, facecolor='y')

# ax.plot(t,a2,'y', label = 'Mito_P =1', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(a2)- np.array(error_a2), np.array(a2)+ np.array(error_a2), alpha =0.25, facecolor='y')


# ax.plot(t,b1,'b', label = 'Amito_P =2',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(b1)- np.array(error_b1), np.array(b1)+ np.array(error_b1), alpha =0.3, facecolor='b')

# ax.plot(t,b2,'b', label = 'Mito_P =2', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(b2)- np.array(error_b2), np.array(b2)+ np.array(error_b2), alpha =0.1, facecolor='b')


# ax.plot(t,c1,'navy', label = 'Amito_P =4',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(c1)- np.array(error_c1), np.array(c1)+ np.array(error_c1), alpha =0.3, facecolor='navy')

# ax.plot(t,c2,'navy', label = 'Mito_P =4', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(c2)- np.array(error_c2), np.array(c2)+ np.array(error_c2), alpha =0.1, facecolor='navy')



# ax.plot(t,d1,'g', label = 'Amito_P =8',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(d1)- np.array(error_d1), np.array(d1)+ np.array(error_d1), alpha =0.3, facecolor='g')

# ax.plot(t,d2,'g', label = 'Mito_P =8', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(d2)- np.array(error_d2), np.array(d2)+ np.array(error_d2), alpha =0.1, facecolor='g')


# ax.plot(t,e1,'m', label = 'Amito_P =16',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(e1)- np.array(error_e1), np.array(e1)+ np.array(error_e1), alpha =0.3, facecolor='m')

# ax.plot(t,e2,'m', label = 'Mito_P =16', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(e2)- np.array(error_e2), np.array(e2)+ np.array(error_e2), alpha =0.1, facecolor='m')


# ax.plot(t,f1,'c', label = 'Amito_P =32',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(f1)- np.array(error_f1), np.array(f1)+ np.array(error_f1), alpha =0.3, facecolor='c')

# ax.plot(t,f2,'c', label = 'Mito_P =32', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(f2)- np.array(error_f2), np.array(f2)+ np.array(error_f2), alpha =0.1, facecolor='c')


# ax.plot(t,g1,'r', label = 'Amito_P =45',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.3, facecolor='r')

# ax.plot(t,g2,'r', label = 'Mito_P =45', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(g2)- np.array(error_g2), np.array(g2)+ np.array(error_g2), alpha =0.1, facecolor='r')


# ax.plot(t,h1,'maroon', label = 'Amito_P =64',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(h1)- np.array(error_h1), np.array(h1)+ np.array(error_h1), alpha =0.3, facecolor='maroon')

# ax.plot(t,h2,'maroon', label = 'Mito_P =64', ls ='--',  linewidth=2.0, alpha =1)
# ax.fill_between(t, np.array(h2)- np.array(error_h2), np.array(h2)+ np.array(error_h2), alpha =0.1, facecolor='maroon')

ax.plot(t,i1,'k', label = 'Amito_P =128',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(i1)- np.array(error_i1), np.array(i1)+ np.array(error_i1), alpha =0.3, facecolor='k')

ax.plot(t,i2,'k', label = 'Mito_P =128', ls ='--',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(i2)- np.array(error_i2), np.array(i2)+ np.array(error_i2), alpha =0.1, facecolor='k')



# plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =25)
frame = legend.get_frame()
# frame.set_framecolor('black')
frame.set_edgecolor('black')

# extraticks=[0.03]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

# ax.set_ylim(-1.5, 1)



# plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/1000), ',')))

# %%
fig = plt.figure(figsize=(20, 16))
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list2

a1 = abs(np.array(total_amito_s1_mean[0])*1*500)
a2 = abs(np.array(total_mito_s1_mean[0])*1*500)


b1 = abs(np.array(total_amito_s1_mean[1])*2*500)
b2 = abs(np.array(total_mito_s1_mean[1])*2*500)


c1 = abs(np.array(total_amito_s1_mean[2])*4*500)
c2 = abs(np.array(total_mito_s1_mean[2])*4*500)


d1 = abs(np.array(total_amito_s1_mean[3])*8*500)
d2 = abs(np.array(total_mito_s1_mean[3])*8*500)


e1 = abs(np.array(total_amito_s1_mean[4])*16*500)
e2 = abs(np.array(total_mito_s1_mean[4])*16*500)


f1 = abs(np.array(total_amito_s1_mean[5])*32*500)
f2 = abs(np.array(total_mito_s1_mean[5])*32*500)


g1 = abs(np.array(total_amito_s1_mean[6])*45*500)
g2 = abs(np.array(total_mito_s1_mean[6])*45*500)


h1 = abs(np.array(total_amito_s1_mean[7])*64*500)
h2 = abs(np.array(total_mito_s1_mean[7])*64*500)


i1 = abs(np.array(total_amito_s1_mean[8])*128*500)
i2 = abs(np.array(total_mito_s1_mean[8])*128*500)


ax.set_title('FGM_Uv Pley_N =500_IF =0.5_Dim = 10_GMU = 0.01_Diff P_Mean S of Mut Generated Each Gen * N * Ploidy_Corrected', fontsize =35)
ax.set_xlabel('Time (generations)', fontsize =30)
ax.set_ylabel('Mean Fitness', fontsize =30)


# ax.semilogy(t, a, )

# ax.set_yscale('log')


# ax.plot(t,a1,'y', label = 'Amito_P =1',  linewidth=2.0, alpha =1)

# ax.plot(t,a2,'y', label = 'Mito_P =1', ls ='--',  linewidth=2.0, alpha =1)


# ax.plot(t,b1,'b', label = 'Amito_P =2',  linewidth=2.0, alpha =1)

# ax.plot(t,b2,'b', label = 'Mito_P =2', ls ='--',  linewidth=2.0, alpha =1)


# ax.plot(t,c1,'navy', label = 'Amito_P =4',  linewidth=2.0, alpha =1)

# ax.plot(t,c2,'navy', label = 'Mito_P =4', ls ='--',  linewidth=2.0, alpha =1)


# ax.plot(t,d1,'g', label = 'Amito_P =8',  linewidth=2.0, alpha =1)

# ax.plot(t,d2,'g', label = 'Mito_P =8', ls ='--',  linewidth=2.0, alpha =1)



# ax.plot(t,e1,'m', label = 'Amito_P =16',  linewidth=2.0, alpha =1)

# ax.plot(t,e2,'m', label = 'Mito_P =16', ls ='--',  linewidth=2.0, alpha =1)


# ax.plot(t,f1,'c', label = 'Amito_P =32',  linewidth=2.0, alpha =1)

# ax.plot(t,f2,'c', label = 'Mito_P =32', ls ='--',  linewidth=2.0, alpha =1)
 

# ax.plot(t,g1,'r', label = 'Amito_P =45',  linewidth=2.0, alpha =1)

# ax.plot(t,g2,'r', label = 'Mito_P =45', ls ='--',  linewidth=2.0, alpha =1)


# ax.plot(t,h1,'maroon', label = 'Amito_P =64',  linewidth=2.0, alpha =1)

# ax.plot(t,h2,'maroon', label = 'Mito_P =64', ls ='--',  linewidth=2.0, alpha =1)


ax.plot(t,i1,'k', label = 'Amito_P =128',  linewidth=2.0, alpha =1)

ax.plot(t,i2,'k', label = 'Mito_P =128', ls ='--',  linewidth=2.0, alpha =1)


plt.axhline(y=1, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =25)
frame = legend.get_frame()
# frame.set_framecolor('black')
frame.set_edgecolor('black')

# extraticks=[0.95]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

# ax.set_ylim(0, 500)



# plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/1000), ',')))
