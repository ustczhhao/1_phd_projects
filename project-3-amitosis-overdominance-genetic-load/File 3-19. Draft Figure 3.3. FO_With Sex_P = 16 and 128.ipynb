# %%
from __future__ import division
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import pickle
# %matplotlib inline

# %%
generation_list = []

for i in range(2002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 2002

# %%
def get_data1(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.mFit_Mean,dtype=float)))
        fit_std.extend(list(pd.Series(f.mFit_Std,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.varFit_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.varFit_Std,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %% [markdown]
# ## N =500_Initial fitness =0.5_Dim = 10_Different Ploidy

# %% [markdown]
# ### Fitness dynamics comparison

# %% [markdown]
# #### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\1.3. No Pley_Diff Ploidy_GMU = 0.01\Amito")

# %%
amito = [ 'Cor_NoPley_GMU001_Dim10_P16_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P128_Amito_Fit_N500_Fit05_SM005.csv']

# %%
m = get_data1(amito)

amito_fit_mean =m[0]
amito_fit_std = m[1]
amito_var_mean =m[2]
amito_var_std = m[3]

# %% [markdown]
# #### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\1.3. No Pley_Diff Ploidy_GMU = 0.01\Mito")

# %%
mito = ['Cor_NoPley_GMU001_Dim10_P16_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P128_Mito_Fit_N500_Fit05_SM005.csv']

# %%
s = get_data1(mito)

mito_fit_mean =s[0]
mito_fit_std = s[1]
mito_var_mean =s[2]
mito_var_std = s[3]

# %% [markdown]
# #### RM

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190331_Test of FGM_7_Trial of Incorporating Sex\Data\1. NP_FO_D =L =10\RM")

# %%
rm = [ 'FO_NP_GMU001_Dim10_P16_RM_Fit_N500_Fit05_SM005_Cor.csv',  'FO_NP_GMU001_Dim10_P128_RM_Fit_N500_Fit05_SM005_Cor.csv']

# %%
n = get_data1(rm)

rm_fit_mean =n[0]
rm_fit_std = n[1]
rm_var_mean =n[2]
rm_var_std = n[3]

# %% [markdown]
# #### RME100

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190331_Test of FGM_7_Trial of Incorporating Sex\Data\1. NP_FO_D =L =10\RME100")

# %%
rme = ['FO_NP_GMU001_Dim10_P16_RME100_Fit_N500_Fit05_SM005_Cor.csv', 'FO_NP_GMU001_Dim10_P128_RME100_Fit_N500_Fit05_SM005_Cor.csv']

# %%
n2 = get_data1(rme)

rme_fit_mean =n2[0]
rme_fit_std = n2[1]
rme_var_mean =n2[2]
rme_var_std = n2[3]

# %%
print 'P16 RME100_Mean', rme_fit_mean[0][-1]
print 'P16 RME100_95% CI Lower', rme_fit_mean[0][-1]-1.98*rme_fit_std[0][-1]/10
print 'P16 RME100_95% CI Upper', rme_fit_mean[0][-1]+1.98*rme_fit_std[0][-1]/10
# Out:
# P16 RME100_Mean 0.721581171796
# P16 RME100_95% CI Lower 0.702538970606
# P16 RME100_95% CI Upper 0.740623372986

# %%
print 'P128 RME100_Mean', rme_fit_mean[1][-1]
print 'P128 RME100_95% CI Lower', rme_fit_mean[1][-1]-1.98*rme_fit_std[1][-1]/10
print 'P128 RME100_95% CI Upper', rme_fit_mean[1][-1]+1.98*rme_fit_std[1][-1]/10
# Out:
# P128 RME100_Mean 0.498673572289
# P128 RME100_95% CI Lower 0.489465407917
# P128 RME100_95% CI Upper 0.50788173666

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 36})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(6)
    ax.spines['bottom'].set_linewidth(6)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')

# %% [markdown]
# ### Ploidy = 16

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)

ax.set_xlim(0,2000)

t = generation_list

a1 = amito_fit_mean[0]
error_a1 = list(1.98* np.array(amito_fit_std[0])/((100)**0.5))

a2 = mito_fit_mean[0]
error_a2 = list(1.98* np.array(mito_fit_std[0])/((100)**0.5))

a3 = rm_fit_mean[0]
error_a3 = list(1.98* np.array(rm_fit_std[0])/((100)**0.5))

a4 = rme_fit_mean[0]
error_a4 = list(1.98* np.array(rme_fit_std[0])/((100)**0.5))


ax.set_xlabel('Time (generations)', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36)


ax.plot(t,a1,'b', label = 'Amitosis',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a1)- np.array(error_a1), np.array(a1)+ np.array(error_a1), alpha =0.3, facecolor='b')

ax.plot(t,a2,'deepskyblue', label = 'Mitosis', linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a2)- np.array(error_a2), np.array(a2)+ np.array(error_a2), alpha =0.3, facecolor='deepskyblue')


ax.plot(t,a3,'r', label = 'Sex Every Gen',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a3)- np.array(error_a3), np.array(a3)+ np.array(error_a3), alpha =0.3, facecolor='r')

ax.plot(t,a4,'m', label = 'Sex Every 100 Gens', linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a4)- np.array(error_a4), np.array(a4)+ np.array(error_a4), alpha =0.3, facecolor='m')


  
plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()

ax.set_ylim(0.4, 1)

#     plt.legend(loc='upper left', frameon=False, prop={'size':26})
# Out:
# (0.4, 1)

# %% [markdown]
# ### Ploidy = 128

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)

ax.set_xlim(0,2000)

t = generation_list

a1 = amito_fit_mean[1]
error_a1 = list(1.98* np.array(amito_fit_std[1])/((100)**0.5))

a2 = mito_fit_mean[1]
error_a2 = list(1.98* np.array(mito_fit_std[1])/((100)**0.5))

a3 = rm_fit_mean[1]
error_a3 = list(1.98* np.array(rm_fit_std[1])/((100)**0.5))

a4 = rme_fit_mean[1]
error_a4 = list(1.98* np.array(rme_fit_std[1])/((100)**0.5))


ax.set_xlabel('Time (generations)', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36, color = 'white')


ax.plot(t,a1,'b', label = 'Amitosis',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a1)- np.array(error_a1), np.array(a1)+ np.array(error_a1), alpha =0.3, facecolor='b')

ax.plot(t,a2,'deepskyblue', label = 'Mitosis', linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a2)- np.array(error_a2), np.array(a2)+ np.array(error_a2), alpha =0.3, facecolor='deepskyblue')


ax.plot(t,a3,'r', label = 'Sex Every Gen',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a3)- np.array(error_a3), np.array(a3)+ np.array(error_a3), alpha =0.3, facecolor='r')

ax.plot(t,a4,'m', label = 'Sex Every 100 Gens', linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a4)- np.array(error_a4), np.array(a4)+ np.array(error_a4), alpha =0.3, facecolor='m')


  
plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()

ax.set_ylim(0.4, 1)

plt.legend(loc='upper left', frameon=False, prop={'size':30})
