# %%
from __future__ import division
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import pickle
import seaborn as sns
# %matplotlib inline

# %%
generation_list = []

for i in range(2002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 2002

# %%
def get_data1(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.mFit_Mean,dtype=float)))
        fit_std.extend(list(pd.Series(f.mFit_Std,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.varFit_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.varFit_Std,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %%
def read_file(data):
    with open(data, 'rb') as f:
        x = pickle.load(f)
        
    return x

# %% [markdown]
# ## N =500_Initial fitness =0.5_Dim = 10_Ploidy = 45

# %% [markdown]
# ### No pleiotropy

# %%
## Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\1.3. No Pley_Diff Ploidy_GMU = 0.01\Amito")

# %%
np_amito = ['Cor_NoPley_GMU001_Dim10_P45_Amito_Fit_N500_Fit05_SM005.csv']

# %%
m1 = get_data1(np_amito)
np_amito_fit_mean =m1[0]
np_amito_fit_std = m1[1]

# %%
print 'No Pley_Amito_Mean', np_amito_fit_mean[0][-1]
print 'No Pley_Amito_95% CI_Lower', np_amito_fit_mean[0][-1]-1.98*np_amito_fit_std[0][-1]/10
print 'No Pley_Amito_95% CI_Upper', np_amito_fit_mean[0][-1]+1.98*np_amito_fit_std[0][-1]/10
# Out:
# No Pley_Amito_Mean 0.756809726652
# No Pley_Amito_95% CI_Lower 0.746402302751
# No Pley_Amito_95% CI_Upper 0.767217150554

# %%
## Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\1.3. No Pley_Diff Ploidy_GMU = 0.01\Mito")

# %%
np_mito = ['Cor_NoPley_GMU001_Dim10_P45_Mito_Fit_N500_Fit05_SM005.csv']

# %%
s1 = get_data1(np_mito)

np_mito_fit_mean =s1[0]
np_mito_fit_std = s1[1]

# %%
len(np_mito_fit_mean)
# Out:
# 1

# %%
print 'No Pley_Mito_Mean', np_mito_fit_mean[0][-1]
print 'No Pley_Mito_95% CI_Lower', np_mito_fit_mean[0][-1]-1.98*np_mito_fit_std[0][-1]/10
print 'No Pley_Mito_95% CI_Upper', np_mito_fit_mean[0][-1]+1.98*np_mito_fit_std[0][-1]/10
# Out:
# No Pley_Mito_Mean 0.855002565537
# No Pley_Mito_95% CI_Lower 0.848706262054
# No Pley_Mito_95% CI_Upper 0.86129886902

# %% [markdown]
# ### Peliotropy level = 2

# %%
### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190224_FGM_7_Restricted Pleiotropy_Varied Pley\Data\1.1. FO_Dim =10 and Loci =10_PL =2\Amito")

# %%
rp_amito = ['Rv_FO_N500_L10_D10_PL2_F05_R001_SM005_Amito_P45_Cor.csv']

# %%
m2 = get_data1(rp_amito)
rp_amito_fit_mean =m2[0]
rp_amito_fit_std = m2[1]

# %%
print 'Rs Pley_Amito_Mean', rp_amito_fit_mean[0][-1]
print 'Rs Pley_Amito_95% CI_Lower', rp_amito_fit_mean[0][-1]-1.98*rp_amito_fit_std[0][-1]/10
print 'Rs Pley_Amito_95% CI_Upper', rp_amito_fit_mean[0][-1]+1.98*rp_amito_fit_std[0][-1]/10
# Out:
# Rs Pley_Amito_Mean 0.773495011236
# Rs Pley_Amito_95% CI_Lower 0.764155013252
# Rs Pley_Amito_95% CI_Upper 0.78283500922

# %%
### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20190224_FGM_7_Restricted Pleiotropy_Varied Pley\Data\1.1. FO_Dim =10 and Loci =10_PL =2\Mito")

# %%
rp_mito = ['Rv_FO_N500_L10_D10_PL2_F05_R001_SM005_Mito_P45_Cor.csv']

# %%
s2 = get_data1(rp_mito)

rp_mito_fit_mean =s2[0]
rp_mito_fit_std = s2[1]

# %%
print 'Rs Pley_Mito_Mean', rp_mito_fit_mean[0][-1]
print 'Rs Pley_Mito_95% CI_Lower', rp_mito_fit_mean[0][-1]-1.98*rp_mito_fit_std[0][-1]/10
print 'Rs Pley_Mito_95% CI_Upper', rp_mito_fit_mean[0][-1]+1.98*rp_mito_fit_std[0][-1]/10
# Out:
# Rs Pley_Mito_Mean 0.828813941056
# Rs Pley_Mito_95% CI_Lower 0.820082433197
# Rs Pley_Mito_95% CI_Upper 0.837545448916

# %% [markdown]
# ### Universal pleiotropy

# %%
### Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\2.3. Universal Pley_Diff Ploidy_GMU = 0.01\Amito")

# %%
up_amito = ['Cor_UvPley_GMU001_Dim10_P45_Amito_Fit_N500_Fit05_SM005.csv']

# %%
m3 = get_data1(up_amito)
up_amito_fit_mean =m3[0]
up_amito_fit_std = m3[1]

# %%
print 'Uv Pley_Amito_Mean', up_amito_fit_mean[0][-1]
print 'Uv Pley_Amito_95% CI_Lower', up_amito_fit_mean[0][-1]-1.98*up_amito_fit_std[0][-1]/10
print 'Uv Pley_Amito_95% CI_Upper', up_amito_fit_mean[0][-1]+1.98*up_amito_fit_std[0][-1]/10
# Out:
# Uv Pley_Amito_Mean 0.795543416682
# Uv Pley_Amito_95% CI_Lower 0.789041987478
# Uv Pley_Amito_95% CI_Upper 0.802044845886

# %%
### Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\2.3. Universal Pley_Diff Ploidy_GMU = 0.01\Mito")

# %%
up_mito = ['Cor_UvPley_GMU001_Dim10_P45_Mito_Fit_N500_Fit05_SM005.csv']

# %%
s3 = get_data1(up_mito)

up_mito_fit_mean =s3[0]
up_mito_fit_std = s3[1]

# %%
print 'Uv Pley_Mito_Mean', up_mito_fit_mean[0][-1]
print 'Uv Pley_Mito_95% CI_Lower', up_mito_fit_mean[0][-1]-1.98*up_mito_fit_std[0][-1]/10
print 'Uv Pley_Mito_95% CI_Upper', up_mito_fit_mean[0][-1]+1.98*up_mito_fit_std[0][-1]/10
# Out:
# Uv Pley_Mito_Mean 0.836097390764
# Uv Pley_Mito_95% CI_Lower 0.82958003296
# Uv Pley_Mito_95% CI_Upper 0.842614748567

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 36})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(6)
    ax.spines['bottom'].set_linewidth(6)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')

# %%
fig = plt.figure(figsize=(16, 12), dpi = 300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list

a1 = np_amito_fit_mean[0]
error_a1 = list(1.98* np.array(np_amito_fit_std[0])/((100)**0.5))

a2 = rp_amito_fit_mean[0]
error_a2 = list(1.98* np.array(rp_amito_fit_std[0])/((100)**0.5))

a3 = up_amito_fit_mean[0]
error_a3 = list(1.98* np.array(up_amito_fit_std[0])/((100)**0.5))


ax.set_xlabel('Time (generations)', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36, color = 'white')


ax.plot(t,a1,'b', label = 'No Pleiotropy',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a1)- np.array(error_a1), np.array(a1)+ np.array(error_a1), alpha =0.3, facecolor='b')

ax.plot(t,a2,'g', label = 'Restricted Pleiotropy',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a2)- np.array(error_a2), np.array(a2)+ np.array(error_a2), alpha =0.3, facecolor='g')

ax.plot(t,a3,'r', label = 'Universal Pleiotropy',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a3)- np.array(error_a3), np.array(a3)+ np.array(error_a3), alpha =0.3, facecolor='r')


plt.legend(loc='upper left', frameon=False, prop={'size':30})

plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()

ax.set_ylim(0.4, 1)
# Out:
# (0.4, 1)

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list

a1 = np_mito_fit_mean[0]
error_a1 = list(1.98* np.array(np_mito_fit_std[0])/((100)**0.5))

a2 = rp_mito_fit_mean[0]
error_a2 = list(1.98* np.array(rp_mito_fit_std[0])/((100)**0.5))

a3 = up_mito_fit_mean[0]
error_a3 = list(1.98* np.array(up_mito_fit_std[0])/((100)**0.5))


ax.set_xlabel('Time (generations)', fontsize =36)
ax.set_ylabel('Population Mean Fitness', fontsize =36)


ax.plot(t,a1,'b', label = 'No Pleiotropy',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a1)- np.array(error_a1), np.array(a1)+ np.array(error_a1), alpha =0.3, facecolor='b')

ax.plot(t,a2,'g', label = 'Restricted Pleiotropy',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a2)- np.array(error_a2), np.array(a2)+ np.array(error_a2), alpha =0.3, facecolor='g')

ax.plot(t,a3,'r', label = 'Universal Pleiotropy',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a3)- np.array(error_a3), np.array(a3)+ np.array(error_a3), alpha =0.3, facecolor='r')


# plt.legend(loc='upper left', frameon=False, prop={'size':30})

plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()

ax.set_ylim(0.4, 1)
# Out:
# (0.4, 1)
