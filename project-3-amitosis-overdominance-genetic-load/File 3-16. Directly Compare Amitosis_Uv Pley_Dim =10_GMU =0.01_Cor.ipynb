# %%
'''
Note that we didn't get too much information from this result.

Here we directly compare the effect of amitosis under universal pleiotropy. The code we used is the same as the file "Directly
Compare Amitosis" in folder 181006_3. Testing of Universal Pleiotropy.


Here we let each setting divides by mitosis for 1KG, then shut down mutatation and selection processes, and only let the 
population undergo amitosis process, and then compare the fitness dynamics of amitosis.

Using corrected data collected with random.seed()

'''
# Out:
# '\nNote that we didn\'t get too much information from this result.\n\nHere we directly compare the effect of amitosis under universal pleiotropy. The code we used is the same as the file "Directly\nCompare Amitosis" in folder 181006_3. Testing of Universal Pleiotropy.\n\n\nHere we let each setting divides by mitosis for 1KG, then shut down mutatation and selection processes, and only let the \npopulation undergo amitosis process, and then compare the fitness dynamics of amitosis.\n\nUsing corrected data collected with random.seed()\n\n'

# %%
from __future__ import division
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import pickle
# %matplotlib inline

# %%
generation_list = []

for i in range(2002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 2002

# %%
def get_data(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.mFit_Mean,dtype=float)))
        fit_std.extend(list(pd.Series(f.mFit_Std,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.varFit_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.varFit_Std,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %%
def read_file(data):
    with open(data, 'rb') as f:
        x = pickle.load(f)
        
    return x

# %% [markdown]
# ## N =500_Initial fitness =0.5_Different Ploidy
# ### 1. Fitness dynamics comparison

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\3.4. Direct compare amitosis_Universal Pley_GMU = 0.01")

# %%
amito = ['Cor_Test_Uv_GMU001_NoSel_P1_L10_Fit_N500_Fit05_SM005_2KG.csv', 'Cor_Test_Uv_GMU001_NoSel_P2_L10_Fit_N500_Fit05_SM005_2KG.csv', \
         'Cor_Test_Uv_GMU001_NoSel_P4_L10_Fit_N500_Fit05_SM005_2KG.csv', 'Cor_Test_Uv_GMU001_NoSel_P8_L10_Fit_N500_Fit05_SM005_2KG.csv',  \
         'Cor_Test_Uv_GMU001_NoSel_P16_L10_Fit_N500_Fit05_SM005_2KG.csv', 'Cor_Test_Uv_GMU001_NoSel_P32_L10_Fit_N500_Fit05_SM005_2KG.csv', \
        'Cor_Test_Uv_GMU001_NoSel_P45_L10_Fit_N500_Fit05_SM005_2KG.csv', 'Cor_Test_Uv_GMU001_NoSel_P64_L10_Fit_N500_Fit05_SM005_2KG.csv', \
         'Cor_Test_Uv_GMU001_NoSel_P128_L10_Fit_N500_Fit05_SM005_2KG.csv']

# %%
m = get_data(amito)

amito_fit_mean =m[0]
amito_fit_std = m[1]
amito_var_mean =m[2]
amito_var_std = m[3]

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 30})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(8)
    ax.spines['bottom'].set_linewidth(8)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=10, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=10, direction='out', pad=50, colors='black')

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list

a1 = amito_fit_mean[0]
error_a1 = list(1.96* np.array(amito_fit_std[0])/((100)**0.5))

b1 = amito_fit_mean[1]
error_b1 = list(1.96* np.array(amito_fit_std[1])/((100)**0.5))

c1 = amito_fit_mean[2]
error_c1 = list(1.96* np.array(amito_fit_std[2])/((100)**0.5))

d1 = amito_fit_mean[3]
error_d1 = list(1.96* np.array(amito_fit_std[3])/((100)**0.5))

e1 = amito_fit_mean[4]
error_e1 = list(1.96* np.array(amito_fit_std[4])/((100)**0.5))

f1 = amito_fit_mean[5]
error_f1 = list(1.96* np.array(amito_fit_std[5])/((100)**0.5))

g1 = amito_fit_mean[6]
error_g1 = list(1.96* np.array(amito_fit_std[6])/((100)**0.5))

h1 = amito_fit_mean[7]
error_h1 = list(1.96* np.array(amito_fit_std[7])/((100)**0.5))

i1 = amito_fit_mean[8]
error_i1 = list(1.96* np.array(amito_fit_std[8])/((100)**0.5))



ax.set_title('FGM_Uv Pley_Dim =10_GMU =0.01_N =500_IF=0.5_Directly Comp Amito_Corrected', fontsize =35)
ax.set_xlabel('Time (generations)', fontsize =30)
ax.set_ylabel('Mean Fitness', fontsize =30)


# ax.semilogy(t, a, )

# ax.set_yscale('log')

ax.plot(t,a1,'y', label = 'P =1',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(a1)- np.array(error_a1), np.array(a1)+ np.array(error_a1), alpha =0.45, facecolor='y')

ax.plot(t,b1,'b', label = 'P =2',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(b1)- np.array(error_b1), np.array(b1)+ np.array(error_b1), alpha =0.3, facecolor='b')

ax.plot(t,c1,'navy', label = 'P =4',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(c1)- np.array(error_c1), np.array(c1)+ np.array(error_c1), alpha =0.3, facecolor='navy')

ax.plot(t,d1,'g', label = 'P =8',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(d1)- np.array(error_d1), np.array(d1)+ np.array(error_d1), alpha =0.3, facecolor='g')

ax.plot(t,e1,'m', label = 'P =16',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(e1)- np.array(error_e1), np.array(e1)+ np.array(error_e1), alpha =0.3, facecolor='m')

ax.plot(t,f1,'c', label = 'P =32',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(f1)- np.array(error_f1), np.array(f1)+ np.array(error_f1), alpha =0.3, facecolor='c')

ax.plot(t,g1,'r', label = 'P =45',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.3, facecolor='r')

ax.plot(t,h1,'maroon', label = 'P =64',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(h1)- np.array(error_h1), np.array(h1)+ np.array(error_h1), alpha =0.3, facecolor='maroon')

ax.plot(t,i1,'k', label = 'P =128',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(i1)- np.array(error_i1), np.array(i1)+ np.array(error_i1), alpha =0.3, facecolor='k')



plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()
# ax.yaxis.set_ticks(np.arange(start, end, 0.1))

legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =25)
frame = legend.get_frame()
# frame.set_framecolor('black')
frame.set_edgecolor('black')

# extraticks=[0.95]
# ax.set_yticks(list(ax.get_yticks()) + extraticks)

ax.set_ylim(0.35, 0.75)



# plt.show()
# plt.gca().get_xaxis().set_major_formatter(FuncFormatter(lambda x, p: format(int(x/1000), ',')))
# Out:
# (0.35, 0.75)

# %% [markdown]
# ### 2. Final fitness comparison

# %%
final_fit = [amito_fit_mean[i][1999] for i in range(9)]

# %%
final_fit
# Out:
# [0.61368698937386557,
#  0.64073182467947942,
#  0.63470134426045999,
#  0.58264551738265324,
#  0.49051400275222362,
#  0.38034398350283444,
#  0.35856975887845982,
#  0.36890327229907177,
#  0.4188140192827457]

# %%
errorbar_fit = np.array([amito_fit_std[i][1999] for i in range(9)])*1.96/10
errorbar_fit
# Out:
# array([ 0.00294906,  0.00528415,  0.00490526,  0.00401609,  0.00443311,
#         0.00486713,  0.00409088,  0.00364941,  0.00248935])

# %%
type(errorbar_fit[0])
# Out:
# numpy.float64

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
publication_figure(ax)

# ax.set_ylim(0.9, 1)
ax.set_xlim(0.8,150)
ax.set_ylim(0.3,0.7)

ax.set_xscale('log',basex=2)

x = [1, 2, 4, 8, 16, 32, 45, 64, 128]
a = final_fit
error_a = errorbar_fit

ax.errorbar(x, a, yerr = error_a, label ='Amitosis', fmt='o', color = 'blue', markersize =12, lw=2, capsize=10, capthick=2)
ax.plot(x,a, color = 'blue', ls = '--')

# ax.plot(x,y3,'grey',label='Deterministic',marker='o', markersize =10, linestyle ='--',linewidth=2.0)

ax.set_title('Final Fitness of Directly Comp Amito_Dim =10_GMU =0.01_Uv Pley_Corrected',fontsize =30)

ax.set_xlabel('Ploidy', fontsize =30)
ax.set_ylabel('Final Fitness', fontsize =30)

ax.set_xticks([1,2,4,8, 16, 32, 45, 64, 128]) # choose which x locations to have ticks
ax.set_xticklabels([1,2,4,8, 16, 32, 45, 64, 128]) # set the labels to display at those ticks

plt.legend(loc='upper right', frameon=False, prop={'size':30})

# legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =15)
# frame = legend.get_frame()
# # frame.set_framecolor('black')
# frame.set_edgecolor('black')

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111)
publication_figure(ax)

# ax.set_ylim(0.9, 1)
ax.set_xlim(0.8,80)
ax.set_ylim(0.3,0.7)

ax.set_xscale('log',basex=2)

x = [1, 2, 4, 8, 16, 32, 45, 64]
a = final_fit[:-1]
error_a = errorbar_fit[:-1]

ax.errorbar(x, a, yerr = error_a, label ='Amitosis', fmt='o', color = 'blue', markersize =12, lw=2, capsize=10, capthick=2)
ax.plot(x,a, color = 'blue', ls = '--')

# ax.plot(x,y3,'grey',label='Deterministic',marker='o', markersize =10, linestyle ='--',linewidth=2.0)

ax.set_title('Final Fitness of Directly Comp Amito_Dim =10_GMU =0.01_Uv Pley',fontsize =30)

ax.set_xlabel('Ploidy', fontsize =30)
ax.set_ylabel('Final Fitness', fontsize =30)

ax.set_xticks([1,2,4,8, 16, 32, 45, 64]) # choose which x locations to have ticks
ax.set_xticklabels([1,2,4,8, 16, 32, 45, 64]) # set the labels to display at those ticks

plt.legend(loc='upper right', frameon=False, prop={'size':30})

# legend = ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize =15)
# frame = legend.get_frame()
# # frame.set_framecolor('black')
# frame.set_edgecolor('black')
