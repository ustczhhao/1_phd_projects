# %%
'''
Note that this setting (dim =10, genomic mutation rate =0.01) is what we used in our further analyses.

Here we further tested the reduction of loci and dimenation # from 100 to 10. Here we scalely reduce the genomic mutation rate 
to be 0.01 (which mutaiton rate per site per generation is the same as that in 100 loci system). We compared the performance of
amitosis and mitosis in adaptation with different ploidies. Also, we analyzed the mutation statistics here.

Setting: no pleyotropy, # of loci and dimension =10, genomic mutation rate =0.01, population size N = 500, STD =0.05.

Using corrected data with random.seed.

'''
# Out:
# '\nNote that this setting (dim =10, genomic mutation rate =0.01) is what we used in our further analyses.\n\nHere we further tested the reduction of loci and dimenation # from 100 to 10. Here we scalely reduce the genomic mutation rate \nto be 0.01 (which mutaiton rate per site per generation is the same as that in 100 loci system). We compared the performance of\namitosis and mitosis in adaptation with different ploidies. Also, we analyzed the mutation statistics here.\n\nSetting: no pleyotropy, # of loci and dimension =10, genomic mutation rate =0.01, population size N = 500, STD =0.05.\n\nUsing corrected data with random.seed.\n\n'

# %%
from __future__ import division
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import pickle
# %matplotlib inline

# %%
generation_list = []

for i in range(2002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 2002

# %%
def get_data1(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.mFit_Mean,dtype=float)))
        fit_std.extend(list(pd.Series(f.mFit_Std,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.varFit_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.varFit_Std,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %%
def get_data2(file_list):
    
    total_fit_mean = []
    total_fit_std = []
    
    total_var_mean = []
    total_var_std = []
    
    for i in file_list:
        f = pd.read_csv(i,dtype=str)
    
        fit_mean = []
        fit_std = []
    
        var_mean = []
        var_std = []
       
        fit_mean.extend(list(pd.Series(f.meanFit,dtype=float)))
        fit_std.extend(list(pd.Series(f.PopMeanFit_STD,dtype=float)))
    
        var_mean.extend(list(pd.Series(f.PopVar_Mean,dtype=float)))
        var_std.extend(list(pd.Series(f.PopVar_STD,dtype=float)))
    
        total_fit_mean.append(fit_mean)
        total_fit_std.append(fit_std)
    
        total_var_mean.append(var_mean)
        total_var_std.append(var_std)  
        
    return total_fit_mean, total_fit_std, total_var_mean, total_var_std

# %%
def read_file(data):
    with open(data, 'rb') as f:
        x = pickle.load(f)
        
    return x

# %% [markdown]
# ## N =500_Initial fitness =0.5_Dim = 10_Different Ploidy

# %% [markdown]
# ### 1. Fitness dynamics comparison

# %%
## Amitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\1.3. No Pley_Diff Ploidy_GMU = 0.01\Amito")

# %%
amito = ['Cor_NoPley_GMU001_Dim10_P1_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P2_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P4_Amito_Fit_N500_Fit05_SM005.csv', \
         'Cor_NoPley_GMU001_Dim10_P8_Amito_Fit_N500_Fit05_SM005.csv',  'Cor_NoPley_GMU001_Dim10_P16_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P32_Amito_Fit_N500_Fit05_SM005.csv', \
        'Cor_NoPley_GMU001_Dim10_P45_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P64_Amito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P128_Amito_Fit_N500_Fit05_SM005.csv']

# %%
m = get_data1(amito)

amito_fit_mean =m[0]
amito_fit_std = m[1]
amito_var_mean =m[2]
amito_var_std = m[3]

# %%
## Mitosis

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20181210_Test of FGM_4_Reduce Dim to 10\Data\1.3. No Pley_Diff Ploidy_GMU = 0.01\Mito")

# %%
mito = ['Cor_NoPley_GMU001_Dim10_P1_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P2_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P4_Mito_Fit_N500_Fit05_SM005.csv', \
         'Cor_NoPley_GMU001_Dim10_P8_Mito_Fit_N500_Fit05_SM005.csv',  'Cor_NoPley_GMU001_Dim10_P16_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P32_Mito_Fit_N500_Fit05_SM005.csv', \
        'Cor_NoPley_GMU001_Dim10_P45_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P64_Mito_Fit_N500_Fit05_SM005.csv', 'Cor_NoPley_GMU001_Dim10_P128_Mito_Fit_N500_Fit05_SM005.csv']

# %%
s = get_data1(mito)

mito_fit_mean =s[0]
mito_fit_std = s[1]
mito_var_mean =s[2]
mito_var_std = s[3]

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 30})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(6)
    ax.spines['bottom'].set_linewidth(6)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')

# %%
fig = plt.figure(figsize=(16, 12), dpi =300)
ax = fig.add_subplot(111)
publication_figure(ax)
# ax.scatter(0,0)

ax.set_xlim(0,2000)

t = generation_list


g1 = amito_fit_mean[6]
error_g1 = list(1.98* np.array(amito_fit_std[6])/((100)**0.5))

g2 = mito_fit_mean[6]
error_g2 = list(1.98* np.array(mito_fit_std[6])/((100)**0.5))


# ax.set_title('FGM_No Pley_N =500_IF =0.5_Dim = 10_GMU = 0.01_Diff Ploidy_Corrected', fontsize =30)
ax.set_xlabel('Time (generations)', fontsize =30)
ax.set_ylabel('Population Mean Fitness', fontsize =30)



ax.plot(t,g1,'b', label = 'Amitosis',  linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g1)- np.array(error_g1), np.array(g1)+ np.array(error_g1), alpha =0.3, facecolor='b')

ax.plot(t,g2,'deepskyblue', label = 'Mitosis', linewidth=2.0, alpha =1)
ax.fill_between(t, np.array(g2)- np.array(error_g2), np.array(g2)+ np.array(error_g2), alpha =0.3, facecolor='deepskyblue')



plt.legend(loc='upper left', frameon=False, prop={'size':30})

plt.axhline(y=0.5, linewidth=2.0, color ='k',ls ='dashed')

ax.minorticks_off()

ax.set_ylim(0.4, 1)
# Out:
# (0.4, 1)

# %%
print 'Amito Final Fit', g1[-1]
print 'Amito 95% CI_Lower', g1[-1]-error_g1[-1]
print 'Amito 95% CI_Upper', g1[-1]+error_g1[-1]
# Out:
# Amito Final Fit 0.756809726652
# Amito 95% CI_Lower 0.746402302751
# Amito 95% CI_Upper 0.767217150554

# %%
print 'Amito Final Fit', g1[1999]
print 'Amito 95% CI_Lower', g1[1999]-error_g1[1999]
print 'Amito 95% CI_Upper', g1[1999]+error_g1[1999]
# Out:
# Amito Final Fit 0.757037535516
# Amito 95% CI_Lower 0.746618258039
# Amito 95% CI_Upper 0.767456812993

# %%
print 'Mito Final Fit', g2[-1]
print 'Mito 95% CI_Lower', g2[-1]-error_g2[-1]
print 'Mito 95% CI_Upper', g2[-1]+error_g2[-1]
# Out:
# Mito Final Fit 0.855002565537
# Mito 95% CI_Lower 0.848706262054
# Mito 95% CI_Upper 0.86129886902

# %%
print 'Mito Final Fit', g2[1999]
print 'Mito 95% CI_Lower', g2[1999]-error_g2[1999]
print 'Mito 95% CI_Upper', g2[1999]+error_g2[1999]
# Out:
# Mito Final Fit 0.854805179168
# Mito 95% CI_Lower 0.848501986313
# Mito 95% CI_Upper 0.861108372023
