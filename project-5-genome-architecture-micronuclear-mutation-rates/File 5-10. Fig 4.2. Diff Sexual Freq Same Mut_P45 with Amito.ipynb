# %%
import matplotlib as lib
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import numpy as np
import pylab
import pandas as pd
import os
import pickle
# %matplotlib inline

# %%
generation_list = []

for i in range(20002):
    generation_list.append(i)
    
print(len(generation_list))
# Out:
# 20002

# %%
os.chdir(r"D:\Prof. Azevedo\Simulation of Ciliate Evolution\20180625_Equilibrium of facultative sex_Test. Efficiency of facultative selection\Data\1. Same MT but different Selection Freq_P45 FS with Amito\RM")

# %%
file_gmu1 = ['Contr4_Fit_P45_RM_E1_10GMU.csv','Contr4_Fit_P45_RM_E2_10GMU.csv','Contr4_Fit_P45_RM_E5_10GMU.csv', \
          'Contr4_Fit_P45_RM_E10_10GMU.csv', 'Contr4_Fit_P45_RM_E20_10GMU.csv', 'Contr4_Fit_P45_RM_E50_10GMU.csv', 'Contr4_Fit_P45_RM_E100_10GMU.csv', \
           'Contr4_Fit_P45_RM_E200_10GMU.csv', 'Contr4_Fit_P45_RM_E500_10GMU.csv']

# %%
gmu1_fit_mean = []
gmu1_fit_std = []


for i in file_gmu1:
    f = pd.read_csv(i,dtype=str)
    
    fit_mean = []
    fit_std = []
    
    fit_mean.extend(list(pd.Series(f.meanFit,dtype=float)))
    fit_std.extend(list(pd.Series(f.PopMeanFit_STD,dtype=float)))
    

    gmu1_fit_mean.append(fit_mean)
    gmu1_fit_std.append(fit_std)

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 30})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=10, width=5, direction='out', pad=25, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=10, width=5, direction='out', pad=25, colors='black')

# %%
def get_fit(gen_file, fit_file, std_file):
    with open(gen_file, 'rb') as f:
        sex_gen = pickle.load(f)
        
    sex_fit_mean = []
    sex_fit_std = []
    for i in sex_gen:
        sex_fit_mean.append(fit_file[i])
        sex_fit_std.append(std_file[i])
        
    return sex_fit_mean, sex_fit_std, sex_gen

# %%
total_gen_file = ['Contr4_P45_RM_SEX_GEN_E1', 'Contr4_P45_RM_SEX_GEN_E2', 'Contr4_P45_RM_SEX_GEN_E5', 'Contr4_P45_RM_SEX_GEN_E10', \
                 'Contr4_P45_RM_SEX_GEN_E20', 'Contr4_P45_RM_SEX_GEN_E50','Contr4_P45_RM_SEX_GEN_E100','Contr4_P45_RM_SEX_GEN_E200', \
                 'Contr4_P45_RM_SEX_GEN_E500']

# %%
total_fit_file = gmu1_fit_mean
total_std_file = gmu1_fit_std

# %%
len(total_std_file)
# Out:
# 9

# %%
total_sex_fit_mean = []
total_sex_fit_std = []
total_sex_gen = []

for i in range(9):
    e = get_fit(total_gen_file[i], total_fit_file[i], total_std_file[i])
    total_sex_fit_mean.append(e[0])
    total_sex_fit_std.append(e[1])
    total_sex_gen.append(e[2])

# %%
len(total_sex_gen[3])
# Out:
# 2001

# %%
len(total_sex_fit_mean[3])
# Out:
# 2001

# %%
def publication_figure(axis):
    plt.rcParams.update({'font.size': 36})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(6)
    ax.spines['bottom'].set_linewidth(6)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=20, width=6, direction='out', pad=50, colors='black')

# %% [markdown]
# # Equilibrium fitness comparison_1

# %% [markdown]
# Here we used the population mean fitness at the last generation as the equilibrium fitness for comparison, and also the STD is the STD of population mean fitnss in the last generation.

# %%
rmu_mean = []
rmu_std = []

for i in range(len(total_sex_fit_mean)):
    rmu_mean.append(total_sex_fit_mean[i][-1])
    rmu_std.append(total_sex_fit_std[i][-1])

# %%
rmu_mean
# Out:
# [0.36411616264196278,
#  0.59516912899421293,
#  0.80025187988609947,
#  0.87833061652167177,
#  0.92216821618517741,
#  0.9438233513248856,
#  0.94845313356706584,
#  0.94591030315302171,
#  0.94791286013791398]

# %%
rmu_std
# Out:
# [0.015257661638551015,
#  0.015805704602902523,
#  0.014316240519077362,
#  0.012430062516646776,
#  0.0079018675878586193,
#  0.0063823024799571585,
#  0.0049315140827972071,
#  0.0080718885422322532,
#  0.0098357329673968014]

# %%
rm_expect = np.exp(-1)
rm_expect
# Out:
# 0.36787944117144233

# %%
def publication_figure2(axis):
    plt.rcParams.update({'font.size': 18})
    ax = axis
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['left'].set_position(('outward', 10))
    ax.spines['bottom'].set_position(('outward', 10))
    #ax.xaxis.set_ticks([])
    ax.tick_params(axis='x', which='both', bottom='on', top='off',labelbottom='on', size=10, width=5, direction='out', pad=25, colors='black')
    ax.tick_params(axis='y', which='both', left='on', right='off',labelbottom='on', size=10, width=5, direction='out', pad=25, colors='black')

# %% [markdown]
# ## Figure 4.2

# %% [markdown]
# ### Old version

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

fig = plt.figure(figsize=(10,8), dpi =300)
ax = fig.add_subplot(111)
publication_figure2(ax)

ax.set_ylim(0.3, 1)
# ax.set_xlim(1,129)

x = range(1, 10)


# N =100
y2 = np.array(rmu_mean)
yerr2 = 1.98*np.array(rmu_std)/((100)**0.5)
ax.errorbar(x, y2, yerr = yerr2, label ='RM', fmt='o', color = 'red', mfc='none', markersize =8, lw=2, capsize=5, capthick=1)
ax.plot(x,y2, color = 'red', ls = '--')

ax.axhline(y=rm_expect, xmin=0, xmax=10, color ='blue', lw =2, ls ='dashed')

# x = range(10)
my_xticks = ['E1','E2', 'E5','E10','E20', 'E50', 'E100', 'E200', 'E500']
plt.xticks(x, my_xticks, rotation =0)


ax.set_xlabel('Sexual Frequency', fontsize =20)
ax.set_ylabel('Equilibrium Pop Mean Fitness', fontsize =20)

# %% [markdown]
# #### New Version

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

fig = plt.figure(figsize=(10,8), dpi =300)
ax = fig.add_subplot(111)
publication_figure2(ax)

ax.set_ylim(0.3, 1)
ax.set_xlim(0.8,550)

x = [1, 2, 5, 10, 20, 50, 100, 200, 500]
ax.set_xscale('log',basex=2)


# N =100
y2 = np.array(rmu_mean)
yerr2 = 1.98*np.array(rmu_std)/((100)**0.5)
ax.errorbar(x, y2, yerr = yerr2, label ='RM', fmt='o', color = 'red', mfc='none', markersize =8, lw=2, capsize=5, capthick=1)
ax.plot(x,y2, color = 'red', ls = '--')

ax.axhline(y=rm_expect, xmin=0, xmax=10, color ='blue', lw =2, ls ='dashed')


ax.set_xticks([1, 2, 5, 10, 20, 50, 100, 200, 500]) # choose which x locations to have ticks
ax.set_xticklabels([1, 2, 5, 10, 20, 50, 100, 200, 500]) # set the labels to display at those ticks


ax.set_xlabel(r'Sexual Period $(\tau)$', fontsize =20)
ax.set_ylabel('Equilibrium Pop Mean Fitness', fontsize =20)
